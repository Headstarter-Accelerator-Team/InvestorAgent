# %% [markdown]
# # Install Libraries

# %%
! pip install yfinance langchain_pinecone openai python-dotenv langchain-community sentence_transformers
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.10/dist-packages (0.2.49)
# Collecting langchain_pinecone
#   Downloading langchain_pinecone-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.54.4)
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Collecting langchain-community
#   Downloading langchain_community-0.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: sentence_transformers in /usr/local/lib/python3.10/dist-packages (3.2.1)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.26.4)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.10/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: lxml>=4.9.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (5.3.0)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.3.6)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2024.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.10/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.10/dist-packages (from yfinance) (3.17.8)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (4.12.3)
# Requirement already satisfied: html5lib>=1.1 in /usr/local/lib/python3.10/dist-packages (from yfinance) (1.1)
# Collecting aiohttp<3.10,>=3.9.5 (from langchain_pinecone)
#   Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.5 kB)
# Requirement already satisfied: langchain-core<0.4,>=0.3 in /usr/local/lib/python3.10/dist-packages (from langchain_pinecone) (0.3.19)
# Collecting pinecone-client<6.0.0,>=5.0.0 (from langchain_pinecone)
#   Downloading pinecone_client-5.0.1-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.2)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.7.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from openai) (2.9.2)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.6)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (2.0.36)
# Collecting dataclasses-json<0.7,>=0.5.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<0.5.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# Collecting langchain<0.4.0,>=0.3.8 (from langchain-community)
#   Downloading langchain-0.3.9-py3-none-any.whl.metadata (7.1 kB)
# Collecting langchain-core<0.4,>=0.3 (from langchain_pinecone)
#   Downloading langchain_core-0.3.21-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.1.143)
# Collecting pydantic-settings<3.0.0,>=2.4.0 (from langchain-community)
#   Downloading pydantic_settings-2.6.1-py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (9.0.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (4.46.2)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (2.5.1+cu121)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.5.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (0.26.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence_transformers) (11.0.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (1.17.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<3.10,>=3.9.5->langchain_pinecone) (4.0.3)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.10)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.2)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.6)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading marshmallow-3.23.1-py3-none-any.whl.metadata (7.5 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: six>=1.9 in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (3.16.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.20.0->sentence_transformers) (24.2)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from langchain<0.4.0,>=0.3.8->langchain-community) (0.3.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core<0.4,>=0.3->langchain_pinecone) (1.33)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (3.10.11)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from langsmith<0.2.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->yfinance) (2024.2)
# Collecting pinecone-plugin-inference<2.0.0,>=1.0.3 (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone)
#   Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl.metadata (2.2 kB)
# Collecting pinecone-plugin-interface<0.0.8,>=0.0.7 (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone)
#   Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.10/dist-packages (from pinecone-client<6.0.0,>=5.0.0->langchain_pinecone) (2.2.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1.9.0->openai) (2.23.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.31->yfinance) (3.4.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.1.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (3.1.4)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence_transformers) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.11.0->sentence_transformers) (1.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (2024.9.11)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.41.0->sentence_transformers) (0.20.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence_transformers) (3.5.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4,>=0.3->langchain_pinecone) (3.0.0)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from yarl<2.0,>=1.0->aiohttp<3.10,>=3.9.5->langchain_pinecone) (0.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence_transformers) (3.0.2)
# Downloading langchain_pinecone-0.2.0-py3-none-any.whl (11 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading langchain_community-0.3.9-py3-none-any.whl (2.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 27.1 MB/s eta 0:00:00
# Downloading aiohttp-3.9.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 46.8 MB/s eta 0:00:00
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Downloading langchain-0.3.9-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 40.6 MB/s eta 0:00:00
# Downloading langchain_core-0.3.21-py3-none-any.whl (409 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 409.5/409.5 kB 21.3 MB/s eta 0:00:00
# Downloading pinecone_client-5.0.1-py3-none-any.whl (244 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.8/244.8 kB 14.4 MB/s eta 0:00:00
# Downloading pydantic_settings-2.6.1-py3-none-any.whl (28 kB)
# Downloading marshmallow-3.23.1-py3-none-any.whl (49 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 2.9 MB/s eta 0:00:00
# Downloading pinecone_plugin_inference-1.1.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 5.2 MB/s eta 0:00:00
# Downloading pinecone_plugin_interface-0.0.7-py3-none-any.whl (6.2 kB)
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: python-dotenv, pinecone-plugin-interface, mypy-extensions, marshmallow, httpx-sse, typing-inspect, pinecone-plugin-inference, pydantic-settings, pinecone-client, dataclasses-json, aiohttp, langchain-core, langchain_pinecone, langchain, langchain-community
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.11.2
#     Uninstalling aiohttp-3.11.2:
#       Successfully uninstalled aiohttp-3.11.2
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.19
#     Uninstalling langchain-core-0.3.19:
#       Successfully uninstalled langchain-core-0.3.19
#   Attempting uninstall: langchain
#     Found existing installation: langchain 0.3.7
#     Uninstalling langchain-0.3.7:
#       Successfully uninstalled langchain-0.3.7
# Successfully installed aiohttp-3.9.5 dataclasses-json-0.6.7 httpx-sse-0.4.0 langchain-0.3.9 langchain-community-0.3.9 langchain-core-0.3.21 langchain_pinecone-0.2.0 marshmallow-3.23.1 mypy-extensions-1.0.0 pinecone-client-5.0.1 pinecone-plugin-inference-1.1.0 pinecone-plugin-interface-0.0.7 pydantic-settings-2.6.1 python-dotenv-1.0.1 typing-inspect-0.9.0

# %%
from langchain_pinecone import PineconeVectorStore
from openai import OpenAI
import dotenv
import json
import yfinance as yf
import concurrent.futures
from langchain_community.embeddings import HuggingFaceEmbeddings
from google.colab import userdata
from langchain.schema import Document
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from pinecone import Pinecone
import numpy as np
import requests
import os

# %%
def get_stock_info(symbol: str) -> dict:
    """
    Retrieves and formats detailed information about a stock from Yahoo Finance.

    Args:
        symbol (str): The stock ticker symbol to look up.

    Returns:
        dict: A dictionary containing detailed stock information, including ticker, name,
              business summary, city, state, country, industry, and sector.
    """
    data = yf.Ticker(symbol)
    stock_info = data.info

    properties = {
        "Ticker": stock_info.get('symbol', 'Information not available'),
        'Name': stock_info.get('longName', 'Information not available'),
        'Business Summary': stock_info.get('longBusinessSummary'),
        'City': stock_info.get('city', 'Information not available'),
        'State': stock_info.get('state', 'Information not available'),
        'Country': stock_info.get('country', 'Information not available'),
        'Industry': stock_info.get('industry', 'Information not available'),
        'Sector': stock_info.get('sector', 'Information not available')
    }

    return properties

# %%
def get_huggingface_embeddings(text, model_name="sentence-transformers/all-mpnet-base-v2"):
    """
    Generates embeddings for the given text using a specified Hugging Face model.

    Args:
        text (str): The input text to generate embeddings for.
        model_name (str): The name of the Hugging Face model to use.
                          Defaults to "sentence-transformers/all-mpnet-base-v2".

    Returns:
        np.ndarray: The generated embeddings as a NumPy array.
    """
    model = SentenceTransformer(model_name)
    return model.encode(text)


def cosine_similarity_between_sentences(sentence1, sentence2):
    """
    Calculates the cosine similarity between two sentences.

    Args:
        sentence1 (str): The first sentence for similarity comparison.
        sentence2 (str): The second sentence for similarity comparison.

    Returns:
        float: The cosine similarity score between the two sentences,
               ranging from -1 (completely opposite) to 1 (identical).

    Notes:
        Prints the similarity score to the console in a formatted string.
    """
    # Get embeddings for both sentences
    embedding1 = np.array(get_huggingface_embeddings(sentence1))
    embedding2 = np.array(get_huggingface_embeddings(sentence2))

    # Reshape embeddings for cosine_similarity function
    embedding1 = embedding1.reshape(1, -1)
    embedding2 = embedding2.reshape(1, -1)

    # Calculate cosine similarity
    similarity = cosine_similarity(embedding1, embedding2)
    similarity_score = similarity[0][0]
    print(f"Cosine similarity between the two sentences: {similarity_score:.4f}")
    return similarity_score


# Example usage
sentence1 = "I like walking to the park"
sentence2 = "I like walking to the office"

similarity = cosine_similarity_between_sentences(sentence1, sentence2)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Cosine similarity between the two sentences: 0.7394

# %%
aapl_info = get_stock_info('AAPL')
print(aapl_info)
# Out:
# {'Ticker': 'AAPL', 'Name': 'Apple Inc.', 'Business Summary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts, as well as advertising services include third-party licensing arrangements and its own advertising platforms. In addition, the company offers various subscription-based services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.', 'City': 'Cupertino', 'State': 'CA', 'Country': 'United States', 'Industry': 'Consumer Electronics', 'Sector': 'Technology'}

# %%
aapl_description = aapl_info['Business Summary']
company_description = "I want to find companies that make food and are headquarted in California"

similarity = cosine_similarity_between_sentences(aapl_description, company_description)
# Out:
# Cosine similarity between the two sentences: 0.2793

# %% [markdown]
# # Get all the Stocks in the Stock Market

# %% [markdown]
# First, we need to get the symbols (also known as tickers) of all the stocks in the stock market

# %%
import requests
import json
def get_company_tickers():
    """
    Downloads and parses the Stock ticker symbols from the GitHub-hosted SEC company tickers JSON file.

    Returns:
        dict: A dictionary containing company tickers and related information.

    Notes:
        The data is sourced from the official SEC website via a GitHub repository:
        https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json
    """
    # URL to fetch the raw JSON file from GitHub
    url = "https://raw.githubusercontent.com/team-headstart/Financial-Analysis-and-Automation-with-LLMs/main/company_tickers.json"

    # Making a GET request to the URL
    response = requests.get(url)

    # Checking if the request was successful
    if response.status_code == 200:
        # Parse the JSON content directly
        company_tickers = json.loads(response.content.decode('utf-8'))

        # Optionally save the content to a local file for future use
        with open("company_tickers.json", "w", encoding="utf-8") as file:
            json.dump(company_tickers, file, indent=4)

        print("File downloaded successfully and saved as 'company_tickers.json'")
        return company_tickers
    else:
        print(f"Failed to download file. Status code: {response.status_code}")
        return None

company_tickers = get_company_tickers()
# Out:
# File downloaded successfully and saved as 'company_tickers.json'

# %%
company_tickers
# Out:
# {'0': {'cik_str': 1045810, 'ticker': 'NVDA', 'title': 'NVIDIA CORP'},
#  '1': {'cik_str': 320193, 'ticker': 'AAPL', 'title': 'Apple Inc.'},
#  '2': {'cik_str': 789019, 'ticker': 'MSFT', 'title': 'MICROSOFT CORP'},
#  '3': {'cik_str': 1018724, 'ticker': 'AMZN', 'title': 'AMAZON COM INC'},
#  '4': {'cik_str': 1652044, 'ticker': 'GOOGL', 'title': 'Alphabet Inc.'},
#  '5': {'cik_str': 1326801, 'ticker': 'META', 'title': 'Meta Platforms, Inc.'},
#  '6': {'cik_str': 1318605, 'ticker': 'TSLA', 'title': 'Tesla, Inc.'},
#  '7': {'cik_str': 1067983,
#   'ticker': 'BRK-B',
#   'title': 'BERKSHIRE HATHAWAY INC'},
#  '8': {'cik_str': 1046179,
#   'ticker': 'TSM',
#   'title': 'TAIWAN SEMICONDUCTOR MANUFACTURING CO LTD'},
#  '9': {'cik_str': 1730168, 'ticker': 'AVGO', 'title': 'Broadcom Inc.'},
#  '10': {'cik_str': 59478, 'ticker': 'LLY', 'title': 'ELI LILLY & Co'},
#  '11': {'cik_str': 19617, 'ticker': 'JPM', 'title': 'JPMORGAN CHASE & CO'},
#  '12': {'cik_str': 104169, 'ticker': 'WMT', 'title': 'Walmart Inc.'},
#  '13': {'cik_str': 1403161, 'ticker': 'V', 'title': 'VISA INC.'},
#  '14': {'cik_str': 731766, 'ticker': 'UNH', 'title': 'UNITEDHEALTH GROUP INC'},
#  '15': {'cik_str': 884394, 'ticker': 'SPY', 'title': 'SPDR S&P 500 ETF TRUST'},
#  '16': {'cik_str': 34088, 'ticker': 'XOM', 'title': 'EXXON MOBIL CORP'},
#  '17': {'cik_str': 1341439, 'ticker': 'ORCL', 'title': 'ORACLE CORP'},
#  '18': {'cik_str': 1141391, 'ticker': 'MA', 'title': 'Mastercard Inc'},
#  '19': {'cik_str': 353278, 'ticker': 'NVO', 'title': 'NOVO NORDISK A S'},
#  '20': {'cik_str': 354950, 'ticker': 'HD', 'title': 'HOME DEPOT, INC.'},
#  '21': {'cik_str': 909832,
#   'ticker': 'COST',
#   'title': 'COSTCO WHOLESALE CORP /NEW'},
#  '22': {'cik_str': 80424, 'ticker': 'PG', 'title': 'PROCTER & GAMBLE Co'},
#  '23': {'cik_str': 200406, 'ticker': 'JNJ', 'title': 'JOHNSON & JOHNSON'},
#  '24': {'cik_str': 70858,
#   'ticker': 'BAC',
#   'title': 'BANK OF AMERICA CORP /DE/'},
#  '25': {'cik_str': 1065280, 'ticker': 'NFLX', 'title': 'NETFLIX INC'},
#  '26': {'cik_str': 1108524, 'ticker': 'CRM', 'title': 'Salesforce, Inc.'},
#  '27': {'cik_str': 1551152, 'ticker': 'ABBV', 'title': 'AbbVie Inc.'},
#  '28': {'cik_str': 2008670, 'ticker': 'RCIT', 'title': 'REELCAUSE INC'},
#  '29': {'cik_str': 93410, 'ticker': 'CVX', 'title': 'CHEVRON CORP'},
#  '30': {'cik_str': 1283699, 'ticker': 'TMUS', 'title': 'T-Mobile US, Inc.'},
#  '31': {'cik_str': 1000184, 'ticker': 'SAP', 'title': 'SAP SE'},
#  '32': {'cik_str': 21344, 'ticker': 'KO', 'title': 'COCA COLA CO'},
#  '33': {'cik_str': 937966, 'ticker': 'ASML', 'title': 'ASML HOLDING NV'},
#  '34': {'cik_str': 72971,
#   'ticker': 'WFC',
#   'title': 'WELLS FARGO & COMPANY/MN'},
#  '35': {'cik_str': 310158, 'ticker': 'MRK', 'title': 'Merck & Co., Inc.'},
#  '36': {'cik_str': 858877, 'ticker': 'CSCO', 'title': 'CISCO SYSTEMS, INC.'},
#  '37': {'cik_str': 1094517, 'ticker': 'TM', 'title': 'TOYOTA MOTOR CORP/'},
#  '38': {'cik_str': 796343, 'ticker': 'ADBE', 'title': 'ADOBE INC.'},
#  '39': {'cik_str': 1467373, 'ticker': 'ACN', 'title': 'Accenture plc'},
#  '40': {'cik_str': 1393818, 'ticker': 'BX', 'title': 'Blackstone Inc.'},
#  '41': {'cik_str': 77476, 'ticker': 'PEP', 'title': 'PEPSICO INC'},
#  '42': {'cik_str': 2488,
#   'ticker': 'AMD',
#   'title': 'ADVANCED MICRO DEVICES INC'},
#  '43': {'cik_str': 895421, 'ticker': 'MS', 'title': 'MORGAN STANLEY'},
#  '44': {'cik_str': 1707925, 'ticker': 'LIN', 'title': 'LINDE PLC'},
#  '45': {'cik_str': 1577552,
#   'ticker': 'BABA',
#   'title': 'Alibaba Group Holding Ltd'},
#  '46': {'cik_str': 63908, 'ticker': 'MCD', 'title': 'MCDONALDS CORP'},
#  '47': {'cik_str': 1114448, 'ticker': 'NVS', 'title': 'NOVARTIS AG'},
#  '48': {'cik_str': 1373715, 'ticker': 'NOW', 'title': 'ServiceNow, Inc.'},
#  '49': {'cik_str': 1744489, 'ticker': 'DIS', 'title': 'Walt Disney Co'},
#  '50': {'cik_str': 4962, 'ticker': 'AXP', 'title': 'AMERICAN EXPRESS CO'},
#  '51': {'cik_str': 1413329,
#   'ticker': 'PM',
#   'title': 'Philip Morris International Inc.'},
#  '52': {'cik_str': 1800, 'ticker': 'ABT', 'title': 'ABBOTT LABORATORIES'},
#  '53': {'cik_str': 1306965, 'ticker': 'SHEL', 'title': 'Shell plc'},
#  '54': {'cik_str': 901832, 'ticker': 'AZN', 'title': 'ASTRAZENECA PLC'},
#  '55': {'cik_str': 97745,
#   'ticker': 'TMO',
#   'title': 'THERMO FISHER SCIENTIFIC INC.'},
#  '56': {'cik_str': 1067839,
#   'ticker': 'QQQ',
#   'title': 'INVESCO QQQ TRUST, SERIES 1'},
#  '57': {'cik_str': 896878, 'ticker': 'INTU', 'title': 'INTUIT INC.'},
#  '58': {'cik_str': 40545, 'ticker': 'GE', 'title': 'GENERAL ELECTRIC CO'},
#  '59': {'cik_str': 51143,
#   'ticker': 'IBM',
#   'title': 'INTERNATIONAL BUSINESS MACHINES CORP'},
#  '60': {'cik_str': 1035267,
#   'ticker': 'ISRG',
#   'title': 'INTUITIVE SURGICAL INC'},
#  '61': {'cik_str': 886982, 'ticker': 'GS', 'title': 'GOLDMAN SACHS GROUP INC'},
#  '62': {'cik_str': 18230, 'ticker': 'CAT', 'title': 'CATERPILLAR INC'},
#  '63': {'cik_str': 97476, 'ticker': 'TXN', 'title': 'TEXAS INSTRUMENTS INC'},
#  '64': {'cik_str': 804328, 'ticker': 'QCOM', 'title': 'QUALCOMM INC/DE'},
#  '65': {'cik_str': 732712,
#   'ticker': 'VZ',
#   'title': 'VERIZON COMMUNICATIONS INC'},
#  '66': {'cik_str': 1000275, 'ticker': 'RY', 'title': 'ROYAL BANK OF CANADA'},
#  '67': {'cik_str': 313616, 'ticker': 'DHR', 'title': 'DANAHER CORP /DE/'},
#  '68': {'cik_str': 1089113, 'ticker': 'HSBC', 'title': 'HSBC HOLDINGS PLC'},
#  '69': {'cik_str': 1075531,
#   'ticker': 'BKNG',
#   'title': 'Booking Holdings Inc.'},
#  '70': {'cik_str': 1061736,
#   'ticker': 'FMX',
#   'title': 'MEXICAN ECONOMIC DEVELOPMENT INC'},
#  '71': {'cik_str': 1166691, 'ticker': 'CMCSA', 'title': 'COMCAST CORP'},
#  '72': {'cik_str': 732717, 'ticker': 'T', 'title': 'AT&T INC.'},
#  '73': {'cik_str': 1737806, 'ticker': 'PDD', 'title': 'PDD Holdings Inc.'},
#  '74': {'cik_str': 1144967, 'ticker': 'HDB', 'title': 'HDFC BANK LTD'},
#  '75': {'cik_str': 753308, 'ticker': 'NEE', 'title': 'NEXTERA ENERGY INC'},
#  '76': {'cik_str': 101829, 'ticker': 'RTX', 'title': 'RTX Corp'},
#  '77': {'cik_str': 64040, 'ticker': 'SPGI', 'title': 'S&P Global Inc.'},
#  '78': {'cik_str': 2012383, 'ticker': 'BLK', 'title': 'BlackRock, Inc.'},
#  '79': {'cik_str': 1543151,
#   'ticker': 'UBER',
#   'title': 'Uber Technologies, Inc'},
#  '80': {'cik_str': 60667, 'ticker': 'LOW', 'title': 'LOWES COMPANIES INC'},
#  '81': {'cik_str': 318154, 'ticker': 'AMGN', 'title': 'AMGEN INC'},
#  '82': {'cik_str': 80661, 'ticker': 'PGR', 'title': 'PROGRESSIVE CORP/OH/'},
#  '83': {'cik_str': 773840,
#   'ticker': 'HON',
#   'title': 'HONEYWELL INTERNATIONAL INC'},
#  '84': {'cik_str': 310764, 'ticker': 'SYK', 'title': 'STRYKER CORP'},
#  '85': {'cik_str': 316709, 'ticker': 'SCHW', 'title': 'SCHWAB CHARLES CORP'},
#  '86': {'cik_str': 1321655,
#   'ticker': 'PLTR',
#   'title': 'Palantir Technologies Inc.'},
#  '87': {'cik_str': 100885, 'ticker': 'UNP', 'title': 'UNION PACIFIC CORP'},
#  '88': {'cik_str': 217410, 'ticker': 'UL', 'title': 'UNILEVER PLC'},
#  '89': {'cik_str': 1551182, 'ticker': 'ETN', 'title': 'Eaton Corp plc'},
#  '90': {'cik_str': 78003, 'ticker': 'PFE', 'title': 'PFIZER INC'},
#  '91': {'cik_str': 6951,
#   'ticker': 'AMAT',
#   'title': 'APPLIED MATERIALS INC /DE'},
#  '92': {'cik_str': 1594805, 'ticker': 'SHOP', 'title': 'SHOPIFY INC.'},
#  '93': {'cik_str': 879764, 'ticker': 'TTE', 'title': 'TotalEnergies SE'},
#  '94': {'cik_str': 1404912, 'ticker': 'KKR', 'title': 'KKR & Co. Inc.'},
#  '95': {'cik_str': 67088,
#   'ticker': 'MUFG',
#   'title': 'MITSUBISHI UFJ FINANCIAL GROUP INC'},
#  '96': {'cik_str': 109198, 'ticker': 'TJX', 'title': 'TJX COMPANIES INC /DE/'},
#  '97': {'cik_str': 1973239, 'ticker': 'ARM', 'title': 'ARM HOLDINGS PLC /UK'},
#  '98': {'cik_str': 811809, 'ticker': 'BHP', 'title': 'BHP Group Ltd'},
#  '99': {'cik_str': 831001, 'ticker': 'C', 'title': 'CITIGROUP INC'},
#  '100': {'cik_str': 1163165, 'ticker': 'COP', 'title': 'CONOCOPHILLIPS'},
#  '101': {'cik_str': 885725,
#   'ticker': 'BSX',
#   'title': 'BOSTON SCIENTIFIC CORP'},
#  '102': {'cik_str': 1327567,
#   'ticker': 'PANW',
#   'title': 'Palo Alto Networks Inc'},
#  '103': {'cik_str': 936468, 'ticker': 'LMT', 'title': 'LOCKHEED MARTIN CORP'},
#  '104': {'cik_str': 1121404, 'ticker': 'SNY', 'title': 'Sanofi'},
#  '105': {'cik_str': 8670,
#   'ticker': 'ADP',
#   'title': 'AUTOMATIC DATA PROCESSING INC'},
#  '106': {'cik_str': 887028, 'ticker': 'RTNTF', 'title': 'RIO TINTO LTD'},
#  '107': {'cik_str': 798354, 'ticker': 'FI', 'title': 'FISERV INC'},
#  '108': {'cik_str': 875320,
#   'ticker': 'VRTX',
#   'title': 'VERTEX PHARMACEUTICALS INC / MA'},
#  '109': {'cik_str': 1596532,
#   'ticker': 'ANET',
#   'title': 'Arista Networks, Inc.'},
#  '110': {'cik_str': 896159, 'ticker': 'CB', 'title': 'Chubb Ltd'},
#  '111': {'cik_str': 1378580, 'ticker': 'EADSY', 'title': 'Airbus SE/ADR'},
#  '112': {'cik_str': 320187, 'ticker': 'NKE', 'title': 'NIKE, Inc.'},
#  '113': {'cik_str': 14272,
#   'ticker': 'BMY',
#   'title': 'BRISTOL MYERS SQUIBB CO'},
#  '114': {'cik_str': 1090727,
#   'ticker': 'UPS',
#   'title': 'UNITED PARCEL SERVICE INC'},
#  '115': {'cik_str': 829224, 'ticker': 'SBUX', 'title': 'STARBUCKS CORP'},
#  '116': {'cik_str': 313838, 'ticker': 'SONY', 'title': 'Sony Group Corp'},
#  '117': {'cik_str': 1613103, 'ticker': 'MDT', 'title': 'Medtronic plc'},
#  '118': {'cik_str': 882095,
#   'ticker': 'GILD',
#   'title': 'GILEAD SCIENCES, INC.'},
#  '119': {'cik_str': 1668717,
#   'ticker': 'BUD',
#   'title': 'Anheuser-Busch InBev SA/NV'},
#  '120': {'cik_str': 315189, 'ticker': 'DE', 'title': 'DEERE & CO'},
#  '121': {'cik_str': 62709,
#   'ticker': 'MMC',
#   'title': 'MARSH & MCLENNAN COMPANIES, INC.'},
#  '122': {'cik_str': 723125, 'ticker': 'MU', 'title': 'MICRON TECHNOLOGY INC'},
#  '123': {'cik_str': 50863, 'ticker': 'INTC', 'title': 'INTEL CORP'},
#  '124': {'cik_str': 1045609, 'ticker': 'PLD', 'title': 'Prologis, Inc.'},
#  '125': {'cik_str': 12927, 'ticker': 'BA', 'title': 'BOEING CO'},
#  '126': {'cik_str': 1103838, 'ticker': 'IBN', 'title': 'ICICI BANK LTD'},
#  '127': {'cik_str': 6281, 'ticker': 'ADI', 'title': 'ANALOG DEVICES INC'},
#  '128': {'cik_str': 1610520, 'ticker': 'UBS', 'title': 'UBS Group AG'},
#  '129': {'cik_str': 863064, 'ticker': 'RIO', 'title': 'RIO TINTO PLC'},
#  '130': {'cik_str': 947263, 'ticker': 'TD', 'title': 'TORONTO DOMINION BANK'},
#  '131': {'cik_str': 1161167,
#   'ticker': 'AIQUY',
#   'title': 'L AIR LIQUIDE SA /FI'},
#  '132': {'cik_str': 92122, 'ticker': 'SO', 'title': 'SOUTHERN CO'},
#  '133': {'cik_str': 89800, 'ticker': 'SHW', 'title': 'SHERWIN WILLIAMS CO'},
#  '134': {'cik_str': 1751008, 'ticker': 'APP', 'title': 'AppLovin Corp'},
#  '135': {'cik_str': 764180, 'ticker': 'MO', 'title': 'ALTRIA GROUP, INC.'},
#  '136': {'cik_str': 1099590, 'ticker': 'MELI', 'title': 'MERCADOLIBRE INC'},
#  '137': {'cik_str': 1156039,
#   'ticker': 'ELV',
#   'title': 'Elevance Health, Inc.'},
#  '138': {'cik_str': 1639920,
#   'ticker': 'SPOT',
#   'title': 'Spotify Technology S.A.'},
#  '139': {'cik_str': 895728, 'ticker': 'ENB', 'title': 'ENBRIDGE INC'},
#  '140': {'cik_str': 1571996,
#   'ticker': 'DELL',
#   'title': 'Dell Technologies Inc.'},
#  '141': {'cik_str': 1996810, 'ticker': 'GEV', 'title': 'GE Vernova Inc.'},
#  '142': {'cik_str': 1858681,
#   'ticker': 'APO',
#   'title': 'Apollo Global Management, Inc.'},
#  '143': {'cik_str': 1466258,
#   'ticker': 'TT',
#   'title': 'Trane Technologies plc'},
#  '144': {'cik_str': 1053507,
#   'ticker': 'AMT',
#   'title': 'AMERICAN TOWER CORP /MA/'},
#  '145': {'cik_str': 1022837,
#   'ticker': 'SMFG',
#   'title': 'SUMITOMO MITSUI FINANCIAL GROUP, INC.'},
#  '146': {'cik_str': 707549, 'ticker': 'LRCX', 'title': 'LAM RESEARCH CORP'},
#  '147': {'cik_str': 1067491, 'ticker': 'INFY', 'title': 'Infosys Ltd'},
#  '148': {'cik_str': 76334, 'ticker': 'PH', 'title': 'PARKER HANNIFIN CORP'},
#  '149': {'cik_str': 1571949,
#   'ticker': 'ICE',
#   'title': 'Intercontinental Exchange, Inc.'},
#  '150': {'cik_str': 1739940, 'ticker': 'CI', 'title': 'Cigna Group'},
#  '151': {'cik_str': 823768, 'ticker': 'WM', 'title': 'WASTE MANAGEMENT INC'},
#  '152': {'cik_str': 1119639,
#   'ticker': 'PBR',
#   'title': 'PETROBRAS - PETROLEO BRASILEIRO SA'},
#  '153': {'cik_str': 1101239, 'ticker': 'EQIX', 'title': 'EQUINIX INC'},
#  '154': {'cik_str': 723254, 'ticker': 'CTAS', 'title': 'CINTAS CORP'},
#  '155': {'cik_str': 860730, 'ticker': 'HCA', 'title': 'HCA Healthcare, Inc.'},
#  '156': {'cik_str': 1326160, 'ticker': 'DUK', 'title': 'Duke Energy CORP'},
#  '157': {'cik_str': 1103982,
#   'ticker': 'MDLZ',
#   'title': 'Mondelez International, Inc.'},
#  '158': {'cik_str': 1001085, 'ticker': 'BN', 'title': 'BROOKFIELD Corp /ON/'},
#  '159': {'cik_str': 1633917,
#   'ticker': 'PYPL',
#   'title': 'PayPal Holdings, Inc.'},
#  '160': {'cik_str': 1059556, 'ticker': 'MCO', 'title': 'MOODYS CORP /DE/'},
#  '161': {'cik_str': 820313, 'ticker': 'APH', 'title': 'AMPHENOL CORP /DE/'},
#  '162': {'cik_str': 766704, 'ticker': 'WELL', 'title': 'WELLTOWER INC.'},
#  '163': {'cik_str': 872589,
#   'ticker': 'REGN',
#   'title': 'REGENERON PHARMACEUTICALS, INC.'},
#  '164': {'cik_str': 1559720, 'ticker': 'ABNB', 'title': 'Airbnb, Inc.'},
#  '165': {'cik_str': 319201, 'ticker': 'KLAC', 'title': 'KLA CORP'},
#  '166': {'cik_str': 929869, 'ticker': 'RELX', 'title': 'RELX PLC'},
#  '167': {'cik_str': 713676,
#   'ticker': 'PNC',
#   'title': 'PNC FINANCIAL SERVICES GROUP, INC.'},
#  '168': {'cik_str': 1535527,
#   'ticker': 'CRWD',
#   'title': 'CrowdStrike Holdings, Inc.'},
#  '169': {'cik_str': 68505,
#   'ticker': 'MSI',
#   'title': 'Motorola Solutions, Inc.'},
#  '170': {'cik_str': 315293, 'ticker': 'AON', 'title': 'Aon plc'},
#  '171': {'cik_str': 1156375, 'ticker': 'CME', 'title': 'CME GROUP INC.'},
#  '172': {'cik_str': 883241, 'ticker': 'SNPS', 'title': 'SYNOPSYS INC'},
#  '173': {'cik_str': 1058090,
#   'ticker': 'CMG',
#   'title': 'CHIPOTLE MEXICAN GRILL INC'},
#  '174': {'cik_str': 948401,
#   'ticker': 'CFRUY',
#   'title': 'COMPAGNIE FINANCIERE RICHEMONT AG /FI'},
#  '175': {'cik_str': 49826,
#   'ticker': 'ITW',
#   'title': 'ILLINOIS TOOL WORKS INC'},
#  '176': {'cik_str': 1303523,
#   'ticker': 'BTI',
#   'title': 'British American Tobacco p.l.c.'},
#  '177': {'cik_str': 813672,
#   'ticker': 'CDNS',
#   'title': 'CADENCE DESIGN SYSTEMS INC'},
#  '178': {'cik_str': 40533, 'ticker': 'GD', 'title': 'GENERAL DYNAMICS CORP'},
#  '179': {'cik_str': 1555280, 'ticker': 'ZTS', 'title': 'Zoetis Inc.'},
#  '180': {'cik_str': 1001838,
#   'ticker': 'SCCO',
#   'title': 'SOUTHERN COPPER CORP/'},
#  '181': {'cik_str': 36104, 'ticker': 'USB', 'title': 'US BANCORP \\DE\\'},
#  '182': {'cik_str': 1648416, 'ticker': 'RACE', 'title': 'Ferrari N.V.'},
#  '183': {'cik_str': 1048286,
#   'ticker': 'MAR',
#   'title': 'MARRIOTT INTERNATIONAL INC /MD/'},
#  '184': {'cik_str': 927653, 'ticker': 'MCK', 'title': 'MCKESSON CORP'},
#  '185': {'cik_str': 21665, 'ticker': 'CL', 'title': 'COLGATE PALMOLIVE CO'},
#  '186': {'cik_str': 1835632,
#   'ticker': 'MRVL',
#   'title': 'Marvell Technology, Inc.'},
#  '187': {'cik_str': 313807, 'ticker': 'BP', 'title': 'BP PLC'},
#  '188': {'cik_str': 1381197,
#   'ticker': 'IBKR',
#   'title': 'Interactive Brokers Group, Inc.'},
#  '189': {'cik_str': 821189, 'ticker': 'EOG', 'title': 'EOG RESOURCES INC'},
#  '190': {'cik_str': 1679788,
#   'ticker': 'COIN',
#   'title': 'Coinbase Global, Inc.'},
#  '191': {'cik_str': 891478, 'ticker': 'SAN', 'title': 'Banco Santander, S.A.'},
#  '192': {'cik_str': 1075124,
#   'ticker': 'TRI',
#   'title': 'THOMSON REUTERS CORP /CAN/'},
#  '193': {'cik_str': 32604, 'ticker': 'EMR', 'title': 'EMERSON ELECTRIC CO'},
#  '194': {'cik_str': 1262039, 'ticker': 'FTNT', 'title': 'Fortinet, Inc.'},
#  '195': {'cik_str': 1133421,
#   'ticker': 'NOC',
#   'title': 'NORTHROP GRUMMAN CORP /DE/'},
#  '196': {'cik_str': 1048911, 'ticker': 'FDX', 'title': 'FEDEX CORP'},
#  '197': {'cik_str': 1442651,
#   'ticker': 'SHECY',
#   'title': 'Shin-Etsu Chemical Co., Ltd.'},
#  '198': {'cik_str': 66740, 'ticker': 'MMM', 'title': '3M CO'},
#  '199': {'cik_str': 1050446, 'ticker': 'MSTR', 'title': 'MICROSTRATEGY Inc'},
#  '200': {'cik_str': 1792789, 'ticker': 'DASH', 'title': 'DoorDash, Inc.'},
#  '201': {'cik_str': 1017413,
#   'ticker': 'CNQ',
#   'title': 'CANADIAN NATURAL RESOURCES LTD'},
#  '202': {'cik_str': 27419, 'ticker': 'TGT', 'title': 'TARGET CORP'},
#  '203': {'cik_str': 2969,
#   'ticker': 'APD',
#   'title': 'Air Products & Chemicals, Inc.'},
#  '204': {'cik_str': 927628,
#   'ticker': 'COF',
#   'title': 'CAPITAL ONE FINANCIAL CORP'},
#  '205': {'cik_str': 1260221, 'ticker': 'TDG', 'title': 'TransDigm Group INC'},
#  '206': {'cik_str': 898173,
#   'ticker': 'ORLY',
#   'title': 'O REILLY AUTOMOTIVE INC'},
#  '207': {'cik_str': 1868275,
#   'ticker': 'CEG',
#   'title': 'Constellation Energy Corp'},
#  '208': {'cik_str': 16875,
#   'ticker': 'CP',
#   'title': 'CANADIAN PACIFIC KANSAS CITY LTD/CN'},
#  '209': {'cik_str': 31462, 'ticker': 'ECL', 'title': 'ECOLAB INC.'},
#  '210': {'cik_str': 16868,
#   'ticker': 'CNI',
#   'title': 'CANADIAN NATIONAL RAILWAY CO'},
#  '211': {'cik_str': 1131399, 'ticker': 'GSK', 'title': 'GSK plc'},
#  '212': {'cik_str': 1327811, 'ticker': 'WDAY', 'title': 'Workday, Inc.'},
#  '213': {'cik_str': 927971,
#   'ticker': 'BMO',
#   'title': 'BANK OF MONTREAL /CAN/'},
#  '214': {'cik_str': 107263,
#   'ticker': 'WMB',
#   'title': 'WILLIAMS COMPANIES, INC.'},
#  '215': {'cik_str': 277948, 'ticker': 'CSX', 'title': 'CSX CORP'},
#  '216': {'cik_str': 1063761,
#   'ticker': 'SPG',
#   'title': 'SIMON PROPERTY GROUP INC /DE/'},
#  '217': {'cik_str': 1061219,
#   'ticker': 'EPD',
#   'title': 'ENTERPRISE PRODUCTS PARTNERS L.P.'},
#  '218': {'cik_str': 1691493, 'ticker': 'NU', 'title': 'Nu Holdings Ltd.'},
#  '219': {'cik_str': 9631, 'ticker': 'BNS', 'title': 'BANK OF NOVA SCOTIA'},
#  '220': {'cik_str': 849395, 'ticker': 'CRH', 'title': 'CRH PUBLIC LTD CO'},
#  '221': {'cik_str': 64803, 'ticker': 'CVS', 'title': 'CVS HEALTH Corp'},
#  '222': {'cik_str': 1783180, 'ticker': 'CARR', 'title': 'CARRIER GLOBAL Corp'},
#  '223': {'cik_str': 835403, 'ticker': 'DEO', 'title': 'DIAGEO PLC'},
#  '224': {'cik_str': 1140625, 'ticker': 'EQNR', 'title': 'EQUINOR ASA'},
#  '225': {'cik_str': 10795, 'ticker': 'BDX', 'title': 'BECTON DICKINSON & CO'},
#  '226': {'cik_str': 1060391,
#   'ticker': 'RSG',
#   'title': 'REPUBLIC SERVICES, INC.'},
#  '227': {'cik_str': 354190,
#   'ticker': 'AJG',
#   'title': 'Arthur J. Gallagher & Co.'},
#  '228': {'cik_str': 769397, 'ticker': 'ADSK', 'title': 'Autodesk, Inc.'},
#  '229': {'cik_str': 1039684, 'ticker': 'OKE', 'title': 'ONEOK INC /NEW/'},
#  '230': {'cik_str': 1443276, 'ticker': 'TOELY', 'title': 'Tokyo Electron LTD'},
#  '231': {'cik_str': 1947559,
#   'ticker': 'ANZGY',
#   'title': 'ANZ GROUP HOLDINGS LIMITED/ADR'},
#  '232': {'cik_str': 1467858, 'ticker': 'GM', 'title': 'General Motors Co'},
#  '233': {'cik_str': 1650372, 'ticker': 'TEAM', 'title': 'Atlassian Corp'},
#  '234': {'cik_str': 884887,
#   'ticker': 'RCL',
#   'title': 'ROYAL CARIBBEAN CRUISES LTD'},
#  '235': {'cik_str': 4977, 'ticker': 'AFL', 'title': 'AFLAC INC'},
#  '236': {'cik_str': 1222333, 'ticker': 'GLD', 'title': 'SPDR GOLD TRUST'},
#  '237': {'cik_str': 92230, 'ticker': 'TFC', 'title': 'TRUIST FINANCIAL CORP'},
#  '238': {'cik_str': 1335730,
#   'ticker': 'MFG',
#   'title': 'MIZUHO FINANCIAL GROUP INC'},
#  '239': {'cik_str': 831259, 'ticker': 'FCX', 'title': 'FREEPORT-MCMORAN INC'},
#  '240': {'cik_str': 1004315, 'ticker': 'NGG', 'title': 'NATIONAL GRID PLC'},
#  '241': {'cik_str': 87347,
#   'ticker': 'SLB',
#   'title': 'SCHLUMBERGER LIMITED/NV'},
#  '242': {'cik_str': 1297996,
#   'ticker': 'DLR',
#   'title': 'DIGITAL REALTY TRUST, INC.'},
#  '243': {'cik_str': 1585689,
#   'ticker': 'HLT',
#   'title': 'Hilton Worldwide Holdings Inc.'},
#  '244': {'cik_str': 1506307, 'ticker': 'KMI', 'title': 'KINDER MORGAN, INC.'},
#  '245': {'cik_str': 1045520,
#   'ticker': 'CM',
#   'title': 'CANADIAN IMPERIAL BANK OF COMMERCE /CAN/'},
#  '246': {'cik_str': 1067318, 'ticker': 'MBGYY', 'title': 'DAIMLER AG'},
#  '247': {'cik_str': 702165, 'ticker': 'NSC', 'title': 'NORFOLK SOUTHERN CORP'},
#  '248': {'cik_str': 1276187, 'ticker': 'ET', 'title': 'Energy Transfer LP'},
#  '249': {'cik_str': 86312,
#   'ticker': 'TRV',
#   'title': 'TRAVELERS COMPANIES, INC.'},
#  '250': {'cik_str': 882835,
#   'ticker': 'ROP',
#   'title': 'ROPER TECHNOLOGIES INC'},
#  '251': {'cik_str': 75362, 'ticker': 'PCAR', 'title': 'PACCAR INC'},
#  '252': {'cik_str': 1393311, 'ticker': 'PSA', 'title': 'Public Storage'},
#  '253': {'cik_str': 1671933, 'ticker': 'TTD', 'title': 'Trade Desk, Inc.'},
#  '254': {'cik_str': 1524684, 'ticker': 'GLNCY', 'title': 'Glencore plc/ADR'},
#  '255': {'cik_str': 1549802, 'ticker': 'JD', 'title': 'JD.com, Inc.'},
#  '256': {'cik_str': 1703399, 'ticker': 'SE', 'title': 'Sea Ltd'},
#  '257': {'cik_str': 1032208, 'ticker': 'SRE', 'title': 'SEMPRA'},
#  '258': {'cik_str': 1099219, 'ticker': 'MET', 'title': 'METLIFE INC'},
#  '259': {'cik_str': 1086888,
#   'ticker': 'MFC',
#   'title': 'MANULIFE FINANCIAL CORP'},
#  '260': {'cik_str': 277135, 'ticker': 'GWW', 'title': 'W.W. GRAINGER, INC.'},
#  '261': {'cik_str': 1390777,
#   'ticker': 'BK',
#   'title': 'Bank of New York Mellon Corp'},
#  '262': {'cik_str': 842180,
#   'ticker': 'BBVA',
#   'title': 'BANCO BILBAO VIZCAYA ARGENTARIA, S.A.'},
#  '263': {'cik_str': 833444,
#   'ticker': 'JCI',
#   'title': 'Johnson Controls International plc'},
#  '264': {'cik_str': 1413447,
#   'ticker': 'NXPI',
#   'title': 'NXP Semiconductors N.V.'},
#  '265': {'cik_str': 1132597,
#   'ticker': 'ITUB',
#   'title': 'Itau Unibanco Holding S.A.'},
#  '266': {'cik_str': 1091667,
#   'ticker': 'CHTR',
#   'title': 'CHARTER COMMUNICATIONS, INC. /MO/'},
#  '267': {'cik_str': 814547, 'ticker': 'FICO', 'title': 'FAIR ISAAC CORP'},
#  '268': {'cik_str': 1067701, 'ticker': 'URI', 'title': 'UNITED RENTALS, INC.'},
#  '269': {'cik_str': 1110646, 'ticker': 'NTES', 'title': 'NetEase, Inc.'},
#  '270': {'cik_str': 820027,
#   'ticker': 'AMP',
#   'title': 'AMERIPRISE FINANCIAL INC'},
#  '271': {'cik_str': 1004980, 'ticker': 'PCG', 'title': 'PG&E Corp'},
#  '272': {'cik_str': 900075, 'ticker': 'CPRT', 'title': 'COPART INC'},
#  '273': {'cik_str': 1547873,
#   'ticker': 'PTCAY',
#   'title': 'PT Chandra Asri Petrochemical Tbk/ADR'},
#  '274': {'cik_str': 1534701, 'ticker': 'PSX', 'title': 'Phillips 66'},
#  '275': {'cik_str': 866787, 'ticker': 'AZO', 'title': 'AUTOZONE INC'},
#  '276': {'cik_str': 882184, 'ticker': 'DHI', 'title': 'HORTON D R INC /DE/'},
#  '277': {'cik_str': 1176948,
#   'ticker': 'ARES',
#   'title': 'Ares Management Corp'},
#  '278': {'cik_str': 899051, 'ticker': 'ALL', 'title': 'ALLSTATE CORP'},
#  '279': {'cik_str': 1539838,
#   'ticker': 'FANG',
#   'title': 'Diamondback Energy, Inc.'},
#  '280': {'cik_str': 723531, 'ticker': 'PAYX', 'title': 'PAYCHEX INC'},
#  '281': {'cik_str': 865752,
#   'ticker': 'MNST',
#   'title': 'Monster Beverage Corp'},
#  '282': {'cik_str': 30554, 'ticker': 'CTA-PA', 'title': 'EIDP, Inc.'},
#  '283': {'cik_str': 1512673, 'ticker': 'SQ', 'title': 'Block, Inc.'},
#  '284': {'cik_str': 4904,
#   'ticker': 'AEP',
#   'title': 'AMERICAN ELECTRIC POWER CO INC'},
#  '285': {'cik_str': 311337, 'ticker': 'SU', 'title': 'SUNCOR ENERGY INC'},
#  '286': {'cik_str': 1232384, 'ticker': 'TRP', 'title': 'TC ENERGY CORP'},
#  '287': {'cik_str': 1510295,
#   'ticker': 'MPC',
#   'title': 'Marathon Petroleum Corp'},
#  '288': {'cik_str': 895564,
#   'ticker': 'BAESY',
#   'title': 'BAE SYSTEMS PLC /FI/'},
#  '289': {'cik_str': 26172, 'ticker': 'CMI', 'title': 'CUMMINS INC'},
#  '290': {'cik_str': 1039765, 'ticker': 'ING', 'title': 'ING GROEP NV'},
#  '291': {'cik_str': 1588489,
#   'ticker': 'GBTC',
#   'title': 'Grayscale Bitcoin Trust ETF'},
#  '292': {'cik_str': 726728, 'ticker': 'O', 'title': 'REALTY INCOME CORP'},
#  '293': {'cik_str': 312069, 'ticker': 'BCS', 'title': 'BARCLAYS PLC'},
#  '294': {'cik_str': 715957, 'ticker': 'D', 'title': 'DOMINION ENERGY, INC'},
#  '295': {'cik_str': 1552000, 'ticker': 'MPLX', 'title': 'MPLX LP'},
#  '296': {'cik_str': 1692819, 'ticker': 'VST', 'title': 'Vistra Corp.'},
#  '297': {'cik_str': 1050915,
#   'ticker': 'PWR',
#   'title': 'QUANTA SERVICES, INC.'},
#  '298': {'cik_str': 1012037,
#   'ticker': 'CODYY',
#   'title': 'COMPAGNIE DE SAINT GOBAIN'},
#  '299': {'cik_str': 1318220,
#   'ticker': 'WCN',
#   'title': 'Waste Connections, Inc.'},
#  '300': {'cik_str': 1136893,
#   'ticker': 'FIS',
#   'title': 'Fidelity National Information Services, Inc.'},
#  '301': {'cik_str': 5272,
#   'ticker': 'AIG',
#   'title': 'AMERICAN INTERNATIONAL GROUP, INC.'},
#  '302': {'cik_str': 3570, 'ticker': 'LNG', 'title': 'Cheniere Energy, Inc.'},
#  '303': {'cik_str': 1635327,
#   'ticker': 'FLUT',
#   'title': 'Flutter Entertainment plc'},
#  '304': {'cik_str': 1278680, 'ticker': 'IAU', 'title': 'ISHARES GOLD TRUST'},
#  '305': {'cik_str': 1140859, 'ticker': 'COR', 'title': 'Cencora, Inc.'},
#  '306': {'cik_str': 815556, 'ticker': 'FAST', 'title': 'FASTENAL CO'},
#  '307': {'cik_str': 797468,
#   'ticker': 'OXY',
#   'title': 'OCCIDENTAL PETROLEUM CORP /DE/'},
#  '308': {'cik_str': 1129137,
#   'ticker': 'AMX',
#   'title': 'AMERICA MOVIL SAB DE CV/'},
#  '309': {'cik_str': 1408198, 'ticker': 'MSCI', 'title': 'MSCI Inc.'},
#  '310': {'cik_str': 202058,
#   'ticker': 'LHX',
#   'title': 'L3HARRIS TECHNOLOGIES, INC. /DE/'},
#  '311': {'cik_str': 745732, 'ticker': 'ROST', 'title': 'ROSS STORES, INC.'},
#  '312': {'cik_str': 1002242, 'ticker': 'E', 'title': 'ENI SPA'},
#  '313': {'cik_str': 1164727, 'ticker': 'NEM', 'title': 'NEWMONT Corp /DE/'},
#  '314': {'cik_str': 878927,
#   'ticker': 'ODFL',
#   'title': 'OLD DOMINION FREIGHT LINE, INC.'},
#  '315': {'cik_str': 1944048, 'ticker': 'KVUE', 'title': 'Kenvue Inc.'},
#  '316': {'cik_str': 1069183,
#   'ticker': 'AXON',
#   'title': 'AXON ENTERPRISE, INC.'},
#  '317': {'cik_str': 4281, 'ticker': 'HWM', 'title': 'Howmet Aerospace Inc.'},
#  '318': {'cik_str': 920760, 'ticker': 'LEN', 'title': 'LENNAR CORP /NEW/'},
#  '319': {'cik_str': 1137774,
#   'ticker': 'PRU',
#   'title': 'PRUDENTIAL FINANCIAL INC'},
#  '320': {'cik_str': 1120193, 'ticker': 'NDAQ', 'title': 'NASDAQ, INC.'},
#  '321': {'cik_str': 55785, 'ticker': 'KMB', 'title': 'KIMBERLY CLARK CORP'},
#  '322': {'cik_str': 1051470, 'ticker': 'CCI', 'title': 'CROWN CASTLE INC.'},
#  '323': {'cik_str': 1674101, 'ticker': 'VRT', 'title': 'Vertiv Holdings Co'},
#  '324': {'cik_str': 4447, 'ticker': 'HES', 'title': 'HESS CORP'},
#  '325': {'cik_str': 1037868, 'ticker': 'AME', 'title': 'AMETEK INC/'},
#  '326': {'cik_str': 1385157, 'ticker': 'TEL', 'title': 'TE Connectivity plc'},
#  '327': {'cik_str': 37996, 'ticker': 'F', 'title': 'FORD MOTOR CO'},
#  '328': {'cik_str': 1035002,
#   'ticker': 'VLO',
#   'title': 'VALERO ENERGY CORP/TX'},
#  '329': {'cik_str': 1393612,
#   'ticker': 'DFS',
#   'title': 'Discover Financial Services'},
#  '330': {'cik_str': 788784,
#   'ticker': 'PEG',
#   'title': 'PUBLIC SERVICE ENTERPRISE GROUP INC'},
#  '331': {'cik_str': 1834584, 'ticker': 'CPNG', 'title': 'Coupang, Inc.'},
#  '332': {'cik_str': 1446250,
#   'ticker': 'BMWKY',
#   'title': 'Bayerische Motoren Werke AG/ADR'},
#  '333': {'cik_str': 16918,
#   'ticker': 'STZ',
#   'title': 'CONSTELLATION BRANDS, INC.'},
#  '334': {'cik_str': 1395064,
#   'ticker': 'TAK',
#   'title': 'TAKEDA PHARMACEUTICAL CO LTD'},
#  '335': {'cik_str': 1160106,
#   'ticker': 'LYG',
#   'title': 'Lloyds Banking Group plc'},
#  '336': {'cik_str': 1418135,
#   'ticker': 'KDP',
#   'title': 'Keurig Dr Pepper Inc.'},
#  '337': {'cik_str': 1279967,
#   'ticker': 'CRARY',
#   'title': 'CREDIT AGRICOLE S A'},
#  '338': {'cik_str': 1561550, 'ticker': 'DDOG', 'title': 'Datadog, Inc.'},
#  '339': {'cik_str': 1446598, 'ticker': 'DNZOY', 'title': 'Denso Corp'},
#  '340': {'cik_str': 1167379, 'ticker': 'ALC', 'title': 'ALCON INC'},
#  '341': {'cik_str': 1535628, 'ticker': 'CAIXY', 'title': 'CaixaBank/ADR'},
#  '342': {'cik_str': 712515, 'ticker': 'EA', 'title': 'ELECTRONIC ARTS INC.'},
#  '343': {'cik_str': 1900304, 'ticker': 'HLN', 'title': 'Haleon plc'},
#  '344': {'cik_str': 1389170,
#   'ticker': 'TRGP',
#   'title': 'Targa Resources Corp.'},
#  '345': {'cik_str': 917851, 'ticker': 'VALE', 'title': 'Vale S.A.'},
#  '346': {'cik_str': 1158838, 'ticker': 'ATEYY', 'title': 'ADVANTEST CORP'},
#  '347': {'cik_str': 1701605, 'ticker': 'BKR', 'title': 'Baker Hughes Co'},
#  '348': {'cik_str': 56873, 'ticker': 'KR', 'title': 'KROGER CO'},
#  '349': {'cik_str': 1640147, 'ticker': 'SNOW', 'title': 'Snowflake Inc.'},
#  '350': {'cik_str': 844150, 'ticker': 'NWG', 'title': 'NatWest Group plc'},
#  '351': {'cik_str': 27904, 'ticker': 'DAL', 'title': 'DELTA AIR LINES, INC.'},
#  '352': {'cik_str': 1699150, 'ticker': 'IR', 'title': 'Ingersoll Rand Inc.'},
#  '353': {'cik_str': 1359519,
#   'ticker': 'SVNDY',
#   'title': 'SEVEN & I HOLDINGS CO LTD'},
#  '354': {'cik_str': 749251, 'ticker': 'IT', 'title': 'GARTNER INC'},
#  '355': {'cik_str': 1121788, 'ticker': 'GRMN', 'title': 'GARMIN LTD'},
#  '356': {'cik_str': 715153, 'ticker': 'HMC', 'title': 'HONDA MOTOR CO LTD'},
#  '357': {'cik_str': 2011641,
#   'ticker': 'FERG',
#   'title': 'Ferguson Enterprises Inc. /DE/'},
#  '358': {'cik_str': 1138118, 'ticker': 'CBRE', 'title': 'CBRE GROUP, INC.'},
#  '359': {'cik_str': 24741, 'ticker': 'GLW', 'title': 'CORNING INC /NY'},
#  '360': {'cik_str': 72903, 'ticker': 'XEL', 'title': 'XCEL ENERGY INC'},
#  '361': {'cik_str': 1442145,
#   'ticker': 'VRSK',
#   'title': 'Verisk Analytics, Inc.'},
#  '362': {'cik_str': 1099800,
#   'ticker': 'EW',
#   'title': 'Edwards Lifesciences Corp'},
#  '363': {'cik_str': 1397187,
#   'ticker': 'LULU',
#   'title': 'lululemon athletica inc.'},
#  '364': {'cik_str': 1781335, 'ticker': 'OTIS', 'title': 'Otis Worldwide Corp'},
#  '365': {'cik_str': 1269238, 'ticker': 'TCOM', 'title': 'Trip.com Group Ltd'},
#  '366': {'cik_str': 1109357, 'ticker': 'EXC', 'title': 'EXELON CORP'},
#  '367': {'cik_str': 49938, 'ticker': 'IMO', 'title': 'IMPERIAL OIL LTD'},
#  '368': {'cik_str': 1545460,
#   'ticker': 'OLCLY',
#   'title': 'Oriental Land Co., Ltd./ADR'},
#  '369': {'cik_str': 2809, 'ticker': 'AEM', 'title': 'AGNICO EAGLE MINES LTD'},
#  '370': {'cik_str': 1058290,
#   'ticker': 'CTSH',
#   'title': 'COGNIZANT TECHNOLOGY SOLUTIONS CORP'},
#  '371': {'cik_str': 1605484, 'ticker': 'STLA', 'title': 'Stellantis N.V.'},
#  '372': {'cik_str': 1755672, 'ticker': 'CTVA', 'title': 'Corteva, Inc.'},
#  '373': {'cik_str': 947484,
#   'ticker': 'ACGL',
#   'title': 'ARCH CAPITAL GROUP LTD.'},
#  '374': {'cik_str': 1637459, 'ticker': 'KHC', 'title': 'Kraft Heinz Co'},
#  '375': {'cik_str': 861967,
#   'ticker': 'WTKWY',
#   'title': 'WOLTERS KLUWER N V /FI'},
#  '376': {'cik_str': 1041061, 'ticker': 'YUM', 'title': 'YUM BRANDS INC'},
#  '377': {'cik_str': 1461748,
#   'ticker': 'PPERY',
#   'title': 'PT Bank Mandiri (Persero) Tbk / ADR'},
#  '378': {'cik_str': 1932393,
#   'ticker': 'GEHC',
#   'title': 'GE HealthCare Technologies Inc.'},
#  '379': {'cik_str': 96021, 'ticker': 'SYY', 'title': 'SYSCO CORP'},
#  '380': {'cik_str': 1396009, 'ticker': 'VMC', 'title': 'Vulcan Materials CO'},
#  '381': {'cik_str': 1090872,
#   'ticker': 'A',
#   'title': 'AGILENT TECHNOLOGIES, INC.'},
#  '382': {'cik_str': 1289490,
#   'ticker': 'EXR',
#   'title': 'Extra Space Storage Inc.'},
#  '383': {'cik_str': 36270, 'ticker': 'MTB', 'title': 'M&T BANK CORP'},
#  '384': {'cik_str': 916076,
#   'ticker': 'MLM',
#   'title': 'MARTIN MARIETTA MATERIALS INC'},
#  '385': {'cik_str': 47217, 'ticker': 'HPQ', 'title': 'HP INC'},
#  '386': {'cik_str': 1041130,
#   'ticker': 'DIA',
#   'title': 'SPDR DOW JONES INDUSTRIAL AVERAGE ETF TRUST'},
#  '387': {'cik_str': 1123799, 'ticker': 'WIT', 'title': 'WIPRO LTD'},
#  '388': {'cik_str': 1650107,
#   'ticker': 'CCEP',
#   'title': 'COCA-COLA EUROPACIFIC PARTNERS plc'},
#  '389': {'cik_str': 1478242, 'ticker': 'IQV', 'title': 'IQVIA HOLDINGS INC.'},
#  '390': {'cik_str': 40704, 'ticker': 'GIS', 'title': 'GENERAL MILLS INC'},
#  '391': {'cik_str': 47111, 'ticker': 'HSY', 'title': 'HERSHEY CO'},
#  '392': {'cik_str': 1300514, 'ticker': 'LVS', 'title': 'LAS VEGAS SANDS CORP'},
#  '393': {'cik_str': 1446519,
#   'ticker': 'DKILY',
#   'title': 'Daikin Industries Ltd'},
#  '394': {'cik_str': 1404655, 'ticker': 'HUBS', 'title': 'HUBSPOT INC'},
#  '395': {'cik_str': 1393052, 'ticker': 'VEEV', 'title': 'VEEVA SYSTEMS INC'},
#  '396': {'cik_str': 1565025, 'ticker': 'ABEV', 'title': 'AMBEV S.A.'},
#  '397': {'cik_str': 1097362,
#   'ticker': 'SLF',
#   'title': 'SUN LIFE FINANCIAL INC'},
#  '398': {'cik_str': 73309, 'ticker': 'NUE', 'title': 'NUCOR CORP'},
#  '399': {'cik_str': 874716,
#   'ticker': 'IDXX',
#   'title': 'IDEXX LABORATORIES INC /DE'},
#  '400': {'cik_str': 943819, 'ticker': 'RMD', 'title': 'RESMED INC'},
#  '401': {'cik_str': 1697862, 'ticker': 'ARGX', 'title': 'ARGENX SE'},
#  '402': {'cik_str': 1666700,
#   'ticker': 'DD',
#   'title': 'DuPont de Nemours, Inc.'},
#  '403': {'cik_str': 874766,
#   'ticker': 'HIG',
#   'title': 'HARTFORD FINANCIAL SERVICES GROUP, INC.'},
#  '404': {'cik_str': 827054,
#   'ticker': 'MCHP',
#   'title': 'MICROCHIP TECHNOLOGY INC'},
#  '405': {'cik_str': 1315098, 'ticker': 'RBLX', 'title': 'Roblox Corp'},
#  '406': {'cik_str': 1020569, 'ticker': 'IRM', 'title': 'IRON MOUNTAIN INC'},
#  '407': {'cik_str': 943452,
#   'ticker': 'WAB',
#   'title': 'WESTINGHOUSE AIR BRAKE TECHNOLOGIES CORP'},
#  '408': {'cik_str': 1823945,
#   'ticker': 'OWL',
#   'title': 'BLUE OWL CAPITAL INC.'},
#  '409': {'cik_str': 1471055,
#   'ticker': 'BSBR',
#   'title': 'Banco Santander (Brasil) S.A.'},
#  '410': {'cik_str': 1047862,
#   'ticker': 'ED',
#   'title': 'CONSOLIDATED EDISON INC'},
#  '411': {'cik_str': 1705696,
#   'ticker': 'VICI',
#   'title': 'VICI PROPERTIES INC.'},
#  '412': {'cik_str': 49071, 'ticker': 'HUM', 'title': 'HUMANA INC'},
#  '413': {'cik_str': 1159508,
#   'ticker': 'DB',
#   'title': 'DEUTSCHE BANK AKTIENGESELLSCHAFT'},
#  '414': {'cik_str': 720005,
#   'ticker': 'RJF',
#   'title': 'RAYMOND JAMES FINANCIAL INC'},
#  '415': {'cik_str': 915912,
#   'ticker': 'AVB',
#   'title': 'AVALONBAY COMMUNITIES INC'},
#  '416': {'cik_str': 1024478,
#   'ticker': 'ROK',
#   'title': 'ROCKWELL AUTOMATION, INC'},
#  '417': {'cik_str': 815097, 'ticker': 'CCL', 'title': 'CARNIVAL CORP'},
#  '418': {'cik_str': 936958,
#   'ticker': 'MDY',
#   'title': 'SPDR S&P MIDCAP 400 ETF TRUST'},
#  '419': {'cik_str': 46619, 'ticker': 'HEI', 'title': 'HEICO CORP'},
#  '420': {'cik_str': 827052, 'ticker': 'EIX', 'title': 'EDISON INTERNATIONAL'},
#  '421': {'cik_str': 850918,
#   'ticker': 'GWLIF',
#   'title': 'GREAT-WEST LIFECO INC.'},
#  '422': {'cik_str': 65984, 'ticker': 'ETR', 'title': 'ENTERGY CORP /DE/'},
#  '423': {'cik_str': 1700171, 'ticker': 'ANYYY', 'title': 'Aena S.A./ADR'},
#  '424': {'cik_str': 35527, 'ticker': 'FITB', 'title': 'FIFTH THIRD BANCORP'},
#  '425': {'cik_str': 1140536,
#   'ticker': 'WTW',
#   'title': 'WILLIS TOWERS WATSON PLC'},
#  '426': {'cik_str': 79282, 'ticker': 'BRO', 'title': 'BROWN & BROWN, INC.'},
#  '427': {'cik_str': 915191,
#   'ticker': 'FRFHF',
#   'title': 'FAIRFAX FINANCIAL HOLDINGS LTD/ CAN'},
#  '428': {'cik_str': 1450468,
#   'ticker': 'MRAAY',
#   'title': 'Murata Manufacturing Co., Ltd./ADR'},
#  '429': {'cik_str': 946581,
#   'ticker': 'TTWO',
#   'title': 'TAKE TWO INTERACTIVE SOFTWARE INC'},
#  '430': {'cik_str': 1811074,
#   'ticker': 'TPL',
#   'title': 'Texas Pacific Land Corp'},
#  '431': {'cik_str': 1178670,
#   'ticker': 'ALNY',
#   'title': 'ALNYLAM PHARMACEUTICALS, INC.'},
#  '432': {'cik_str': 1751788, 'ticker': 'DOW', 'title': 'DOW INC.'},
#  '433': {'cik_str': 33185, 'ticker': 'EFX', 'title': 'EQUIFAX INC'},
#  '434': {'cik_str': 783325,
#   'ticker': 'WEC',
#   'title': 'WEC ENERGY GROUP, INC.'},
#  '435': {'cik_str': 1618756,
#   'ticker': 'QSR',
#   'title': 'Restaurant Brands International Inc.'},
#  '436': {'cik_str': 1713683, 'ticker': 'ZS', 'title': 'Zscaler, Inc.'},
#  '437': {'cik_str': 1477333, 'ticker': 'NET', 'title': 'Cloudflare, Inc.'},
#  '438': {'cik_str': 798941,
#   'ticker': 'FCNCA',
#   'title': 'FIRST CITIZENS BANCSHARES INC /DE/'},
#  '439': {'cik_str': 1093557, 'ticker': 'DXCM', 'title': 'DEXCOM INC'},
#  '440': {'cik_str': 100517,
#   'ticker': 'UAL',
#   'title': 'United Airlines Holdings, Inc.'},
#  '441': {'cik_str': 1335258,
#   'ticker': 'LYV',
#   'title': 'Live Nation Entertainment, Inc.'},
#  '442': {'cik_str': 1524472, 'ticker': 'XYL', 'title': 'Xylem Inc.'},
#  '443': {'cik_str': 916365,
#   'ticker': 'TSCO',
#   'title': 'TRACTOR SUPPLY CO /DE/'},
#  '444': {'cik_str': 1123360, 'ticker': 'GPN', 'title': 'GLOBAL PAYMENTS INC'},
#  '445': {'cik_str': 1132924,
#   'ticker': 'CHT',
#   'title': 'CHUNGHWA TELECOM CO LTD'},
#  '446': {'cik_str': 1057352, 'ticker': 'CSGP', 'title': 'COSTAR GROUP, INC.'},
#  '447': {'cik_str': 1329099, 'ticker': 'BIDU', 'title': 'Baidu, Inc.'},
#  '448': {'cik_str': 1065088, 'ticker': 'EBAY', 'title': 'EBAY INC'},
#  '449': {'cik_str': 756894, 'ticker': 'GOLD', 'title': 'BARRICK GOLD CORP'},
#  '450': {'cik_str': 844551,
#   'ticker': 'WDS',
#   'title': 'WOODSIDE ENERGY GROUP LTD'},
#  '451': {'cik_str': 1013462, 'ticker': 'ANSS', 'title': 'ANSYS INC'},
#  '452': {'cik_str': 1671750,
#   'ticker': 'DSCSY',
#   'title': 'Disco Corporation/ADR'},
#  '453': {'cik_str': 1071739, 'ticker': 'CNC', 'title': 'CENTENE CORP'},
#  '454': {'cik_str': 721371, 'ticker': 'CAH', 'title': 'CARDINAL HEALTH INC'},
#  '455': {'cik_str': 906107, 'ticker': 'EQR', 'title': 'EQUITY RESIDENTIAL'},
#  '456': {'cik_str': 1445465, 'ticker': 'PPRUY', 'title': 'Kering'},
#  '457': {'cik_str': 1475260, 'ticker': 'CVE', 'title': 'CENOVUS ENERGY INC.'},
#  '458': {'cik_str': 79879, 'ticker': 'PPG', 'title': 'PPG INDUSTRIES INC'},
#  '459': {'cik_str': 1758730, 'ticker': 'TW', 'title': 'Tradeweb Markets Inc.'},
#  '460': {'cik_str': 1783879,
#   'ticker': 'HOOD',
#   'title': 'Robinhood Markets, Inc.'},
#  '461': {'cik_str': 1690820, 'ticker': 'CVNA', 'title': 'CARVANA CO.'},
#  '462': {'cik_str': 1125259, 'ticker': 'CUK', 'title': 'CARNIVAL PLC'},
#  '463': {'cik_str': 55067, 'ticker': 'K', 'title': 'KELLANOVA'},
#  '464': {'cik_str': 93751, 'ticker': 'STT', 'title': 'STATE STREET CORP'},
#  '465': {'cik_str': 1468522, 'ticker': 'FER', 'title': 'Ferrovial SE'},
#  '466': {'cik_str': 906163, 'ticker': 'NVR', 'title': 'NVR INC'},
#  '467': {'cik_str': 29905, 'ticker': 'DOV', 'title': 'DOVER Corp'},
#  '468': {'cik_str': 1642896, 'ticker': 'IOT', 'title': 'Samsara Inc.'},
#  '469': {'cik_str': 1097864, 'ticker': 'ON', 'title': 'ON SEMICONDUCTOR CORP'},
#  '470': {'cik_str': 1021020,
#   'ticker': 'OEZVY',
#   'title': 'OSTERREICHISCHE ELEKTRIZITATSWIRTSCHAFTS /FI'},
#  '471': {'cik_str': 1280452,
#   'ticker': 'MPWR',
#   'title': 'MONOLITHIC POWER SYSTEMS INC'},
#  '472': {'cik_str': 1645590,
#   'ticker': 'HPE',
#   'title': 'Hewlett Packard Enterprise Co'},
#  '473': {'cik_str': 1805284,
#   'ticker': 'RKT',
#   'title': 'Rocket Companies, Inc.'},
#  '474': {'cik_str': 1489393,
#   'ticker': 'LYB',
#   'title': 'LyondellBasell Industries N.V.'},
#  '475': {'cik_str': 717826,
#   'ticker': 'ERIC',
#   'title': 'ERICSSON LM TELEPHONE CO'},
#  '476': {'cik_str': 1131345, 'ticker': 'NVZMY', 'title': 'NOVOZYMES AS/FI'},
#  '477': {'cik_str': 1323404,
#   'ticker': 'WPM',
#   'title': 'Wheaton Precious Metals Corp.'},
#  '478': {'cik_str': 740260, 'ticker': 'VTR', 'title': 'Ventas, Inc.'},
#  '479': {'cik_str': 313927,
#   'ticker': 'CHD',
#   'title': 'CHURCH & DWIGHT CO INC /DE/'},
#  '480': {'cik_str': 910521, 'ticker': 'DECK', 'title': 'DECKERS OUTDOOR CORP'},
#  '481': {'cik_str': 2005951, 'ticker': 'SW', 'title': 'Smurfit Westrock plc'},
#  '482': {'cik_str': 1383312,
#   'ticker': 'BR',
#   'title': 'BROADRIDGE FINANCIAL SOLUTIONS, INC.'},
#  '483': {'cik_str': 822416, 'ticker': 'PHM', 'title': 'PULTEGROUP INC/MI/'},
#  '484': {'cik_str': 1113169,
#   'ticker': 'TROW',
#   'title': 'PRICE T ROWE GROUP INC'},
#  '485': {'cik_str': 45012, 'ticker': 'HAL', 'title': 'HALLIBURTON CO'},
#  '486': {'cik_str': 1410636,
#   'ticker': 'AWK',
#   'title': 'American Water Works Company, Inc.'},
#  '487': {'cik_str': 1601046,
#   'ticker': 'KEYS',
#   'title': 'Keysight Technologies, Inc.'},
#  '488': {'cik_str': 1659166, 'ticker': 'FTV', 'title': 'Fortive Corp'},
#  '489': {'cik_str': 1050952, 'ticker': 'PUBGY', 'title': 'PUBLICIS GROUPE SA'},
#  '490': {'cik_str': 800365,
#   'ticker': 'FUJIY',
#   'title': 'FUJI PHOTO FILM CO LTD /FI'},
#  '491': {'cik_str': 7084,
#   'ticker': 'ADM',
#   'title': 'Archer-Daniels-Midland Co'},
#  '492': {'cik_str': 1609711, 'ticker': 'GDDY', 'title': 'GoDaddy Inc.'},
#  '493': {'cik_str': 1383650,
#   'ticker': 'CQP',
#   'title': 'Cheniere Energy Partners, L.P.'},
#  '494': {'cik_str': 860731,
#   'ticker': 'TYL',
#   'title': 'TYLER TECHNOLOGIES INC'},
#  '495': {'cik_str': 33213, 'ticker': 'EQT', 'title': 'EQT Corp'},
#  '496': {'cik_str': 49196,
#   'ticker': 'HBAN',
#   'title': 'HUNTINGTON BANCSHARES INC /MD/'},
#  '497': {'cik_str': 1175454, 'ticker': 'CPAY', 'title': 'CORPAY, INC.'},
#  '498': {'cik_str': 1967680, 'ticker': 'VLTO', 'title': 'Veralto Corp'},
#  '499': {'cik_str': 1601712, 'ticker': 'SYF', 'title': 'Synchrony Financial'},
#  '500': {'cik_str': 814052, 'ticker': 'TEF', 'title': 'TELEFONICA S A'},
#  '501': {'cik_str': 1446705, 'ticker': 'NTDTY', 'title': 'NTT Data Corp'},
#  '502': {'cik_str': 1090012, 'ticker': 'DVN', 'title': 'DEVON ENERGY CORP/DE'},
#  '503': {'cik_str': 1037646,
#   'ticker': 'MTD',
#   'title': 'METTLER TOLEDO INTERNATIONAL INC/'},
#  '504': {'cik_str': 1585521,
#   'ticker': 'ZM',
#   'title': 'Zoom Video Communications, Inc.'},
#  '505': {'cik_str': 922224, 'ticker': 'PPL', 'title': 'PPL Corp'},
#  '506': {'cik_str': 936340, 'ticker': 'DTE', 'title': 'DTE ENERGY CO'},
#  '507': {'cik_str': 718940, 'ticker': 'BCE', 'title': 'BCE INC'},
#  '508': {'cik_str': 1070304, 'ticker': 'IX', 'title': 'ORIX CORP'},
#  '509': {'cik_str': 1446596, 'ticker': 'FANUY', 'title': 'Fanuc Ltd'},
#  '510': {'cik_str': 313216,
#   'ticker': 'PHG',
#   'title': 'KONINKLIJKE PHILIPS NV'},
#  '511': {'cik_str': 1038683,
#   'ticker': 'RYAAY',
#   'title': 'RYANAIR HOLDINGS PLC'},
#  '512': {'cik_str': 1445930,
#   'ticker': 'KB',
#   'title': 'KB Financial Group Inc.'},
#  '513': {'cik_str': 1002910, 'ticker': 'AEE', 'title': 'AMEREN CORP'},
#  '514': {'cik_str': 1061574, 'ticker': 'GIB', 'title': 'CGI INC'},
#  '515': {'cik_str': 924613, 'ticker': 'NOK', 'title': 'NOKIA CORP'},
#  '516': {'cik_str': 84839, 'ticker': 'ROL', 'title': 'ROLLINS INC'},
#  '517': {'cik_str': 1809587, 'ticker': 'BEKE', 'title': 'KE Holdings Inc.'},
#  '518': {'cik_str': 1546066,
#   'ticker': 'PBA',
#   'title': 'PEMBINA PIPELINE CORP'},
#  '519': {'cik_str': 1002047, 'ticker': 'NTAP', 'title': 'NetApp, Inc.'},
#  '520': {'cik_str': 1160330, 'ticker': 'BBD', 'title': 'BANK BRADESCO'},
#  '521': {'cik_str': 1281761,
#   'ticker': 'RF',
#   'title': 'REGIONS FINANCIAL CORP'},
#  '522': {'cik_str': 1031296, 'ticker': 'FE', 'title': 'FIRSTENERGY CORP'},
#  '523': {'cik_str': 1791706, 'ticker': 'LI', 'title': 'Li Auto Inc.'},
#  '524': {'cik_str': 20286,
#   'ticker': 'CINF',
#   'title': 'CINCINNATI FINANCIAL CORP'},
#  '525': {'cik_str': 48898, 'ticker': 'HUBB', 'title': 'HUBBELL INC'},
#  '526': {'cik_str': 1034054,
#   'ticker': 'SBAC',
#   'title': 'SBA COMMUNICATIONS CORP'},
#  '527': {'cik_str': 1776985, 'ticker': 'BNTX', 'title': 'BioNTech SE'},
#  '528': {'cik_str': 1402057, 'ticker': 'CDW', 'title': 'CDW Corp'},
#  '529': {'cik_str': 1937926,
#   'ticker': 'BAM',
#   'title': 'Brookfield Asset Management Ltd.'},
#  '530': {'cik_str': 875045, 'ticker': 'BIIB', 'title': 'BIOGEN INC.'},
#  '531': {'cik_str': 1397911,
#   'ticker': 'LPLA',
#   'title': 'LPL Financial Holdings Inc.'},
#  '532': {'cik_str': 1880661, 'ticker': 'TPG', 'title': 'TPG Inc.'},
#  '533': {'cik_str': 1009001, 'ticker': 'CCJ', 'title': 'CAMECO CORP'},
#  '534': {'cik_str': 1764757, 'ticker': 'DIDIY', 'title': 'DiDi Global Inc.'},
#  '535': {'cik_str': 1650164, 'ticker': 'TOST', 'title': 'Toast, Inc.'},
#  '536': {'cik_str': 100493, 'ticker': 'TSN', 'title': 'TYSON FOODS, INC.'},
#  '537': {'cik_str': 1324424, 'ticker': 'EXPE', 'title': 'Expedia Group, Inc.'},
#  '538': {'cik_str': 105634, 'ticker': 'EME', 'title': 'EMCOR Group, Inc.'},
#  '539': {'cik_str': 886986, 'ticker': 'TECK', 'title': 'TECK RESOURCES LTD'},
#  '540': {'cik_str': 839923,
#   'ticker': 'VOD',
#   'title': 'VODAFONE GROUP PUBLIC LTD CO'},
#  '541': {'cik_str': 105770,
#   'ticker': 'WST',
#   'title': 'WEST PHARMACEUTICAL SERVICES INC'},
#  '542': {'cik_str': 11544, 'ticker': 'WRB', 'title': 'BERKLEY W R CORP'},
#  '543': {'cik_str': 1001250,
#   'ticker': 'EL',
#   'title': 'ESTEE LAUDER COMPANIES INC'},
#  '544': {'cik_str': 1725964, 'ticker': 'NTR', 'title': 'Nutrien Ltd.'},
#  '545': {'cik_str': 1709048, 'ticker': 'GFS', 'title': 'GLOBALFOUNDRIES Inc.'},
#  '546': {'cik_str': 1400691,
#   'ticker': 'HDELY',
#   'title': 'HeidelbergCement AG'},
#  '547': {'cik_str': 857005, 'ticker': 'PTC', 'title': 'PTC INC.'},
#  '548': {'cik_str': 868675, 'ticker': 'TU', 'title': 'TELUS CORP'},
#  '549': {'cik_str': 932787,
#   'ticker': 'STM',
#   'title': 'STMicroelectronics N.V.'},
#  '550': {'cik_str': 72741, 'ticker': 'ES', 'title': 'EVERSOURCE ENERGY'},
#  '551': {'cik_str': 1437107,
#   'ticker': 'WBD',
#   'title': 'Warner Bros. Discovery, Inc.'},
#  '552': {'cik_str': 731802, 'ticker': 'ATO', 'title': 'ATMOS ENERGY CORP'},
#  '553': {'cik_str': 106535, 'ticker': 'WY', 'title': 'WEYERHAEUSER CO'},
#  '554': {'cik_str': 1136869,
#   'ticker': 'ZBH',
#   'title': 'ZIMMER BIOMET HOLDINGS, INC.'},
#  '555': {'cik_str': 51253,
#   'ticker': 'IFF',
#   'title': 'INTERNATIONAL FLAVORS & FRAGRANCES INC'},
#  '556': {'cik_str': 1456346, 'ticker': 'FNV', 'title': 'FRANCO NEVADA Corp'},
#  '557': {'cik_str': 1666175, 'ticker': 'FTS', 'title': 'Fortis Inc.'},
#  '558': {'cik_str': 895126, 'ticker': 'EXE', 'title': 'EXPAND ENERGY Corp'},
#  '559': {'cik_str': 1094285,
#   'ticker': 'TDY',
#   'title': 'TELEDYNE TECHNOLOGIES INC'},
#  '560': {'cik_str': 1096343, 'ticker': 'MKL', 'title': 'MARKEL GROUP INC.'},
#  '561': {'cik_str': 1713445, 'ticker': 'RDDT', 'title': 'Reddit, Inc.'},
#  '562': {'cik_str': 1757898, 'ticker': 'STE', 'title': 'STERIS plc'},
#  '563': {'cik_str': 1069202,
#   'ticker': 'LII',
#   'title': 'LENNOX INTERNATIONAL INC'},
#  '564': {'cik_str': 1985487,
#   'ticker': 'KSPI',
#   'title': 'Joint Stock Co Kaspi.kz'},
#  '565': {'cik_str': 1336920,
#   'ticker': 'LDOS',
#   'title': 'Leidos Holdings, Inc.'},
#  '566': {'cik_str': 106040, 'ticker': 'WDC', 'title': 'WESTERN DIGITAL CORP'},
#  '567': {'cik_str': 1110803, 'ticker': 'ILMN', 'title': 'ILLUMINA, INC.'},
#  '568': {'cik_str': 1116578, 'ticker': 'PUK', 'title': 'PRUDENTIAL PLC'},
#  '569': {'cik_str': 1000697, 'ticker': 'WAT', 'title': 'WATERS CORP /DE/'},
#  '570': {'cik_str': 1669414,
#   'ticker': 'SMPNY',
#   'title': 'Sompo Japan Nipponkoa Holdings, Inc./ADR'},
#  '571': {'cik_str': 73124, 'ticker': 'NTRS', 'title': 'NORTHERN TRUST CORP'},
#  '572': {'cik_str': 1093028,
#   'ticker': 'EJPRY',
#   'title': 'EAST JAPAN RAILWAY CO /FI'},
#  '573': {'cik_str': 1022671, 'ticker': 'STLD', 'title': 'STEEL DYNAMICS INC'},
#  '574': {'cik_str': 75677,
#   'ticker': 'PKG',
#   'title': 'PACKAGING CORP OF AMERICA'},
#  '575': {'cik_str': 922621, 'ticker': 'ERIE', 'title': 'ERIE INDEMNITY CO'},
#  '576': {'cik_str': 1374310,
#   'ticker': 'CBOE',
#   'title': 'Cboe Global Markets, Inc.'},
#  '577': {'cik_str': 1651308, 'ticker': 'BGNE', 'title': 'BeiGene, Ltd.'},
#  '578': {'cik_str': 105016, 'ticker': 'WSO', 'title': 'WATSCO INC'},
#  '579': {'cik_str': 21076, 'ticker': 'CLX', 'title': 'CLOROX CO /DE/'},
#  '580': {'cik_str': 1122411,
#   'ticker': 'ASX',
#   'title': 'ASE Technology Holding Co., Ltd.'},
#  '581': {'cik_str': 1158967, 'ticker': 'NJDCY', 'title': 'NIDEC CORP'},
#  '582': {'cik_str': 1417663,
#   'ticker': 'SNWV',
#   'title': 'SANUWAVE Health, Inc.'},
#  '583': {'cik_str': 1687229,
#   'ticker': 'INVH',
#   'title': 'Invitation Homes Inc.'},
#  '584': {'cik_str': 1274494, 'ticker': 'FSLR', 'title': 'FIRST SOLAR, INC.'},
#  '585': {'cik_str': 1190723, 'ticker': 'TS', 'title': 'TENARIS SA'},
#  '586': {'cik_str': 1511737, 'ticker': 'UI', 'title': 'Ubiquiti Inc.'},
#  '587': {'cik_str': 759944,
#   'ticker': 'CFG',
#   'title': 'CITIZENS FINANCIAL GROUP INC/RI'},
#  '588': {'cik_str': 1137789,
#   'ticker': 'STX',
#   'title': 'Seagate Technology Holdings plc'},
#  '589': {'cik_str': 811156, 'ticker': 'CMS', 'title': 'CMS ENERGY CORP'},
#  '590': {'cik_str': 1441816, 'ticker': 'MDB', 'title': 'MongoDB, Inc.'},
#  '591': {'cik_str': 1316835,
#   'ticker': 'BLDR',
#   'title': 'Builders FirstSource, Inc.'},
#  '592': {'cik_str': 790051,
#   'ticker': 'CSL',
#   'title': 'CARLISLE COMPANIES INC'},
#  '593': {'cik_str': 1754301, 'ticker': 'FOXA', 'title': 'Fox Corp'},
#  '594': {'cik_str': 1334687,
#   'ticker': 'CJPRY',
#   'title': 'CENTRAL JAPAN RAILWAY CO'},
#  '595': {'cik_str': 920522,
#   'ticker': 'ESS',
#   'title': 'ESSEX PROPERTY TRUST, INC.'},
#  '596': {'cik_str': 63754, 'ticker': 'MKC', 'title': 'MCCORMICK & CO INC'},
#  '597': {'cik_str': 764478, 'ticker': 'BBY', 'title': 'BEST BUY CO INC'},
#  '598': {'cik_str': 877212,
#   'ticker': 'ZBRA',
#   'title': 'ZEBRA TECHNOLOGIES CORP'},
#  '599': {'cik_str': 711404,
#   'ticker': 'COO',
#   'title': 'COOPER COMPANIES, INC.'},
#  '600': {'cik_str': 1130310,
#   'ticker': 'CNP',
#   'title': 'CENTERPOINT ENERGY INC'},
# ...
#  '806': {'cik_str': 1294591,
#   'ticker': 'RKUNY',
#   'title': 'Rakuten Group, Inc.'},
#  '807': {'cik_str': 1037976,
#   'ticker': 'JLL',
#   'title': 'JONES LANG LASALLE INC'},
#  '808': {'cik_str': 1810997, 'ticker': 'XPEV', 'title': 'XPENG INC.'},
#  '809': {'cik_str': 216228, 'ticker': 'ITT', 'title': 'ITT INC.'},
#  '810': {'cik_str': 1910139,
#   'ticker': 'MBLY',
#   'title': 'Mobileye Global Inc.'},
#  '811': {'cik_str': 1070750,
#   'ticker': 'HST',
#   'title': 'HOST HOTELS & RESORTS, INC.'},
#  '812': {'cik_str': 802481, 'ticker': 'PPC', 'title': 'PILGRIMS PRIDE CORP'},
#  '813': {'cik_str': 1172724, 'ticker': 'GFI', 'title': 'GOLD FIELDS LTD'},
#  '814': {'cik_str': 1043604,
#   'ticker': 'JNPR',
#   'title': 'JUNIPER NETWORKS INC'},
#  '815': {'cik_str': 1517231,
#   'ticker': 'SSMXY',
#   'title': 'Sysmex Corporation/ADR'},
#  '816': {'cik_str': 1025378, 'ticker': 'WPC', 'title': 'W. P. Carey Inc.'},
#  '817': {'cik_str': 1754581, 'ticker': 'FUTU', 'title': 'Futu Holdings Ltd'},
#  '818': {'cik_str': 1588823,
#   'ticker': 'TFII',
#   'title': 'TFI International Inc.'},
#  '819': {'cik_str': 1579241, 'ticker': 'ALLE', 'title': 'Allegion plc'},
#  '820': {'cik_str': 1070423,
#   'ticker': 'PAA',
#   'title': 'PLAINS ALL AMERICAN PIPELINE LP'},
#  '821': {'cik_str': 1504122,
#   'ticker': 'PTBRY',
#   'title': 'PT Bank Negara Indonesia (Persero) Tbk/ADR'},
#  '822': {'cik_str': 1048477,
#   'ticker': 'BMRN',
#   'title': 'BIOMARIN PHARMACEUTICAL INC'},
#  '823': {'cik_str': 1326380, 'ticker': 'GME', 'title': 'GameStop Corp.'},
#  '824': {'cik_str': 89089,
#   'ticker': 'SCI',
#   'title': 'SERVICE CORP INTERNATIONAL'},
#  '825': {'cik_str': 1170010, 'ticker': 'KMX', 'title': 'CARMAX INC'},
#  '826': {'cik_str': 915913, 'ticker': 'ALB', 'title': 'ALBEMARLE CORP'},
#  '827': {'cik_str': 1135951,
#   'ticker': 'RDY',
#   'title': 'DR REDDYS LABORATORIES LTD'},
#  '828': {'cik_str': 1600520,
#   'ticker': 'JPXGY',
#   'title': 'Japan Exchange Group, Inc./ADR'},
#  '829': {'cik_str': 1720635, 'ticker': 'NVT', 'title': 'nVent Electric plc'},
#  '830': {'cik_str': 914475,
#   'ticker': 'NBIX',
#   'title': 'NEUROCRINE BIOSCIENCES INC'},
#  '831': {'cik_str': 1681459, 'ticker': 'FTI', 'title': 'TechnipFMC plc'},
#  '832': {'cik_str': 1658566,
#   'ticker': 'PR',
#   'title': 'Permian Resources Corp'},
#  '833': {'cik_str': 1032975,
#   'ticker': 'LOGI',
#   'title': 'LOGITECH INTERNATIONAL S.A.'},
#  '834': {'cik_str': 1104506, 'ticker': 'INSM', 'title': 'INSMED Inc'},
#  '835': {'cik_str': 1725057, 'ticker': 'DAY', 'title': 'Dayforce, Inc.'},
#  '836': {'cik_str': 915389, 'ticker': 'EMN', 'title': 'EASTMAN CHEMICAL CO'},
#  '837': {'cik_str': 1281721, 'ticker': 'SGIOY', 'title': 'SHIONOGI & CO LTD'},
#  '838': {'cik_str': 720672, 'ticker': 'SF', 'title': 'STIFEL FINANCIAL CORP'},
#  '839': {'cik_str': 1531152,
#   'ticker': 'BJ',
#   'title': "BJ's Wholesale Club Holdings, Inc."},
#  '840': {'cik_str': 1964738, 'ticker': 'SOLV', 'title': 'Solventum Corp'},
#  '841': {'cik_str': 59527,
#   'ticker': 'LECO',
#   'title': 'LINCOLN ELECTRIC HOLDINGS INC'},
#  '842': {'cik_str': 4457, 'ticker': 'UHAL', 'title': 'U-Haul Holding Co /NV/'},
#  '843': {'cik_str': 1161125, 'ticker': 'BCH', 'title': 'BANK OF CHILE'},
#  '844': {'cik_str': 1513761,
#   'ticker': 'NCLH',
#   'title': 'Norwegian Cruise Line Holdings Ltd.'},
#  '845': {'cik_str': 1042046,
#   'ticker': 'AFG',
#   'title': 'AMERICAN FINANCIAL GROUP INC'},
#  '846': {'cik_str': 1170858,
#   'ticker': 'SBS',
#   'title': 'COMPANHIA DE SANEAMENTO BASICO DO ESTADO DE SAO PAULO-SABESP'},
#  '847': {'cik_str': 1486957,
#   'ticker': 'BWXT',
#   'title': 'BWX Technologies, Inc.'},
#  '848': {'cik_str': 1446444,
#   'ticker': 'TKHVY',
#   'title': 'Turk Hava Yollari A.O.'},
#  '849': {'cik_str': 1675149, 'ticker': 'AA', 'title': 'Alcoa Corp'},
#  '850': {'cik_str': 1450346,
#   'ticker': 'POAHY',
#   'title': 'Porsche Automobil Holding SE / ADR'},
#  '851': {'cik_str': 353991,
#   'ticker': 'NDEKY',
#   'title': 'NITTO DENKO CORP / ADR/'},
#  '852': {'cik_str': 91419, 'ticker': 'SJM', 'title': 'J M SMUCKER Co'},
#  '853': {'cik_str': 701818, 'ticker': 'KGC', 'title': 'KINROSS GOLD CORP'},
#  '854': {'cik_str': 1360901, 'ticker': 'EVR', 'title': 'Evercore Inc.'},
#  '855': {'cik_str': 1792580, 'ticker': 'OVV', 'title': 'Ovintiv Inc.'},
#  '856': {'cik_str': 38777, 'ticker': 'BEN', 'title': 'FRANKLIN RESOURCES INC'},
#  '857': {'cik_str': 896622, 'ticker': 'ATR', 'title': 'APTARGROUP, INC.'},
#  '858': {'cik_str': 82811, 'ticker': 'RRX', 'title': 'REGAL REXNORD CORP'},
#  '859': {'cik_str': 1483994, 'ticker': 'HTHT', 'title': 'H World Group Ltd'},
#  '860': {'cik_str': 1267238, 'ticker': 'AIZ', 'title': 'ASSURANT, INC.'},
#  '861': {'cik_str': 888491,
#   'ticker': 'OHI',
#   'title': 'OMEGA HEALTHCARE INVESTORS INC'},
#  '862': {'cik_str': 789570,
#   'ticker': 'MGM',
#   'title': 'MGM Resorts International'},
#  '863': {'cik_str': 1591698,
#   'ticker': 'PCTY',
#   'title': 'Paylocity Holding Corp'},
#  '864': {'cik_str': 806968, 'ticker': 'WPP', 'title': 'WPP plc'},
#  '865': {'cik_str': 40729, 'ticker': 'ALLY', 'title': 'Ally Financial Inc.'},
#  '866': {'cik_str': 1237831, 'ticker': 'GMED', 'title': 'GLOBUS MEDICAL INC'},
#  '867': {'cik_str': 1043219,
#   'ticker': 'NLY',
#   'title': 'ANNALY CAPITAL MANAGEMENT INC'},
#  '868': {'cik_str': 1646972,
#   'ticker': 'ACI',
#   'title': 'Albertsons Companies, Inc.'},
#  '869': {'cik_str': 1298675, 'ticker': 'CUBE', 'title': 'CubeSmart'},
#  '870': {'cik_str': 1507079,
#   'ticker': 'FND',
#   'title': 'Floor & Decor Holdings, Inc.'},
#  '871': {'cik_str': 831641, 'ticker': 'TTEK', 'title': 'TETRA TECH INC'},
#  '872': {'cik_str': 1679273,
#   'ticker': 'LW',
#   'title': 'Lamb Weston Holdings, Inc.'},
#  '873': {'cik_str': 1468608,
#   'ticker': 'VDMCY',
#   'title': 'Vodacom Group Ltd / ADR'},
#  '874': {'cik_str': 1495153, 'ticker': 'MMYT', 'title': 'MakeMyTrip Ltd'},
#  '875': {'cik_str': 1062066, 'ticker': 'ALSMY', 'title': 'ALSTOM'},
#  '876': {'cik_str': 1446656, 'ticker': 'KIKOY', 'title': 'Kikkoman Corp'},
#  '877': {'cik_str': 1003935, 'ticker': 'NICE', 'title': 'NICE Ltd.'},
#  '878': {'cik_str': 1669162,
#   'ticker': 'KNSL',
#   'title': 'Kinsale Capital Group, Inc.'},
#  '879': {'cik_str': 845982, 'ticker': 'SNN', 'title': 'SMITH & NEPHEW PLC'},
#  '880': {'cik_str': 842023, 'ticker': 'TECH', 'title': 'BIO-TECHNE Corp'},
#  '881': {'cik_str': 1596783, 'ticker': 'CTLT', 'title': 'Catalent, Inc.'},
#  '882': {'cik_str': 1649094, 'ticker': 'PCVX', 'title': 'Vaxcyte, Inc.'},
#  '883': {'cik_str': 1019849,
#   'ticker': 'PAG',
#   'title': 'PENSKE AUTOMOTIVE GROUP, INC.'},
#  '884': {'cik_str': 1219601, 'ticker': 'CCK', 'title': 'CROWN HOLDINGS, INC.'},
#  '885': {'cik_str': 1474735,
#   'ticker': 'GNRC',
#   'title': 'GENERAC HOLDINGS INC.'},
#  '886': {'cik_str': 36966, 'ticker': 'FHN', 'title': 'FIRST HORIZON CORP'},
#  '887': {'cik_str': 1573516, 'ticker': 'MUSA', 'title': 'Murphy USA Inc.'},
#  '888': {'cik_str': 15615, 'ticker': 'MTZ', 'title': 'MASTEC INC'},
#  '889': {'cik_str': 1579091, 'ticker': 'CART', 'title': 'Maplebear Inc.'},
#  '890': {'cik_str': 824142, 'ticker': 'AAON', 'title': 'AAON, INC.'},
#  '891': {'cik_str': 909037,
#   'ticker': 'SQM',
#   'title': 'CHEMICAL & MINING CO OF CHILE INC'},
#  '892': {'cik_str': 1433642, 'ticker': 'HLNE', 'title': 'Hamilton Lane INC'},
#  '893': {'cik_str': 1555812,
#   'ticker': 'SMKUY',
#   'title': 'Siam Makro Public Co Limited/ADR'},
#  '894': {'cik_str': 78128,
#   'ticker': 'WTRG',
#   'title': 'Essential Utilities, Inc.'},
#  '895': {'cik_str': 769218, 'ticker': 'AEG', 'title': 'AEGON LTD.'},
#  '896': {'cik_str': 1127248, 'ticker': 'EMRAF', 'title': 'EMERA INC'},
#  '897': {'cik_str': 1027664, 'ticker': 'ESLT', 'title': 'ELBIT SYSTEMS LTD'},
#  '898': {'cik_str': 91142, 'ticker': 'AOS', 'title': 'SMITH A O CORP'},
#  '899': {'cik_str': 317540,
#   'ticker': 'COKE',
#   'title': 'Coca-Cola Consolidated, Inc.'},
#  '900': {'cik_str': 1545772,
#   'ticker': 'BPYPP',
#   'title': 'Brookfield Property Partners L.P.'},
#  '901': {'cik_str': 871464,
#   'ticker': 'HNGKY',
#   'title': 'HONGKONG LAND HOLDINGS LTD /FI'},
#  '902': {'cik_str': 887225,
#   'ticker': 'KEP',
#   'title': 'KOREA ELECTRIC POWER CORP'},
#  '903': {'cik_str': 16058,
#   'ticker': 'CACI',
#   'title': 'CACI INTERNATIONAL INC /DE/'},
#  '904': {'cik_str': 764622,
#   'ticker': 'PNW',
#   'title': 'PINNACLE WEST CAPITAL CORP'},
#  '905': {'cik_str': 1375365,
#   'ticker': 'SMCI',
#   'title': 'Super Micro Computer, Inc.'},
#  '906': {'cik_str': 350894, 'ticker': 'SEIC', 'title': 'SEI INVESTMENTS CO'},
#  '907': {'cik_str': 1611052,
#   'ticker': 'PCOR',
#   'title': 'PROCORE TECHNOLOGIES, INC.'},
#  '908': {'cik_str': 109563,
#   'ticker': 'AIT',
#   'title': 'APPLIED INDUSTRIAL TECHNOLOGIES INC'},
#  '909': {'cik_str': 275880, 'ticker': 'PSN', 'title': 'PARSONS CORP'},
#  '910': {'cik_str': 1633931, 'ticker': 'BLD', 'title': 'TopBuild Corp'},
#  '911': {'cik_str': 20212, 'ticker': 'CHDN', 'title': 'Churchill Downs Inc'},
#  '912': {'cik_str': 1622536, 'ticker': 'TLN', 'title': 'Talen Energy Corp'},
#  '913': {'cik_str': 108312, 'ticker': 'WWD', 'title': 'Woodward, Inc.'},
#  '914': {'cik_str': 801337,
#   'ticker': 'WBS',
#   'title': 'WEBSTER FINANCIAL CORP'},
#  '915': {'cik_str': 51644,
#   'ticker': 'IPG',
#   'title': 'INTERPUBLIC GROUP OF COMPANIES, INC.'},
#  '916': {'cik_str': 1078642, 'ticker': 'CRRFY', 'title': 'CARREFOUR SA'},
#  '917': {'cik_str': 1604028,
#   'ticker': 'WMS',
#   'title': 'ADVANCED DRAINAGE SYSTEMS, INC.'},
#  '918': {'cik_str': 1144215, 'ticker': 'AYI', 'title': 'ACUITY BRANDS INC'},
#  '919': {'cik_str': 89439, 'ticker': 'MLI', 'title': 'MUELLER INDUSTRIES INC'},
#  '920': {'cik_str': 1428439, 'ticker': 'ROKU', 'title': 'ROKU, INC'},
#  '921': {'cik_str': 918646, 'ticker': 'EXP', 'title': 'EAGLE MATERIALS INC'},
#  '922': {'cik_str': 785161, 'ticker': 'EHC', 'title': 'Encompass Health Corp'},
#  '923': {'cik_str': 1874178,
#   'ticker': 'RIVN',
#   'title': 'Rivian Automotive, Inc. / DE'},
#  '924': {'cik_str': 1411207,
#   'ticker': 'ALSN',
#   'title': 'Allison Transmission Holdings Inc'},
#  '925': {'cik_str': 1783398, 'ticker': 'UWMC', 'title': 'UWM Holdings Corp'},
#  '926': {'cik_str': 1973832, 'ticker': 'AU', 'title': 'AngloGold Ashanti PLC'},
#  '927': {'cik_str': 938323, 'ticker': 'PSO', 'title': 'PEARSON PLC'},
#  '928': {'cik_str': 1541309,
#   'ticker': 'CSXXY',
#   'title': 'carsales.com Limited/ADR'},
#  '929': {'cik_str': 1065696, 'ticker': 'LKQ', 'title': 'LKQ CORP'},
#  '930': {'cik_str': 929008,
#   'ticker': 'WCC',
#   'title': 'WESCO INTERNATIONAL INC'},
#  '931': {'cik_str': 1901440, 'ticker': 'ULS', 'title': 'UL Solutions Inc.'},
#  '932': {'cik_str': 1023128, 'ticker': 'LAD', 'title': 'LITHIA MOTORS INC'},
#  '933': {'cik_str': 1944013, 'ticker': 'CR', 'title': 'Crane Co'},
#  '934': {'cik_str': 939767, 'ticker': 'EXEL', 'title': 'EXELIXIS, INC.'},
#  '935': {'cik_str': 1584509, 'ticker': 'ARMK', 'title': 'Aramark'},
#  '936': {'cik_str': 1475922, 'ticker': 'PRI', 'title': 'Primerica, Inc.'},
#  '937': {'cik_str': 1174922, 'ticker': 'WYNN', 'title': 'WYNN RESORTS LTD'},
#  '938': {'cik_str': 1212545,
#   'ticker': 'WAL',
#   'title': 'WESTERN ALLIANCE BANCORPORATION'},
#  '939': {'cik_str': 873303,
#   'ticker': 'SRPT',
#   'title': 'Sarepta Therapeutics, Inc.'},
#  '940': {'cik_str': 1576789, 'ticker': 'WIX', 'title': 'Wix.com Ltd.'},
#  '941': {'cik_str': 1278021,
#   'ticker': 'MKTX',
#   'title': 'MARKETAXESS HOLDINGS INC'},
#  '942': {'cik_str': 874761, 'ticker': 'AES', 'title': 'AES CORP'},
#  '943': {'cik_str': 1447126,
#   'ticker': 'KAIKY',
#   'title': 'Kawasaki Kisen Kaisha Ltd'},
#  '944': {'cik_str': 1668397,
#   'ticker': 'MEDP',
#   'title': 'Medpace Holdings, Inc.'},
#  '945': {'cik_str': 1324948, 'ticker': 'RBC', 'title': 'RBC Bearings INC'},
#  '946': {'cik_str': 1988894, 'ticker': 'AS', 'title': 'Amer Sports, Inc.'},
#  '947': {'cik_str': 1177394, 'ticker': 'SNX', 'title': 'TD SYNNEX CORP'},
#  '948': {'cik_str': 1842022, 'ticker': 'DTM', 'title': 'DT Midstream, Inc.'},
#  '949': {'cik_str': 1796209, 'ticker': 'APG', 'title': 'APi Group Corp'},
#  '950': {'cik_str': 34903,
#   'ticker': 'FRT',
#   'title': 'FEDERAL REALTY INVESTMENT TRUST'},
#  '951': {'cik_str': 936395, 'ticker': 'CIEN', 'title': 'CIENA CORP'},
#  '952': {'cik_str': 1062579, 'ticker': 'DOX', 'title': 'AMDOCS LTD'},
#  '953': {'cik_str': 1571283,
#   'ticker': 'REXR',
#   'title': 'Rexford Industrial Realty, Inc.'},
#  '954': {'cik_str': 1100682,
#   'ticker': 'CRL',
#   'title': 'CHARLES RIVER LABORATORIES INTERNATIONAL, INC.'},
#  '955': {'cik_str': 1973266,
#   'ticker': 'TKO',
#   'title': 'TKO Group Holdings, Inc.'},
#  '956': {'cik_str': 1602065, 'ticker': 'VNOM', 'title': 'Viper Energy, Inc.'},
#  '957': {'cik_str': 1835830, 'ticker': 'KVYO', 'title': 'Klaviyo, Inc.'},
#  '958': {'cik_str': 1050140,
#   'ticker': 'DSGX',
#   'title': 'DESCARTES SYSTEMS GROUP INC'},
#  '959': {'cik_str': 1115055,
#   'ticker': 'PNFP',
#   'title': 'PINNACLE FINANCIAL PARTNERS INC'},
#  '960': {'cik_str': 1653482, 'ticker': 'GTLB', 'title': 'Gitlab Inc.'},
#  '961': {'cik_str': 1030894, 'ticker': 'CLS', 'title': 'CELESTICA INC'},
#  '962': {'cik_str': 1736541, 'ticker': 'NIO', 'title': 'NIO Inc.'},
#  '963': {'cik_str': 74260,
#   'ticker': 'ORI',
#   'title': 'OLD REPUBLIC INTERNATIONAL CORP'},
#  '964': {'cik_str': 1206264,
#   'ticker': 'TPX',
#   'title': 'TEMPUR SEALY INTERNATIONAL, INC.'},
#  '965': {'cik_str': 1131383, 'ticker': 'STN', 'title': 'STANTEC INC'},
#  '966': {'cik_str': 1433270, 'ticker': 'AR', 'title': 'ANTERO RESOURCES Corp'},
#  '967': {'cik_str': 1330568, 'ticker': 'SLV', 'title': 'iShares Silver Trust'},
#  '968': {'cik_str': 1438654,
#   'ticker': 'RDEIY',
#   'title': 'Red Electrica Corporacion SA/ADR'},
#  '969': {'cik_str': 1481045,
#   'ticker': 'DSEEY',
#   'title': 'Daiwa Securities Group Inc.'},
#  '970': {'cik_str': 1819994,
#   'ticker': 'RKLB',
#   'title': 'Rocket Lab USA, Inc.'},
#  '971': {'cik_str': 6201,
#   'ticker': 'AAL',
#   'title': 'American Airlines Group Inc.'},
#  '972': {'cik_str': 1772016,
#   'ticker': 'BRBR',
#   'title': 'BELLRING BRANDS, INC.'},
#  '973': {'cik_str': 1440130,
#   'ticker': 'UUGRY',
#   'title': 'United Utilities Group plc'},
#  '974': {'cik_str': 2025410, 'ticker': 'SARO', 'title': 'StandardAero, Inc.'},
#  '975': {'cik_str': 1628171,
#   'ticker': 'RVMD',
#   'title': 'Revolution Medicines, Inc.'},
#  '976': {'cik_str': 1636222, 'ticker': 'WING', 'title': 'Wingstop Inc.'},
#  '977': {'cik_str': 85535, 'ticker': 'RGLD', 'title': 'ROYAL GOLD INC'},
#  '978': {'cik_str': 1519751,
#   'ticker': 'FBIN',
#   'title': 'Fortune Brands Innovations, Inc.'},
#  '979': {'cik_str': 1516513, 'ticker': 'DOCS', 'title': 'Doximity, Inc.'},
#  '980': {'cik_str': 1046257, 'ticker': 'INGR', 'title': 'Ingredion Inc'},
#  '981': {'cik_str': 1124140, 'ticker': 'EXAS', 'title': 'EXACT SCIENCES CORP'},
#  '982': {'cik_str': 29644, 'ticker': 'DCI', 'title': 'DONALDSON Co INC'},
#  '983': {'cik_str': 22356,
#   'ticker': 'CBSH',
#   'title': 'COMMERCE BANCSHARES INC /MO/'},
#  '984': {'cik_str': 1065837, 'ticker': 'SKX', 'title': 'SKECHERS USA INC'},
#  '985': {'cik_str': 1321732, 'ticker': 'PEN', 'title': 'Penumbra Inc'},
#  '986': {'cik_str': 320335, 'ticker': 'GL', 'title': 'GLOBE LIFE INC.'},
#  '987': {'cik_str': 1015820, 'ticker': 'QGEN', 'title': 'QIAGEN N.V.'},
#  '988': {'cik_str': 1372920,
#   'ticker': 'EDU',
#   'title': 'New Oriental Education & Technology Group Inc.'},
#  '989': {'cik_str': 28412, 'ticker': 'CMA', 'title': 'COMERICA INC /NEW/'},
#  '990': {'cik_str': 1027552,
#   'ticker': 'BSAC',
#   'title': 'BANCO SANTANDER CHILE'},
#  '991': {'cik_str': 1913510, 'ticker': 'VFS', 'title': 'VinFast Auto Ltd.'},
#  '992': {'cik_str': 12208,
#   'ticker': 'BIO',
#   'title': 'BIO-RAD LABORATORIES, INC.'},
#  '993': {'cik_str': 1492691,
#   'ticker': 'KNX',
#   'title': 'Knight-Swift Transportation Holdings Inc.'},
#  '994': {'cik_str': 1124198, 'ticker': 'FLR', 'title': 'FLUOR CORP'},
#  '995': {'cik_str': 1380365,
#   'ticker': 'IDKOY',
#   'title': 'IDEMITSU KOSAN CO., LTD'},
#  '996': {'cik_str': 1766363,
#   'ticker': 'EDR',
#   'title': 'Endeavor Group Holdings, Inc.'},
#  '997': {'cik_str': 1833756, 'ticker': 'DRS', 'title': 'Leonardo DRS, Inc.'},
#  '998': {'cik_str': 1493594,
#   'ticker': 'MTSI',
#   'title': 'MACOM Technology Solutions Holdings, Inc.'},
#  '999': {'cik_str': 1567514,
#   'ticker': 'ITCI',
#   'title': 'Intra-Cellular Therapies, Inc.'},
#  ...}

# %%
len(company_tickers)
# Out:
# 9998

# %% [markdown]
# # Inserting Stocks into Pinecone
#
# **1. Create an account on [Pinecone.io](https://app.pinecone.io/)**
#
# **2. Create a new index called "stocks" and set the dimensions to 768. Leave the rest of the settings as they are.**
#
# ![Screenshot 2024-12-02 at 4 48 03 PM](https://github.com/user-attachments/assets/13b484da-cd00-4337-a4db-4779080eb42c)
#
#
# **3. Create an API Key for Pinecone**
#
# ![Screenshot 2024-11-24 at 10 44 37 PM](https://github.com/user-attachments/assets/e7feacc6-2bd1-472a-82e5-659f65624a88)
#
#
# **4. Store your Pinecone API Key within Google Colab's secrets section, and then enable access to it (see the blue checkmark)**
#
#
# ![Screenshot 2024-11-24 at 10 45 25 PM](https://github.com/user-attachments/assets/eaf73083-0b5f-4d17-9e0c-eab84f91b0bc)

# %%
from google.colab import userdata
pinecone_api_key = userdata.get("PINECONE_API_KEY")
os.environ['PINECONE_API_KEY'] = pinecone_api_key

index_name = "stocks"
namespace = "stock-descriptions"

hf_embeddings = HuggingFaceEmbeddings()
vectorstore = PineconeVectorStore(index_name=index_name, embedding=hf_embeddings)
# Out:
# <ipython-input-17-5657f255fe44>:8: LangChainDeprecationWarning: Default values for HuggingFaceEmbeddings.model_name were deprecated in LangChain 0.2.16 and will be removed in 0.4.0. Explicitly pass a model_name to the HuggingFaceEmbeddings constructor instead.
#   hf_embeddings = HuggingFaceEmbeddings()

# %%
# for idx, stock in company_tickers.items():
#     stock_ticker = stock['ticker']
#     stock_data = get_stock_info(stock_ticker)
#     stock_description = stock_data['Business Summary']

#     print(f"Processing stock {idx} / {len(company_tickers)} :", stock_ticker)

#     vectorstore_from_documents = PineconeVectorStore.from_documents(
#         documents=[Document(page_content=stock_description, metadata=stock_data)],
#         embedding=hf_embeddings,
#         index_name=index_name,
#         namespace=namespace
#     )

# %% [markdown]
# # Parallelizing
#
# [![](https://mermaid.ink/img/pako:eNqNkl1rgzAUhv9KyMXYwF74cSVjYA0rhY6WKRQWe5FqWqU1cUm8GKX_ffmwa65Gc6Hn5LxvzmM8F1jzhsIUHgUZWlCiigG9MlwoXp_AqpPqdS_esmyzCsBivV7o10fxXgagLFbZDsxmb2COi44dzxRsBK-plDoBZSsoaXbuNPeU4941qWBBv0fKVEfOvud5yejh0NWdLr1U0LnMmts2eYhDMLsZgEHa3TV5aEXbEG-zZZnasiXfLMGnaScVeNKRHDiT1DNunRGF5pMFtUaAiCKe5h4hp84jHHks9mJ8mMjBRBOMrT9G45wommis84bjYThZHuPYwzA_xqeIHUU8UZjyYxDOiOIJwhj_uRKnzhOc3FHsdHgoiUNJJhRTfgzFGVEyoRijj0JZAwPYU9GTrtFjfDHbFVQt7WkFUx02RJzMMF21joyKFz-shqkSIw2g4OOxhemBnKXOxqEhiqKO6DHt_3YHwr44v-XXX7It6B4?type=png)](https://mermaid.live/edit#pako:eNqNkl1rgzAUhv9KyMXYwF74cSVjYA0rhY6WKRQWe5FqWqU1cUm8GKX_ffmwa65Gc6Hn5LxvzmM8F1jzhsIUHgUZWlCiigG9MlwoXp_AqpPqdS_esmyzCsBivV7o10fxXgagLFbZDsxmb2COi44dzxRsBK-plDoBZSsoaXbuNPeU4941qWBBv0fKVEfOvud5yejh0NWdLr1U0LnMmts2eYhDMLsZgEHa3TV5aEXbEG-zZZnasiXfLMGnaScVeNKRHDiT1DNunRGF5pMFtUaAiCKe5h4hp84jHHks9mJ8mMjBRBOMrT9G45wommis84bjYThZHuPYwzA_xqeIHUU8UZjyYxDOiOIJwhj_uRKnzhOc3FHsdHgoiUNJJhRTfgzFGVEyoRijj0JZAwPYU9GTrtFjfDHbFVQt7WkFUx02RJzMMF21joyKFz-shqkSIw2g4OOxhemBnKXOxqEhiqKO6DHt_3YHwr44v-XXX7It6B4)

# %%
# Initialize tracking lists
successful_tickers = []
unsuccessful_tickers = []

# Load existing successful/unsuccessful tickers
try:
    with open('successful_tickers.txt', 'r') as f:
        successful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(successful_tickers)} successful tickers")
except FileNotFoundError:
    print("No existing successful tickers file found")

try:
    with open('unsuccessful_tickers.txt', 'r') as f:
        unsuccessful_tickers = [line.strip() for line in f if line.strip()]
    print(f"Loaded {len(unsuccessful_tickers)} unsuccessful tickers")
except FileNotFoundError:
    print("No existing unsuccessful tickers file found")
# Out:
# Loaded 336 successful tickers
# Loaded 5 unsuccessful tickers

# %% [markdown]
# [![](https://mermaid.ink/img/pako:eNqFk0uLgzAQgP_KkMOe7MHXRZaC1baXvsDCwqqHrGarVJMSE9hS-983NnWxULceRmf4Pp2MyQVlLCfIQweOTwXsw4SCuvw4Eiw7wqpsxPsXn_r-bmXAcrtdqts6WuwN2Ecr3wB__blJYTKZwixe45JCwKjgrKoI7zwXdphjlVXwwfiR8CbVH9BxdjPbqKxlJTAlTDbVuYXAjDUNZveSHWcZaRromkj_F61etIbire8Xpt2b9tDslvpCdHrRGYrddF6Ibi-6D4vsBjqcUWDe_NCMl0TAG6gfwwmEWOA7FlgasEYBWwP2KOBowBkFXA24Y4COoW61DRklLcwvQUHUHooEFrK53hHrAbkX7WdF51nRfVLUcX4fs8y6ObawMON-phvyI2CGRVakyEA14TUuc7XnL52ZIFGQmiTIU4855scEJfSqOCwFi840Q57gkhiIM3kokPeNq0Zl8pRjQcISq4NT_1VPmH4y1ufXXwdkCM8?type=png)](https://mermaid.live/edit#pako:eNqFk0uLgzAQgP_KkMOe7MHXRZaC1baXvsDCwqqHrGarVJMSE9hS-983NnWxULceRmf4Pp2MyQVlLCfIQweOTwXsw4SCuvw4Eiw7wqpsxPsXn_r-bmXAcrtdqts6WuwN2Ecr3wB__blJYTKZwixe45JCwKjgrKoI7zwXdphjlVXwwfiR8CbVH9BxdjPbqKxlJTAlTDbVuYXAjDUNZveSHWcZaRromkj_F61etIbire8Xpt2b9tDslvpCdHrRGYrddF6Ibi-6D4vsBjqcUWDe_NCMl0TAG6gfwwmEWOA7FlgasEYBWwP2KOBowBkFXA24Y4COoW61DRklLcwvQUHUHooEFrK53hHrAbkX7WdF51nRfVLUcX4fs8y6ObawMON-phvyI2CGRVakyEA14TUuc7XnL52ZIFGQmiTIU4855scEJfSqOCwFi840Q57gkhiIM3kokPeNq0Zl8pRjQcISq4NT_1VPmH4y1ufXXwdkCM8)

# %%
def process_stock(stock_ticker: str) -> str:
    # Skip if already processed
    if stock_ticker in successful_tickers:
        return f"Already processed {stock_ticker}"

    try:
        # Get and store stock data
        stock_data = get_stock_info(stock_ticker)
        stock_description = stock_data['Business Summary']

        # Store stock description in Pinecone
        vectorstore_from_texts = PineconeVectorStore.from_documents(
            documents=[Document(page_content=stock_description, metadata=stock_data)],
            embedding=hf_embeddings,
            index_name=index_name,
            namespace=namespace
        )

        # Track success
        with open('successful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        successful_tickers.append(stock_ticker)

        return f"Processed {stock_ticker} successfully"

    except Exception as e:
        # Track failure
        with open('unsuccessful_tickers.txt', 'a') as f:
            f.write(f"{stock_ticker}\n")
        unsuccessful_tickers.append(stock_ticker)

        return f"ERROR processing {stock_ticker}: {e}"

def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
    with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_ticker = {
            executor.submit(process_stock, ticker): ticker
            for ticker in tickers
        }

        for future in concurrent.futures.as_completed(future_to_ticker):
            ticker = future_to_ticker[future]
            try:
                result = future.result()
                print(result)

                # Stop on error
                if result.startswith("ERROR"):
                    print(f"Stopping program due to error in {ticker}")
                    executor.shutdown(wait=False)
                    raise SystemExit(1)

            except Exception as exc:
                print(f'{ticker} generated an exception: {exc}')
                print("Stopping program due to exception")
                executor.shutdown(wait=False)
                raise SystemExit(1)

# Prepare your tickers
tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# Process them
parallel_process_stocks(tickers_to_process, max_workers=10)
# Out:
# Already processed CMCSA
# Already processed RCL
# Already processed RELX
# Already processed KLAC
# Already processed GS
# Already processed TEAM
# Already processed ABNB
# Already processed GM
# Already processed REGN
# Already processed ANZGY
# Already processed WELL
# Already processed TOELY
# Already processed APH
# Already processed MCO
# Already processed OKE
# Already processed PYPL
# Already processed ADSK
# Already processed HES
# Already processed BN
# Already processed AJG
# Already processed DFS
# Already processed MDLZ
# Already processed STZ
# Already processed RSG
# Already processed DUK
# Already processed HCA
# Already processed BDX
# Already processed CTAS
# Already processed EQNR
# Already processed EQIX
# Already processed ISRG
# Already processed GBTC
# Already processed DEO
# Already processed VRT
# Already processed PBR
# Already processed ING
# Already processed CARR
# Already processed WM
# Already processed CI
# Already processed CMI
# Already processed CVS
# Already processed WCN
# Already processed ICE
# Already processed BAESY
# Already processed CRH
# Already processed PH
# Already processed BCS
# Already processed MPC
# Already processed HDB
# Already processed BNS
# Already processed INFY
# Already processed RTX
# Already processed BMWKY
# Already processed TRP
# Already processed NU
# Already processed LRCX
# Already processed CCI
# Already processed SMFG
# Already processed SU
# Already processed EPD
# Already processed HSBC
# Already processed CAT
# Already processed AMT
# Already processed AEP
# Already processed SPG
# Already processed TT
# Already processed SQ
# Already processed CSX
# Already processed APO
# Already processed D
# Already processed CTA-PA
# Already processed WMB
# Already processed GEV
# Already processed DHR
# Already processed DELL
# Already processed MNST
# Already processed BMO
# Already processed MPLX
# Already processed KMB
# Already processed LOW
# Already processed ENB
# Already processed CODYY
# Already processed PAYX
# Already processed WDAY
# Already processed SPOT
# Already processed VST
# Already processed FANG
# Already processed GSK
# Already processed TXN
# Already processed ELV
# Already processed ALL
# Already processed CNI
# Already processed MELI
# Already processed MO
# Already processed ARES
# Already processed ECL
# Already processed FIS
# Already processed APP
# Already processed DHI
# Already processed CP
# Already processed BKNG
# Already processed NDAQ
# Already processed SHW
# Already processed PDD
# Already processed AIG
# Already processed AZO
# Already processed CEG
# Already processed RY
# Already processed SO
# Already processed BRK-B
# Already processed PSX
# Already processed ORLY
# Already processed AIQUY
# Already processed LNG
# Already processed TD
# Already processed PTCAY
# Already processed TDG
# Already processed RIO
# Already processed FLUT
# Already processed CPRT
# Already processed COF
# Already processed UBS
# Already processed PCG
# Already processed APD
# Already processed PRU
# Already processed ADI
# Already processed IAU
# Already processed UBER
# Already processed AMP
# Already processed TGT
# Already processed IBN
# Already processed TSLA
# Already processed BA
# Already processed NTES
# Already processed CNQ
# Already processed COR
# Already processed EA
# Already processed PLD
# Already processed URI
# Already processed DASH
# Already processed INTC
# Already processed FAST
# Already processed FICO
# Already processed MSTR
# Already processed MU
# Already processed CHTR
# Already processed MMM
# Already processed MMC
# Already processed LEN
# Already processed OXY
# Already processed WMT
# Already processed DE
# Already processed ITUB
# Already processed SHECY
# Already processed BUD
# Already processed NXPI
# Already processed FDX
# Already processed GILD
# Already processed JCI
# Already processed NOC
# Already processed MDT
# Already processed QCOM
# Already processed BBVA
# Already processed FTNT
# Already processed SONY
# Already processed SBUX
# Already processed BK
# Already processed EMR
# Already processed HWM
# Already processed O
# Already processed UPS
# Already processed GWW
# Already processed TRI
# Already processed T
# Already processed BMY
# Already processed PWR
# Already processed MFC
# Already processed SAN
# Already processed NKE
# Already processed MET
# Already processed COIN
# Already processed EADSY
# Already processed VZ
# Already processed CB
# Already processed SRE
# Already processed EOG
# Already processed ANET
# Already processed VLO
# Already processed SE
# Already processed IBKR
# Already processed VRTX
# Already processed JD
# Already processed BP
# Already processed AXON
# Already processed FI
# Already processed GLNCY
# Already processed MRVL
# Already processed RTNTF
# Already processed ADP
# Already processed TTD
# Already processed CL
# Already processed SNY
# Already processed PSA
# Already processed MCK
# Already processed LMT
# Already processed PCAR
# Already processed MAR
# Already processed PANW
# Already processed ROP
# Already processed RACE
# Already processed BSX
# Already processed KVUE
# Already processed COP
# Already processed USB
# Already processed C
# Already processed ET
# Already processed SCCO
# Already processed BHP
# Already processed CPNG
# Already processed ZTS
# Already processed ARM
# Already processed GD
# Already processed TJX
# Already processed MUFG
# Already processed CM
# Already processed CDNS
# Already processed ODFL
# Already processed KKR
# Already processed BTI
# Already processed TTE
# Already processed HLT
# Already processed ITW
# Already processed SHOP
# Already processed KDP
# Already processed DLR
# Already processed CFRUY
# Already processed AMAT
# Already processed FMX
# Already processed PFE
# Already processed CMG
# Already processed ETN
# Already processed NGG
# Already processed SNPS
# Already processed NEM
# Already processed UL
# Already processed FCX
# Already processed CME
# Already processed UNP
# Already processed MFG
# Already processed AON
# Already processed PLTR
# Already processed AMX
# Already processed SCHW
# Already processed TFC
# Already processed MSI
# Already processed SYK
# Already processed GLD
# Already processed CRWD
# Already processed HON
# Already processed AFL
# Already processed PNC
# Already processed SPGI
# Already processed NEE
# Already processed CRARY
# Already processed TMO
# Already processed AME
# Already processed TAK
# Already processed UNH
# Already processed BAC
# Already processed NFLX
# Already processed ABT
# Already processed AVGO
# Already processed JPM
# Already processed TSM
# Already processed CRM
# Already processed ABBV
# Already processed RCIT
# Already processed PGR
# Already processed SPY
# Already processed LHX
# Already processed INTU
# Already processed PM
# Already processed GOOGL
# Already processed AMGN
# Already processed MSFT
# Already processed META
# Already processed TM
# Already processed BX
# Already processed XOM
# Already processed WFC
# Already processed NOW
# Already processed PEP
# Already processed IBM
# Already processed NVS
# Already processed LIN
# Already processed AMD
# Already processed QQQ
# Already processed ADBE
# Already processed MRK
# Already processed CSCO
# Already processed MSCI
# Already processed ASML
# Already processed CAIXY
# Already processed SAP
# Already processed DIS
# Already processed KO
# Already processed ACN
# Already processed AXP
# Already processed AMZN
# Already processed DDOG
# Already processed PG
# Already processed NVO
# Already processed F
# Already processed HD
# Already processed BLK
# Already processed BABA
# Already processed MS
# Already processed COST
# Already processed GE
# Already processed CVX
# Already processed MCD
# Already processed V
# Already processed PEG
# Already processed TEL
# Already processed JNJ
# Already processed AZN
# Already processed SHEL
# Already processed AAPL
# Already processed NVDA
# Already processed ROST
# Already processed ORCL
# Already processed MA
# Already processed LYG
# Already processed TMUS
# Already processed E
# Already processed LLY
# Processed MBGYY successfully
# Processed VALE successfully
# Processed NSC successfully
# Already processed KR
# Already processed SNOW
# Already processed NWG
# Processed HLN successfully
# Processed TRGP successfully
# Already processed SVNDY
# Processed TRV successfully
# Processed DNZOY successfully
# Processed KMI successfully
# Processed SLB successfully
# Processed ALC successfully
# Processed ATEYY successfully
# Processed IT successfully
# Processed DAL successfully
# Processed BKR successfully
# Processed FERG successfully
# Processed HMC successfully
# Processed IR successfully
# Already processed EXC
# Processed XEL successfully
# Processed GRMN successfully
# Processed GLW successfully
# Processed OTIS successfully
# Already processed STLA
# Processed CBRE successfully
# Processed LULU successfully
# Processed VRSK successfully
# Processed EW successfully
# Processed AEM successfully
# Processed OLCLY successfully
# Processed TCOM successfully
# Processed IMO successfully
# Processed YUM successfully
# Processed CTVA successfully
# Processed CTSH successfully
# Processed KHC successfully
# Processed ACGL successfully
# Processed WTKWY successfully
# Already processed DIA
# Processed PPERY successfully
# Processed VMC successfully
# Processed SYY successfully
# Processed EXR successfully
# Processed MLM successfully
# Processed GEHC successfully
# Processed MTB successfully
# Processed A successfully
# Processed HPQ successfully
# Processed LVS successfully
# Processed WIT successfully
# Processed CCEP successfully
# Processed IQV successfully
# Processed HSY successfully
# Processed DKILY successfully
# Processed HUBS successfully
# Processed GIS successfully
# Processed SLF successfully
# Processed VEEV successfully
# Already processed IRM
# Processed ABEV successfully
# Processed NUE successfully
# Processed RBLX successfully
# Processed IDXX successfully
# Processed RMD successfully
# Processed HIG successfully
# Processed ARGX successfully
# Processed OWL successfully
# Processed DD successfully
# Processed MCHP successfully
# Processed BSBR successfully
# Already processed MDY
# Processed WAB successfully
# Processed ED successfully
# Processed AVB successfully
# Processed VICI successfully
# Processed HUM successfully
# Processed CCL successfully
# Processed DB successfully
# Processed EIX successfully
# Processed ROK successfully
# Processed RJF successfully
# Processed ETR successfully
# Processed HEI successfully
# Processed GWLIF successfully
# Processed ANYYY successfully
# Processed BRO successfully
# Processed MRAAY successfully
# Processed FRFHF successfully
# Processed FITB successfully
# Processed WTW successfully
# Processed TTWO successfully
# Processed TPL successfully
# Processed FCNCA successfully
# Processed EFX successfully
# Processed DOW successfully
# Processed UAL successfully
# Processed WEC successfully
# Processed QSR successfully
# Processed ALNY successfully
# Processed DXCM successfully
# Processed ZS successfully
# Processed NET successfully
# Processed CHT successfully
# Processed BIDU successfully
# Processed EBAY successfully
# Processed GPN successfully
# Processed GOLD successfully
# Processed LYV successfully
# Processed TSCO successfully
# Processed WDS successfully
# Processed XYL successfully
# Processed DSCSY successfully
# Processed CSGP successfully
# Processed EQR successfully
# Processed CNC successfully
# Processed ANSS successfully
# Processed PPRUY successfully
# Processed CVNA successfully
# Processed CVE successfully
# Processed CAH successfully
# Processed CUK successfully
# Processed TW successfully
# Processed FER successfully
# Processed HOOD successfully
# Processed PPG successfully
# Processed STT successfully
# Processed NVR successfully
# Processed K successfully
# Processed OEZVY successfully
# Processed ON successfully
# Processed MPWR successfully
# Processed WPM successfully
# Processed IOT successfully
# Processed DOV successfully
# Processed RKT successfully
# Processed LYB successfully
# Processed VTR successfully
# Processed HPE successfully
# Processed ERIC successfully
# Processed NVZMY successfully
# Processed DECK successfully
# Processed SW successfully
# Processed PHM successfully
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-fdec19a42429> in parallel_process_stocks(tickers, max_workers)
#      40
# ---> 41         for future in concurrent.futures.as_completed(future_to_ticker):
#      42             ticker = future_to_ticker[future]
#
# /usr/lib/python3.10/concurrent/futures/_base.py in as_completed(fs, timeout)
#     244
# --> 245             waiter.event.wait(wait_timeout)
#     246
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     606             if not signaled:
# --> 607                 signaled = self._cond.wait(timeout)
#     608             return signaled
#
# /usr/lib/python3.10/threading.py in wait(self, timeout)
#     319             if timeout is None:
# --> 320                 waiter.acquire()
#     321                 gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-fdec19a42429> in <cell line: 63>()
#      61
#      62 # Process them
# ---> 63 parallel_process_stocks(tickers_to_process, max_workers=10)
#
# <ipython-input-20-fdec19a42429> in parallel_process_stocks(tickers, max_workers)
#      33
#      34 def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
# ---> 35     with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
#      36         future_to_ticker = {
#      37             executor.submit(process_stock, ticker): ticker
#
# /usr/lib/python3.10/concurrent/futures/_base.py in __exit__(self, exc_type, exc_val, exc_tb)
#     647
#     648     def __exit__(self, exc_type, exc_val, exc_tb):
# --> 649         self.shutdown(wait=True)
#     650         return False
#     651
#
# /usr/lib/python3.10/concurrent/futures/thread.py in shutdown(self, wait, cancel_futures)
#     233         if wait:
#     234             for t in self._threads:
# --> 235                 t.join()
#     236     shutdown.__doc__ = _base.Executor.shutdown.__doc__
#
# /usr/lib/python3.10/threading.py in join(self, timeout)
#    1094
#    1095         if timeout is None:
# -> 1096             self._wait_for_tstate_lock()
#    1097         else:
#    1098             # the behavior of a negative timeout isn't documented, but
#
# /usr/lib/python3.10/threading.py in _wait_for_tstate_lock(self, block, timeout)
#    1114
#    1115         try:
# -> 1116             if lock.acquire(block, timeout):
#    1117                 lock.release()
#    1118                 self._stop()
#
# KeyboardInterrupt:

# %%
# def process_stock(stock_ticker: str) -> str:
#     # Skip if already processed
#     if stock_ticker in successful_tickers:
#         return f"Already processed {stock_ticker}"

#     try:
#         # Get stock data using the provided ticker symbol
#         stock_data = get_stock_info(stock_ticker)

#         # Extract the business summary from the stock data
#         stock_description = stock_data['Business Summary']

#         # Store the stock description in the Pinecone vector store
#         vectorstore_from_texts = PineconeVectorStore.from_documents(
#             documents=[Document(page_content=stock_description, metadata=stock_data)],  # Document with content and metadata
#             embedding=hf_embeddings,  # Hugging Face embeddings for vector representation
#             index_name=index_name,  # Name of the Pinecone index
#             namespace=namespace  # Namespace to logically organize vectors
#         )

#         # Log successful processing of the ticker
#         with open('successful_tickers.txt', 'a') as f:
#             f.write(f"{stock_ticker}\n")  # Append ticker to success log
#         successful_tickers.append(stock_ticker)  # Track success in the list

#         return f"Processed {stock_ticker} successfully"

#     except Exception as e:
#         # Log failure to process the ticker
#         with open('unsuccessful_tickers.txt', 'a') as f:
#             f.write(f"{stock_ticker}\n")  # Append ticker to failure log
#         unsuccessful_tickers.append(stock_ticker)  # Track failure in the list

#         return f"ERROR processing {stock_ticker}: {e}"

# def parallel_process_stocks(tickers: list, max_workers: int = 10) -> None:
#     # Create a ThreadPoolExecutor to process stock tickers in parallel
#     with concurrent.futures.ThreadPoolExecutor(max_workers=max_workers) as executor:
#         # Map each ticker to a future task for processing
#         future_to_ticker = {
#             executor.submit(process_stock, ticker): ticker  # Submit `process_stock` for each ticker
#             for ticker in tickers
#         }

#         # Iterate over completed futures as they finish
#         for future in concurrent.futures.as_completed(future_to_ticker):
#             ticker = future_to_ticker[future]  # Get the ticker corresponding to the future
#             try:
#                 # Retrieve the result of the future
#                 result = future.result()
#                 print(result)  # Print the result of processing

#                 # Stop execution if an error occurred
#                 if result.startswith("ERROR"):
#                     print(f"Stopping program due to error in {ticker}")
#                     executor.shutdown(wait=False)  # Shut down the executor early
#                     raise SystemExit(1)  # Exit the program with an error status

#             except Exception as exc:
#                 # Handle unexpected exceptions in processing
#                 print(f'{ticker} generated an exception: {exc}')
#                 print("Stopping program due to exception")
#                 executor.shutdown(wait=False)  # Shut down the executor early
#                 raise SystemExit(1)  # Exit the program with an error status

# # Prepare a list of tickers to process
# tickers_to_process = [company_tickers[num]['ticker'] for num in company_tickers.keys()]

# # Process the tickers in parallel with a specified maximum number of workers
# parallel_process_stocks(tickers_to_process, max_workers=10)

# %% [markdown]
# # Perform RAG

# %%
# Initialize Pinecone
pc = Pinecone(api_key=userdata.get("PINECONE_API_KEY"),)

# Connect to your Pinecone index
pinecone_index = pc.Index("stocks")

# %%
query = "What are some companies are involved with building data centers?"

# %%
raw_query_embedding = get_huggingface_embeddings(query)

# %%
top_matches = pinecone_index.query(vector=raw_query_embedding.tolist(), top_k=20, include_metadata=True, namespace="stock-descriptions")

# %%
top_matches
# Out:
# {'matches': [{'id': '05ec8f4a-899c-4898-b4bf-99cab908c2ec',
#               'metadata': {'Business Summary': 'GDS Holdings Limited, together '
#                                                'with its subsidiaries, '
#                                                'develops and operates data '
#                                                "centers in the People's "
#                                                'Republic of China. The company '
#                                                'offers colocation services '
#                                                'comprising critical facilities '
#                                                'space, customer-available '
#                                                'power, racks, and cooling; '
#                                                'managed hosting services, '
#                                                'including business continuity '
#                                                'and disaster recovery, network '
#                                                'management, data storage, '
#                                                'system security, operating '
#                                                'system, database, and server '
#                                                'middleware services; managed '
#                                                'cloud services; and consulting '
#                                                'services. It serves cloud '
#                                                'service providers, large '
#                                                'Internet companies, financial '
#                                                'institutions, '
#                                                'telecommunications and IT '
#                                                'service providers, and large '
#                                                'domestic private sector and '
#                                                'multinational corporations. '
#                                                'The company was founded in '
#                                                '2001 and is headquartered in '
#                                                "Shanghai, the People's "
#                                                'Republic of China.',
#                            'City': 'Shanghai',
#                            'Country': 'China',
#                            'Industry': 'Information Technology Services',
#                            'Name': 'GDS Holdings Limited',
#                            'Sector': 'Technology',
#                            'State': 'Information not available',
#                            'Ticker': 'GDS',
#                            'text': 'GDS Holdings Limited, together with its '
#                                    'subsidiaries, develops and operates data '
#                                    "centers in the People's Republic of China. "
#                                    'The company offers colocation services '
#                                    'comprising critical facilities space, '
#                                    'customer-available power, racks, and '
#                                    'cooling; managed hosting services, '
#                                    'including business continuity and disaster '
#                                    'recovery, network management, data '
#                                    'storage, system security, operating '
#                                    'system, database, and server middleware '
#                                    'services; managed cloud services; and '
#                                    'consulting services. It serves cloud '
#                                    'service providers, large Internet '
#                                    'companies, financial institutions, '
#                                    'telecommunications and IT service '
#                                    'providers, and large domestic private '
#                                    'sector and multinational corporations. The '
#                                    'company was founded in 2001 and is '
#                                    "headquartered in Shanghai, the People's "
#                                    'Republic of China.'},
#               'score': 0.546473622,
#               'values': []},
#              {'id': 'dbf6246f-2e27-4c01-8c8a-23ca0731c66a',
#               'metadata': {'Business Summary': 'GDS Holdings Limited, together '
#                                                'with its subsidiaries, '
#                                                'develops and operates data '
#                                                "centers in the People's "
#                                                'Republic of China. The company '
#                                                'offers colocation services '
#                                                'comprising critical facilities '
#                                                'space, customer-available '
#                                                'power, racks, and cooling; '
#                                                'managed hosting services, '
#                                                'including business continuity '
#                                                'and disaster recovery, network '
#                                                'management, data storage, '
#                                                'system security, operating '
#                                                'system, database, and server '
#                                                'middleware services; managed '
#                                                'cloud services; and consulting '
#                                                'services. It serves cloud '
#                                                'service providers, large '
#                                                'Internet companies, financial '
#                                                'institutions, '
#                                                'telecommunications and IT '
#                                                'service providers, and large '
#                                                'domestic private sector and '
#                                                'multinational corporations. '
#                                                'The company was founded in '
#                                                '2001 and is headquartered in '
#                                                "Shanghai, the People's "
#                                                'Republic of China.',
#                            'City': 'Shanghai',
#                            'Country': 'China',
#                            'Industry': 'Information Technology Services',
#                            'Name': 'GDS Holdings Limited',
#                            'Sector': 'Technology',
#                            'State': 'Information not available',
#                            'Ticker': 'GDS',
#                            'text': 'GDS Holdings Limited, together with its '
#                                    'subsidiaries, develops and operates data '
#                                    "centers in the People's Republic of China. "
#                                    'The company offers colocation services '
#                                    'comprising critical facilities space, '
#                                    'customer-available power, racks, and '
#                                    'cooling; managed hosting services, '
#                                    'including business continuity and disaster '
#                                    'recovery, network management, data '
#                                    'storage, system security, operating '
#                                    'system, database, and server middleware '
#                                    'services; managed cloud services; and '
#                                    'consulting services. It serves cloud '
#                                    'service providers, large Internet '
#                                    'companies, financial institutions, '
#                                    'telecommunications and IT service '
#                                    'providers, and large domestic private '
#                                    'sector and multinational corporations. The '
#                                    'company was founded in 2001 and is '
#                                    "headquartered in Shanghai, the People's "
#                                    'Republic of China.'},
#               'score': 0.546473622,
#               'values': []},
#              {'id': '26141769-77b8-4947-b0d0-bd592df7cc98',
#               'metadata': {'Business Summary': 'Iris Energy Limited owns and '
#                                                'operates bitcoin mining data '
#                                                'centers. It also provides high '
#                                                'performance computing  '
#                                                'solutions, including Al cloud '
#                                                'services. The company was '
#                                                'incorporated in 2018 and is '
#                                                'headquartered in Sydney, '
#                                                'Australia.',
#                            'City': 'Sydney',
#                            'Country': 'Australia',
#                            'Industry': 'Capital Markets',
#                            'Name': 'IREN Limited',
#                            'Sector': 'Financial Services',
#                            'State': 'NSW',
#                            'Ticker': 'IREN',
#                            'text': 'Iris Energy Limited owns and operates '
#                                    'bitcoin mining data centers. It also '
#                                    'provides high performance computing  '
#                                    'solutions, including Al cloud services. '
#                                    'The company was incorporated in 2018 and '
#                                    'is headquartered in Sydney, Australia.'},
#               'score': 0.51131469,
#               'values': []},
#              {'id': '01a6dfb2-35f6-4dfe-935b-e3de2c949df6',
#               'metadata': {'Business Summary': 'Iris Energy Limited owns and '
#                                                'operates bitcoin mining data '
#                                                'centers. It also provides high '
#                                                'performance computing  '
#                                                'solutions, including Al cloud '
#                                                'services. The company was '
#                                                'incorporated in 2018 and is '
#                                                'headquartered in Sydney, '
#                                                'Australia.',
#                            'City': 'Sydney',
#                            'Country': 'Australia',
#                            'Industry': 'Capital Markets',
#                            'Name': 'IREN Limited',
#                            'Sector': 'Financial Services',
#                            'State': 'NSW',
#                            'Ticker': 'IREN',
#                            'text': 'Iris Energy Limited owns and operates '
#                                    'bitcoin mining data centers. It also '
#                                    'provides high performance computing  '
#                                    'solutions, including Al cloud services. '
#                                    'The company was incorporated in 2018 and '
#                                    'is headquartered in Sydney, Australia.'},
#               'score': 0.51131469,
#               'values': []},
#              {'id': '471c36a7-586d-4e74-9654-f7ddc55b9993',
#               'metadata': {'Business Summary': 'Hewlett Packard Enterprise '
#                                                'Company provides solutions '
#                                                'that allow customers to '
#                                                'capture, analyze, and act upon '
#                                                'data seamlessly in the '
#                                                'Americas, Europe, the Middle '
#                                                'East, Africa, the Asia '
#                                                'Pacific, and Japan. It '
#                                                'operates in six segments: '
#                                                'Compute, HPC & AI, Storage, '
#                                                'Intelligent Edge, Financial '
#                                                'Services, and Corporate '
#                                                'Investments and Other. The '
#                                                'company offers general purpose '
#                                                'servers for multi-workload '
#                                                'computing and '
#                                                'workload-optimized servers; '
#                                                'HPE ProLiant rack and tower '
#                                                'servers; HPE Synergy; HPE '
#                                                'Alletra, HPE GreenLake, Zerto, '
#                                                'HPE InfoSight, and HPE '
#                                                'CloudPhysics storage products; '
#                                                'HPE Cray EX, HPE Cray XD, and '
#                                                'converged edge systems; and '
#                                                'HPE Superdome Flex, HPE '
#                                                'Nonstop, and HPE Integrity '
#                                                'products. It also provides HPE '
#                                                'Aruba products that includes '
#                                                'hardware products, such as '
#                                                'Wi-Fi access points, switches, '
#                                                'and gateways; HPE Aruba '
#                                                'Networking software and '
#                                                'services comprising '
#                                                'cloud-based management, '
#                                                'network management and access '
#                                                'control, analytics and '
#                                                'assurance, software-defined '
#                                                'wide-area networking, network '
#                                                'security, analytics and '
#                                                'assurance, and location '
#                                                'services software; and '
#                                                'professional and support '
#                                                'services, as well as '
#                                                'as-a-service and consumption '
#                                                'models. In addition, the '
#                                                'company offers leasing, '
#                                                'financing, IT consumption, and '
#                                                'utility programs and asset '
#                                                'management services for '
#                                                'customers to facilitate '
#                                                'technology deployment models '
#                                                'and the acquisition of various '
#                                                'IT solutions, including '
#                                                'hardware, software, and '
#                                                'services from Hewlett Packard '
#                                                'Enterprise and others; '
#                                                'consultative-led services; HPE '
#                                                'Ezmeral Container Platform; '
#                                                'HPE Ezmeral Software Container '
#                                                'Platform and HPE Ezmeral '
#                                                'Software Data Fabric; OpsRamp; '
#                                                'and Hewlett Packard Labs. It '
#                                                'serves commercial and large '
#                                                'enterprise groups, such as '
#                                                'business and public sector '
#                                                'enterprises; and through '
#                                                'various partners comprising '
#                                                'resellers, distribution '
#                                                'partners, original equipment '
#                                                'manufacturers, independent '
#                                                'software vendors, systems '
#                                                'integrators, and advisory '
#                                                'firms. The company was founded '
#                                                'in 1939 and is headquartered '
#                                                'in Spring, Texas.',
#                            'City': 'Spring',
#                            'Country': 'United States',
#                            'Industry': 'Communication Equipment',
#                            'Name': 'Hewlett Packard Enterprise Company',
#                            'Sector': 'Technology',
#                            'State': 'TX',
#                            'Ticker': 'HPE',
#                            'text': 'Hewlett Packard Enterprise Company '
#                                    'provides solutions that allow customers to '
#                                    'capture, analyze, and act upon data '
#                                    'seamlessly in the Americas, Europe, the '
#                                    'Middle East, Africa, the Asia Pacific, and '
#                                    'Japan. It operates in six segments: '
#                                    'Compute, HPC & AI, Storage, Intelligent '
#                                    'Edge, Financial Services, and Corporate '
#                                    'Investments and Other. The company offers '
#                                    'general purpose servers for multi-workload '
#                                    'computing and workload-optimized servers; '
#                                    'HPE ProLiant rack and tower servers; HPE '
#                                    'Synergy; HPE Alletra, HPE GreenLake, '
#                                    'Zerto, HPE InfoSight, and HPE CloudPhysics '
#                                    'storage products; HPE Cray EX, HPE Cray '
#                                    'XD, and converged edge systems; and HPE '
#                                    'Superdome Flex, HPE Nonstop, and HPE '
#                                    'Integrity products. It also provides HPE '
#                                    'Aruba products that includes hardware '
#                                    'products, such as Wi-Fi access points, '
#                                    'switches, and gateways; HPE Aruba '
#                                    'Networking software and services '
#                                    'comprising cloud-based management, network '
#                                    'management and access control, analytics '
#                                    'and assurance, software-defined wide-area '
#                                    'networking, network security, analytics '
#                                    'and assurance, and location services '
#                                    'software; and professional and support '
#                                    'services, as well as as-a-service and '
#                                    'consumption models. In addition, the '
#                                    'company offers leasing, financing, IT '
#                                    'consumption, and utility programs and '
#                                    'asset management services for customers to '
#                                    'facilitate technology deployment models '
#                                    'and the acquisition of various IT '
#                                    'solutions, including hardware, software, '
#                                    'and services from Hewlett Packard '
#                                    'Enterprise and others; consultative-led '
#                                    'services; HPE Ezmeral Container Platform; '
#                                    'HPE Ezmeral Software Container Platform '
#                                    'and HPE Ezmeral Software Data Fabric; '
#                                    'OpsRamp; and Hewlett Packard Labs. It '
#                                    'serves commercial and large enterprise '
#                                    'groups, such as business and public sector '
#                                    'enterprises; and through various partners '
#                                    'comprising resellers, distribution '
#                                    'partners, original equipment '
#                                    'manufacturers, independent software '
#                                    'vendors, systems integrators, and advisory '
#                                    'firms. The company was founded in 1939 and '
#                                    'is headquartered in Spring, Texas.'},
#               'score': 0.490928888,
#               'values': []},
#              {'id': 'c873795b-bade-4c0e-8a79-81ffdb678150',
#               'metadata': {'Business Summary': 'Hewlett Packard Enterprise '
#                                                'Company provides solutions '
#                                                'that allow customers to '
#                                                'capture, analyze, and act upon '
#                                                'data seamlessly in the '
#                                                'Americas, Europe, the Middle '
#                                                'East, Africa, the Asia '
#                                                'Pacific, and Japan. It '
#                                                'operates in six segments: '
#                                                'Compute, HPC & AI, Storage, '
#                                                'Intelligent Edge, Financial '
#                                                'Services, and Corporate '
#                                                'Investments and Other. The '
#                                                'company offers general purpose '
#                                                'servers for multi-workload '
#                                                'computing and '
#                                                'workload-optimized servers; '
#                                                'HPE ProLiant rack and tower '
#                                                'servers; HPE Synergy; HPE '
#                                                'Alletra, HPE GreenLake, Zerto, '
#                                                'HPE InfoSight, and HPE '
#                                                'CloudPhysics storage products; '
#                                                'HPE Cray EX, HPE Cray XD, and '
#                                                'converged edge systems; and '
#                                                'HPE Superdome Flex, HPE '
#                                                'Nonstop, and HPE Integrity '
#                                                'products. It also provides HPE '
#                                                'Aruba products that includes '
#                                                'hardware products, such as '
#                                                'Wi-Fi access points, switches, '
#                                                'and gateways; HPE Aruba '
#                                                'Networking software and '
#                                                'services comprising '
#                                                'cloud-based management, '
#                                                'network management and access '
#                                                'control, analytics and '
#                                                'assurance, software-defined '
#                                                'wide-area networking, network '
#                                                'security, analytics and '
#                                                'assurance, and location '
#                                                'services software; and '
#                                                'professional and support '
#                                                'services, as well as '
#                                                'as-a-service and consumption '
#                                                'models. In addition, the '
#                                                'company offers leasing, '
#                                                'financing, IT consumption, and '
#                                                'utility programs and asset '
#                                                'management services for '
#                                                'customers to facilitate '
#                                                'technology deployment models '
#                                                'and the acquisition of various '
#                                                'IT solutions, including '
#                                                'hardware, software, and '
#                                                'services from Hewlett Packard '
#                                                'Enterprise and others; '
#                                                'consultative-led services; HPE '
#                                                'Ezmeral Container Platform; '
#                                                'HPE Ezmeral Software Container '
#                                                'Platform and HPE Ezmeral '
#                                                'Software Data Fabric; OpsRamp; '
#                                                'and Hewlett Packard Labs. It '
#                                                'serves commercial and large '
#                                                'enterprise groups, such as '
#                                                'business and public sector '
#                                                'enterprises; and through '
#                                                'various partners comprising '
#                                                'resellers, distribution '
#                                                'partners, original equipment '
#                                                'manufacturers, independent '
#                                                'software vendors, systems '
#                                                'integrators, and advisory '
#                                                'firms. The company was founded '
#                                                'in 1939 and is headquartered '
#                                                'in Spring, Texas.',
#                            'City': 'Spring',
#                            'Country': 'United States',
#                            'Industry': 'Communication Equipment',
#                            'Name': 'Hewlett Packard Enterprise Company',
#                            'Sector': 'Technology',
#                            'State': 'TX',
#                            'Ticker': 'HPE',
#                            'text': 'Hewlett Packard Enterprise Company '
#                                    'provides solutions that allow customers to '
#                                    'capture, analyze, and act upon data '
#                                    'seamlessly in the Americas, Europe, the '
#                                    'Middle East, Africa, the Asia Pacific, and '
#                                    'Japan. It operates in six segments: '
#                                    'Compute, HPC & AI, Storage, Intelligent '
#                                    'Edge, Financial Services, and Corporate '
#                                    'Investments and Other. The company offers '
#                                    'general purpose servers for multi-workload '
#                                    'computing and workload-optimized servers; '
#                                    'HPE ProLiant rack and tower servers; HPE '
#                                    'Synergy; HPE Alletra, HPE GreenLake, '
#                                    'Zerto, HPE InfoSight, and HPE CloudPhysics '
#                                    'storage products; HPE Cray EX, HPE Cray '
#                                    'XD, and converged edge systems; and HPE '
#                                    'Superdome Flex, HPE Nonstop, and HPE '
#                                    'Integrity products. It also provides HPE '
#                                    'Aruba products that includes hardware '
#                                    'products, such as Wi-Fi access points, '
#                                    'switches, and gateways; HPE Aruba '
#                                    'Networking software and services '
#                                    'comprising cloud-based management, network '
#                                    'management and access control, analytics '
#                                    'and assurance, software-defined wide-area '
#                                    'networking, network security, analytics '
#                                    'and assurance, and location services '
#                                    'software; and professional and support '
#                                    'services, as well as as-a-service and '
#                                    'consumption models. In addition, the '
#                                    'company offers leasing, financing, IT '
#                                    'consumption, and utility programs and '
#                                    'asset management services for customers to '
#                                    'facilitate technology deployment models '
#                                    'and the acquisition of various IT '
#                                    'solutions, including hardware, software, '
#                                    'and services from Hewlett Packard '
#                                    'Enterprise and others; consultative-led '
#                                    'services; HPE Ezmeral Container Platform; '
#                                    'HPE Ezmeral Software Container Platform '
#                                    'and HPE Ezmeral Software Data Fabric; '
#                                    'OpsRamp; and Hewlett Packard Labs. It '
#                                    'serves commercial and large enterprise '
#                                    'groups, such as business and public sector '
#                                    'enterprises; and through various partners '
#                                    'comprising resellers, distribution '
#                                    'partners, original equipment '
#                                    'manufacturers, independent software '
#                                    'vendors, systems integrators, and advisory '
#                                    'firms. The company was founded in 1939 and '
#                                    'is headquartered in Spring, Texas.'},
#               'score': 0.490928888,
#               'values': []},
#              {'id': '3476089e-75bc-4f88-85d0-5f12268feecc',
#               'metadata': {'Business Summary': 'Teradata Corporation, together '
#                                                'with its subsidiaries, '
#                                                'provides a connected '
#                                                'multi-cloud data platform for '
#                                                'enterprise analytics. The '
#                                                'company offers Teradata '
#                                                'Vantage, an open and connected '
#                                                'platform designed to leverage '
#                                                'data across an enterprise. Its '
#                                                'business consulting services '
#                                                'include support services for '
#                                                'organizations to establish a '
#                                                'data and analytic vision, '
#                                                'enable a multi-cloud ecosystem '
#                                                'architecture, and identify and '
#                                                'operationalize analytical '
#                                                'opportunities, as well as to '
#                                                'ensure the analytical '
#                                                'infrastructure delivers value. '
#                                                'The company offers support and '
#                                                'maintenance services. It '
#                                                'serves clients in financial '
#                                                'services, government, '
#                                                'healthcare and life sciences, '
#                                                'manufacturing, retail, '
#                                                'telecommunications, and '
#                                                'travel/transportation sectors '
#                                                'through a direct sales force '
#                                                'in the Americas, Europe, the '
#                                                'Middle East, Africa, the Asia '
#                                                'Pacific, and Japan. Teradata '
#                                                'Corporation was incorporated '
#                                                'in 1979 and is headquartered '
#                                                'in San Diego, California.',
#                            'City': 'San Diego',
#                            'Country': 'United States',
#                            'Industry': 'Software - Infrastructure',
#                            'Name': 'Teradata Corporation',
#                            'Sector': 'Technology',
#                            'State': 'CA',
#                            'Ticker': 'TDC',
#                            'text': 'Teradata Corporation, together with its '
#                                    'subsidiaries, provides a connected '
#                                    'multi-cloud data platform for enterprise '
#                                    'analytics. The company offers Teradata '
#                                    'Vantage, an open and connected platform '
#                                    'designed to leverage data across an '
#                                    'enterprise. Its business consulting '
#                                    'services include support services for '
#                                    'organizations to establish a data and '
#                                    'analytic vision, enable a multi-cloud '
#                                    'ecosystem architecture, and identify and '
#                                    'operationalize analytical opportunities, '
#                                    'as well as to ensure the analytical '
#                                    'infrastructure delivers value. The company '
#                                    'offers support and maintenance services. '
#                                    'It serves clients in financial services, '
#                                    'government, healthcare and life sciences, '
#                                    'manufacturing, retail, telecommunications, '
#                                    'and travel/transportation sectors through '
#                                    'a direct sales force in the Americas, '
#                                    'Europe, the Middle East, Africa, the Asia '
#                                    'Pacific, and Japan. Teradata Corporation '
#                                    'was incorporated in 1979 and is '
#                                    'headquartered in San Diego, California.'},
#               'score': 0.471572548,
#               'values': []},
#              {'id': 'f1c839f5-8364-4085-b36b-d85543d864ee',
#               'metadata': {'Business Summary': 'Teradata Corporation, together '
#                                                'with its subsidiaries, '
#                                                'provides a connected '
#                                                'multi-cloud data platform for '
#                                                'enterprise analytics. The '
#                                                'company offers Teradata '
#                                                'Vantage, an open and connected '
#                                                'platform designed to leverage '
#                                                'data across an enterprise. Its '
#                                                'business consulting services '
#                                                'include support services for '
#                                                'organizations to establish a '
#                                                'data and analytic vision, '
#                                                'enable a multi-cloud ecosystem '
#                                                'architecture, and identify and '
#                                                'operationalize analytical '
#                                                'opportunities, as well as to '
#                                                'ensure the analytical '
#                                                'infrastructure delivers value. '
#                                                'The company offers support and '
#                                                'maintenance services. It '
#                                                'serves clients in financial '
#                                                'services, government, '
#                                                'healthcare and life sciences, '
#                                                'manufacturing, retail, '
#                                                'telecommunications, and '
#                                                'travel/transportation sectors '
#                                                'through a direct sales force '
#                                                'in the Americas, Europe, the '
#                                                'Middle East, Africa, the Asia '
#                                                'Pacific, and Japan. Teradata '
#                                                'Corporation was incorporated '
#                                                'in 1979 and is headquartered '
#                                                'in San Diego, California.',
#                            'City': 'San Diego',
#                            'Country': 'United States',
#                            'Industry': 'Software - Infrastructure',
#                            'Name': 'Teradata Corporation',
#                            'Sector': 'Technology',
#                            'State': 'CA',
#                            'Ticker': 'TDC',
#                            'text': 'Teradata Corporation, together with its '
#                                    'subsidiaries, provides a connected '
#                                    'multi-cloud data platform for enterprise '
#                                    'analytics. The company offers Teradata '
#                                    'Vantage, an open and connected platform '
#                                    'designed to leverage data across an '
#                                    'enterprise. Its business consulting '
#                                    'services include support services for '
#                                    'organizations to establish a data and '
#                                    'analytic vision, enable a multi-cloud '
#                                    'ecosystem architecture, and identify and '
#                                    'operationalize analytical opportunities, '
#                                    'as well as to ensure the analytical '
#                                    'infrastructure delivers value. The company '
#                                    'offers support and maintenance services. '
#                                    'It serves clients in financial services, '
#                                    'government, healthcare and life sciences, '
#                                    'manufacturing, retail, telecommunications, '
#                                    'and travel/transportation sectors through '
#                                    'a direct sales force in the Americas, '
#                                    'Europe, the Middle East, Africa, the Asia '
#                                    'Pacific, and Japan. Teradata Corporation '
#                                    'was incorporated in 1979 and is '
#                                    'headquartered in San Diego, California.'},
#               'score': 0.471572548,
#               'values': []},
#              {'id': '2a897b0d-2c83-4835-8956-f621581d6a82',
#               'metadata': {'Business Summary': 'Super Micro Computer, Inc., '
#                                                'together with its '
#                                                'subsidiaries, develops and '
#                                                'manufactures high performance '
#                                                'server and storage solutions '
#                                                'based on modular and open '
#                                                'architecture in the United '
#                                                'States, Europe, Asia, and '
#                                                'internationally. Its solutions '
#                                                'range from complete server, '
#                                                'storage systems, modular blade '
#                                                'servers, blades, workstations, '
#                                                'full racks, networking '
#                                                'devices, server sub-systems, '
#                                                'server management software, '
#                                                'and security software. The '
#                                                'company provides '
#                                                'application-optimized server '
#                                                'solutions, rackmount and blade '
#                                                'servers, storage, and '
#                                                'subsystems and accessories; '
#                                                'and server software management '
#                                                'solutions, such as Server '
#                                                'Management Suite, including '
#                                                'Supermicro Server Manager, '
#                                                'Supermicro Power Management '
#                                                'software, Supermicro Update '
#                                                'Manager, SuperCloud Composer, '
#                                                'and SuperDoctor 5. In '
#                                                'addition, it offers server '
#                                                'subsystems and accessories '
#                                                'comprising server boards, '
#                                                'chassis, power supplies, and '
#                                                'other accessories. Further, '
#                                                'the company provides server '
#                                                'and storage system '
#                                                'integration, configuration, '
#                                                'and software upgrade and '
#                                                'update services; and technical '
#                                                'documentation services, as '
#                                                'well as identifies service '
#                                                'requirements, creates and '
#                                                'executes project plans, and '
#                                                'conducts verification testing '
#                                                'and technical documentation, '
#                                                'and training services. '
#                                                'Additionally, it offers help '
#                                                'desk and on-site product '
#                                                'support services for its '
#                                                'server and storage systems; '
#                                                'and customer support services, '
#                                                'including ongoing maintenance '
#                                                'and technical support for its '
#                                                'products. The company provides '
#                                                'its products to enterprise '
#                                                'data centers, cloud computing, '
#                                                'artificial intelligence, and '
#                                                '5G and edge computing markets. '
#                                                'It sells its products through '
#                                                'direct and indirect sales '
#                                                'force, distributors, '
#                                                'value-added resellers, system '
#                                                'integrators, and original '
#                                                'equipment manufacturers. The '
#                                                'company was incorporated in '
#                                                '1993 and is headquartered in '
#                                                'San Jose, California.',
#                            'City': 'San Jose',
#                            'Country': 'United States',
#                            'Industry': 'Computer Hardware',
#                            'Name': 'Super Micro Computer, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'CA',
#                            'Ticker': 'SMCI',
#                            'text': 'Super Micro Computer, Inc., together with '
#                                    'its subsidiaries, develops and '
# ...
#                                                'DevOps, data center, network '
#                                                'modernization, asset '
#                                                'management, help desk '
#                                                'operations, and digital '
#                                                'workplace enablement; and '
#                                                'environment, energy, and '
#                                                'infrastructure services. The '
#                                                'Health segment offers '
#                                                'solutions to federal and '
#                                                'commercial customers '
#                                                'responsible for health and '
#                                                'well-being of people, include '
#                                                'health information management, '
#                                                'managed health, digital '
#                                                'modernization, and life '
#                                                'sciences research and '
#                                                'development services. Leidos '
#                                                'Holdings, Inc. was founded in '
#                                                '1969 and is headquartered in '
#                                                'Reston, Virginia.',
#                            'City': 'Reston',
#                            'Country': 'United States',
#                            'Industry': 'Information Technology Services',
#                            'Name': 'Leidos Holdings, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'VA',
#                            'Ticker': 'LDOS',
#                            'text': 'Leidos Holdings, Inc., together with its '
#                                    'subsidiaries, provides services and '
#                                    'solutions in the defense, intelligence, '
#                                    'civil, and health markets in the United '
#                                    'States and internationally. The company '
#                                    'operates through Defense Solutions, Civil, '
#                                    'and Health segments. The Defense Solutions '
#                                    'segment offers national security solutions '
#                                    'and systems for air, land, sea, space, and '
#                                    'cyberspace for the U.S. Intelligence '
#                                    'Community, the Department of Defense, the '
#                                    'space development agency, the National '
#                                    'Aeronautics and Space Administration, '
#                                    'defense information systems agency, '
#                                    'military services, and government agencies '
#                                    'of U.S. allies abroad, as well as other '
#                                    'federal and commercial customers in the '
#                                    'national security industry. The solutions '
#                                    'include technology, large-scale systems, '
#                                    'command and control platforms, data '
#                                    'analytics, logistics, and cybersecurity '
#                                    'solutions, as well as intelligence '
#                                    'analysis and operations support services '
#                                    'to critical missions. The Civil segment '
#                                    'provides systems integration services to '
#                                    'air navigation service providers, '
#                                    'including the federal aviation '
#                                    'administration, the En route automation '
#                                    'modernization, advanced technology oceanic '
#                                    'procedure, time based flow management, '
#                                    'terminal flight data management, geo-7, '
#                                    'and future flight services, as well as '
#                                    'enterprise-information display systems; '
#                                    'and security detection services. It also '
#                                    'offers information technology (IT) '
#                                    'solutions in cloud computing, mobility, '
#                                    'application modernization, DevOps, data '
#                                    'center, network modernization, asset '
#                                    'management, help desk operations, and '
#                                    'digital workplace enablement; and '
#                                    'environment, energy, and infrastructure '
#                                    'services. The Health segment offers '
#                                    'solutions to federal and commercial '
#                                    'customers responsible for health and '
#                                    'well-being of people, include health '
#                                    'information management, managed health, '
#                                    'digital modernization, and life sciences '
#                                    'research and development services. Leidos '
#                                    'Holdings, Inc. was founded in 1969 and is '
#                                    'headquartered in Reston, Virginia.'},
#               'score': 0.457822651,
#               'values': []},
#              {'id': '301e6b75-03e4-46e9-8d8d-0e00fd824d7a',
#               'metadata': {'Business Summary': 'Leidos Holdings, Inc., '
#                                                'together with its '
#                                                'subsidiaries, provides '
#                                                'services and solutions in the '
#                                                'defense, intelligence, civil, '
#                                                'and health markets in the '
#                                                'United States and '
#                                                'internationally. The company '
#                                                'operates through Defense '
#                                                'Solutions, Civil, and Health '
#                                                'segments. The Defense '
#                                                'Solutions segment offers '
#                                                'national security solutions '
#                                                'and systems for air, land, '
#                                                'sea, space, and cyberspace for '
#                                                'the U.S. Intelligence '
#                                                'Community, the Department of '
#                                                'Defense, the space development '
#                                                'agency, the National '
#                                                'Aeronautics and Space '
#                                                'Administration, defense '
#                                                'information systems agency, '
#                                                'military services, and '
#                                                'government agencies of U.S. '
#                                                'allies abroad, as well as '
#                                                'other federal and commercial '
#                                                'customers in the national '
#                                                'security industry. The '
#                                                'solutions include technology, '
#                                                'large-scale systems, command '
#                                                'and control platforms, data '
#                                                'analytics, logistics, and '
#                                                'cybersecurity solutions, as '
#                                                'well as intelligence analysis '
#                                                'and operations support '
#                                                'services to critical missions. '
#                                                'The Civil segment provides '
#                                                'systems integration services '
#                                                'to air navigation service '
#                                                'providers, including the '
#                                                'federal aviation '
#                                                'administration, the En route '
#                                                'automation modernization, '
#                                                'advanced technology oceanic '
#                                                'procedure, time based flow '
#                                                'management, terminal flight '
#                                                'data management, geo-7, and '
#                                                'future flight services, as '
#                                                'well as enterprise-information '
#                                                'display systems; and security '
#                                                'detection services. It also '
#                                                'offers information technology '
#                                                '(IT) solutions in cloud '
#                                                'computing, mobility, '
#                                                'application modernization, '
#                                                'DevOps, data center, network '
#                                                'modernization, asset '
#                                                'management, help desk '
#                                                'operations, and digital '
#                                                'workplace enablement; and '
#                                                'environment, energy, and '
#                                                'infrastructure services. The '
#                                                'Health segment offers '
#                                                'solutions to federal and '
#                                                'commercial customers '
#                                                'responsible for health and '
#                                                'well-being of people, include '
#                                                'health information management, '
#                                                'managed health, digital '
#                                                'modernization, and life '
#                                                'sciences research and '
#                                                'development services. Leidos '
#                                                'Holdings, Inc. was founded in '
#                                                '1969 and is headquartered in '
#                                                'Reston, Virginia.',
#                            'City': 'Reston',
#                            'Country': 'United States',
#                            'Industry': 'Information Technology Services',
#                            'Name': 'Leidos Holdings, Inc.',
#                            'Sector': 'Technology',
#                            'State': 'VA',
#                            'Ticker': 'LDOS',
#                            'text': 'Leidos Holdings, Inc., together with its '
#                                    'subsidiaries, provides services and '
#                                    'solutions in the defense, intelligence, '
#                                    'civil, and health markets in the United '
#                                    'States and internationally. The company '
#                                    'operates through Defense Solutions, Civil, '
#                                    'and Health segments. The Defense Solutions '
#                                    'segment offers national security solutions '
#                                    'and systems for air, land, sea, space, and '
#                                    'cyberspace for the U.S. Intelligence '
#                                    'Community, the Department of Defense, the '
#                                    'space development agency, the National '
#                                    'Aeronautics and Space Administration, '
#                                    'defense information systems agency, '
#                                    'military services, and government agencies '
#                                    'of U.S. allies abroad, as well as other '
#                                    'federal and commercial customers in the '
#                                    'national security industry. The solutions '
#                                    'include technology, large-scale systems, '
#                                    'command and control platforms, data '
#                                    'analytics, logistics, and cybersecurity '
#                                    'solutions, as well as intelligence '
#                                    'analysis and operations support services '
#                                    'to critical missions. The Civil segment '
#                                    'provides systems integration services to '
#                                    'air navigation service providers, '
#                                    'including the federal aviation '
#                                    'administration, the En route automation '
#                                    'modernization, advanced technology oceanic '
#                                    'procedure, time based flow management, '
#                                    'terminal flight data management, geo-7, '
#                                    'and future flight services, as well as '
#                                    'enterprise-information display systems; '
#                                    'and security detection services. It also '
#                                    'offers information technology (IT) '
#                                    'solutions in cloud computing, mobility, '
#                                    'application modernization, DevOps, data '
#                                    'center, network modernization, asset '
#                                    'management, help desk operations, and '
#                                    'digital workplace enablement; and '
#                                    'environment, energy, and infrastructure '
#                                    'services. The Health segment offers '
#                                    'solutions to federal and commercial '
#                                    'customers responsible for health and '
#                                    'well-being of people, include health '
#                                    'information management, managed health, '
#                                    'digital modernization, and life sciences '
#                                    'research and development services. Leidos '
#                                    'Holdings, Inc. was founded in 1969 and is '
#                                    'headquartered in Reston, Virginia.'},
#               'score': 0.457822651,
#               'values': []}],
#  'namespace': 'stock-descriptions',
#  'usage': {'read_units': 7}}

# %%
contexts = [item['metadata']['text'] for item in top_matches['matches']]

# %%
contexts = [
    {
        **item['metadata']  # Unpack all key-value pairs in 'metadata'
    }
    for item in top_matches['matches']
]

# %%
# Convert each context dictionary to a string
contexts_str = ["\n".join(f"{key}: {value}" for key, value in context.items()) for context in contexts[:7]]

# Join the stringified contexts
augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts_str) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query

# %%
augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 5]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-85-9013157228e7> in <cell line: 1>()
# ----> 1 augmented_query = "<CONTEXT>\n" + "\n\n-------\n\n".join(contexts[ : 15]) + "\n-------\n</CONTEXT>\n\n\n\nMY QUESTION:\n" + query
#
# TypeError: sequence item 0: expected str instance, dict found

# %%
print(augmented_query)
# Out:
# <CONTEXT>
# Business Summary: GDS Holdings Limited, together with its subsidiaries, develops and operates data centers in the People's Republic of China. The company offers colocation services comprising critical facilities space, customer-available power, racks, and cooling; managed hosting services, including business continuity and disaster recovery, network management, data storage, system security, operating system, database, and server middleware services; managed cloud services; and consulting services. It serves cloud service providers, large Internet companies, financial institutions, telecommunications and IT service providers, and large domestic private sector and multinational corporations. The company was founded in 2001 and is headquartered in Shanghai, the People's Republic of China.
# City: Shanghai
# Country: China
# Industry: Information Technology Services
# Name: GDS Holdings Limited
# Sector: Technology
# State: Information not available
# Ticker: GDS
# text: GDS Holdings Limited, together with its subsidiaries, develops and operates data centers in the People's Republic of China. The company offers colocation services comprising critical facilities space, customer-available power, racks, and cooling; managed hosting services, including business continuity and disaster recovery, network management, data storage, system security, operating system, database, and server middleware services; managed cloud services; and consulting services. It serves cloud service providers, large Internet companies, financial institutions, telecommunications and IT service providers, and large domestic private sector and multinational corporations. The company was founded in 2001 and is headquartered in Shanghai, the People's Republic of China.
#
# -------
#
# Business Summary: GDS Holdings Limited, together with its subsidiaries, develops and operates data centers in the People's Republic of China. The company offers colocation services comprising critical facilities space, customer-available power, racks, and cooling; managed hosting services, including business continuity and disaster recovery, network management, data storage, system security, operating system, database, and server middleware services; managed cloud services; and consulting services. It serves cloud service providers, large Internet companies, financial institutions, telecommunications and IT service providers, and large domestic private sector and multinational corporations. The company was founded in 2001 and is headquartered in Shanghai, the People's Republic of China.
# City: Shanghai
# Country: China
# Industry: Information Technology Services
# Name: GDS Holdings Limited
# Sector: Technology
# State: Information not available
# Ticker: GDS
# text: GDS Holdings Limited, together with its subsidiaries, develops and operates data centers in the People's Republic of China. The company offers colocation services comprising critical facilities space, customer-available power, racks, and cooling; managed hosting services, including business continuity and disaster recovery, network management, data storage, system security, operating system, database, and server middleware services; managed cloud services; and consulting services. It serves cloud service providers, large Internet companies, financial institutions, telecommunications and IT service providers, and large domestic private sector and multinational corporations. The company was founded in 2001 and is headquartered in Shanghai, the People's Republic of China.
#
# -------
#
# Business Summary: Iris Energy Limited owns and operates bitcoin mining data centers. It also provides high performance computing  solutions, including Al cloud services. The company was incorporated in 2018 and is headquartered in Sydney, Australia.
# City: Sydney
# Country: Australia
# Industry: Capital Markets
# Name: IREN Limited
# Sector: Financial Services
# State: NSW
# Ticker: IREN
# text: Iris Energy Limited owns and operates bitcoin mining data centers. It also provides high performance computing  solutions, including Al cloud services. The company was incorporated in 2018 and is headquartered in Sydney, Australia.
#
# -------
#
# Business Summary: Iris Energy Limited owns and operates bitcoin mining data centers. It also provides high performance computing  solutions, including Al cloud services. The company was incorporated in 2018 and is headquartered in Sydney, Australia.
# City: Sydney
# Country: Australia
# Industry: Capital Markets
# Name: IREN Limited
# Sector: Financial Services
# State: NSW
# Ticker: IREN
# text: Iris Energy Limited owns and operates bitcoin mining data centers. It also provides high performance computing  solutions, including Al cloud services. The company was incorporated in 2018 and is headquartered in Sydney, Australia.
#
# -------
#
# Business Summary: Hewlett Packard Enterprise Company provides solutions that allow customers to capture, analyze, and act upon data seamlessly in the Americas, Europe, the Middle East, Africa, the Asia Pacific, and Japan. It operates in six segments: Compute, HPC & AI, Storage, Intelligent Edge, Financial Services, and Corporate Investments and Other. The company offers general purpose servers for multi-workload computing and workload-optimized servers; HPE ProLiant rack and tower servers; HPE Synergy; HPE Alletra, HPE GreenLake, Zerto, HPE InfoSight, and HPE CloudPhysics storage products; HPE Cray EX, HPE Cray XD, and converged edge systems; and HPE Superdome Flex, HPE Nonstop, and HPE Integrity products. It also provides HPE Aruba products that includes hardware products, such as Wi-Fi access points, switches, and gateways; HPE Aruba Networking software and services comprising cloud-based management, network management and access control, analytics and assurance, software-defined wide-area networking, network security, analytics and assurance, and location services software; and professional and support services, as well as as-a-service and consumption models. In addition, the company offers leasing, financing, IT consumption, and utility programs and asset management services for customers to facilitate technology deployment models and the acquisition of various IT solutions, including hardware, software, and services from Hewlett Packard Enterprise and others; consultative-led services; HPE Ezmeral Container Platform; HPE Ezmeral Software Container Platform and HPE Ezmeral Software Data Fabric; OpsRamp; and Hewlett Packard Labs. It serves commercial and large enterprise groups, such as business and public sector enterprises; and through various partners comprising resellers, distribution partners, original equipment manufacturers, independent software vendors, systems integrators, and advisory firms. The company was founded in 1939 and is headquartered in Spring, Texas.
# City: Spring
# Country: United States
# Industry: Communication Equipment
# Name: Hewlett Packard Enterprise Company
# Sector: Technology
# State: TX
# Ticker: HPE
# text: Hewlett Packard Enterprise Company provides solutions that allow customers to capture, analyze, and act upon data seamlessly in the Americas, Europe, the Middle East, Africa, the Asia Pacific, and Japan. It operates in six segments: Compute, HPC & AI, Storage, Intelligent Edge, Financial Services, and Corporate Investments and Other. The company offers general purpose servers for multi-workload computing and workload-optimized servers; HPE ProLiant rack and tower servers; HPE Synergy; HPE Alletra, HPE GreenLake, Zerto, HPE InfoSight, and HPE CloudPhysics storage products; HPE Cray EX, HPE Cray XD, and converged edge systems; and HPE Superdome Flex, HPE Nonstop, and HPE Integrity products. It also provides HPE Aruba products that includes hardware products, such as Wi-Fi access points, switches, and gateways; HPE Aruba Networking software and services comprising cloud-based management, network management and access control, analytics and assurance, software-defined wide-area networking, network security, analytics and assurance, and location services software; and professional and support services, as well as as-a-service and consumption models. In addition, the company offers leasing, financing, IT consumption, and utility programs and asset management services for customers to facilitate technology deployment models and the acquisition of various IT solutions, including hardware, software, and services from Hewlett Packard Enterprise and others; consultative-led services; HPE Ezmeral Container Platform; HPE Ezmeral Software Container Platform and HPE Ezmeral Software Data Fabric; OpsRamp; and Hewlett Packard Labs. It serves commercial and large enterprise groups, such as business and public sector enterprises; and through various partners comprising resellers, distribution partners, original equipment manufacturers, independent software vendors, systems integrators, and advisory firms. The company was founded in 1939 and is headquartered in Spring, Texas.
#
# -------
#
# Business Summary: Hewlett Packard Enterprise Company provides solutions that allow customers to capture, analyze, and act upon data seamlessly in the Americas, Europe, the Middle East, Africa, the Asia Pacific, and Japan. It operates in six segments: Compute, HPC & AI, Storage, Intelligent Edge, Financial Services, and Corporate Investments and Other. The company offers general purpose servers for multi-workload computing and workload-optimized servers; HPE ProLiant rack and tower servers; HPE Synergy; HPE Alletra, HPE GreenLake, Zerto, HPE InfoSight, and HPE CloudPhysics storage products; HPE Cray EX, HPE Cray XD, and converged edge systems; and HPE Superdome Flex, HPE Nonstop, and HPE Integrity products. It also provides HPE Aruba products that includes hardware products, such as Wi-Fi access points, switches, and gateways; HPE Aruba Networking software and services comprising cloud-based management, network management and access control, analytics and assurance, software-defined wide-area networking, network security, analytics and assurance, and location services software; and professional and support services, as well as as-a-service and consumption models. In addition, the company offers leasing, financing, IT consumption, and utility programs and asset management services for customers to facilitate technology deployment models and the acquisition of various IT solutions, including hardware, software, and services from Hewlett Packard Enterprise and others; consultative-led services; HPE Ezmeral Container Platform; HPE Ezmeral Software Container Platform and HPE Ezmeral Software Data Fabric; OpsRamp; and Hewlett Packard Labs. It serves commercial and large enterprise groups, such as business and public sector enterprises; and through various partners comprising resellers, distribution partners, original equipment manufacturers, independent software vendors, systems integrators, and advisory firms. The company was founded in 1939 and is headquartered in Spring, Texas.
# City: Spring
# Country: United States
# Industry: Communication Equipment
# Name: Hewlett Packard Enterprise Company
# Sector: Technology
# State: TX
# Ticker: HPE
# text: Hewlett Packard Enterprise Company provides solutions that allow customers to capture, analyze, and act upon data seamlessly in the Americas, Europe, the Middle East, Africa, the Asia Pacific, and Japan. It operates in six segments: Compute, HPC & AI, Storage, Intelligent Edge, Financial Services, and Corporate Investments and Other. The company offers general purpose servers for multi-workload computing and workload-optimized servers; HPE ProLiant rack and tower servers; HPE Synergy; HPE Alletra, HPE GreenLake, Zerto, HPE InfoSight, and HPE CloudPhysics storage products; HPE Cray EX, HPE Cray XD, and converged edge systems; and HPE Superdome Flex, HPE Nonstop, and HPE Integrity products. It also provides HPE Aruba products that includes hardware products, such as Wi-Fi access points, switches, and gateways; HPE Aruba Networking software and services comprising cloud-based management, network management and access control, analytics and assurance, software-defined wide-area networking, network security, analytics and assurance, and location services software; and professional and support services, as well as as-a-service and consumption models. In addition, the company offers leasing, financing, IT consumption, and utility programs and asset management services for customers to facilitate technology deployment models and the acquisition of various IT solutions, including hardware, software, and services from Hewlett Packard Enterprise and others; consultative-led services; HPE Ezmeral Container Platform; HPE Ezmeral Software Container Platform and HPE Ezmeral Software Data Fabric; OpsRamp; and Hewlett Packard Labs. It serves commercial and large enterprise groups, such as business and public sector enterprises; and through various partners comprising resellers, distribution partners, original equipment manufacturers, independent software vendors, systems integrators, and advisory firms. The company was founded in 1939 and is headquartered in Spring, Texas.
#
# -------
#
# Business Summary: Teradata Corporation, together with its subsidiaries, provides a connected multi-cloud data platform for enterprise analytics. The company offers Teradata Vantage, an open and connected platform designed to leverage data across an enterprise. Its business consulting services include support services for organizations to establish a data and analytic vision, enable a multi-cloud ecosystem architecture, and identify and operationalize analytical opportunities, as well as to ensure the analytical infrastructure delivers value. The company offers support and maintenance services. It serves clients in financial services, government, healthcare and life sciences, manufacturing, retail, telecommunications, and travel/transportation sectors through a direct sales force in the Americas, Europe, the Middle East, Africa, the Asia Pacific, and Japan. Teradata Corporation was incorporated in 1979 and is headquartered in San Diego, California.
# City: San Diego
# Country: United States
# Industry: Software - Infrastructure
# Name: Teradata Corporation
# Sector: Technology
# State: CA
# Ticker: TDC
# text: Teradata Corporation, together with its subsidiaries, provides a connected multi-cloud data platform for enterprise analytics. The company offers Teradata Vantage, an open and connected platform designed to leverage data across an enterprise. Its business consulting services include support services for organizations to establish a data and analytic vision, enable a multi-cloud ecosystem architecture, and identify and operationalize analytical opportunities, as well as to ensure the analytical infrastructure delivers value. The company offers support and maintenance services. It serves clients in financial services, government, healthcare and life sciences, manufacturing, retail, telecommunications, and travel/transportation sectors through a direct sales force in the Americas, Europe, the Middle East, Africa, the Asia Pacific, and Japan. Teradata Corporation was incorporated in 1979 and is headquartered in San Diego, California.
# -------
# </CONTEXT>
#
#
#
# MY QUESTION:
# What are some companies are involved with building data centers?

# %%
client = OpenAI(
  base_url="https://api.groq.com/openai/v1",
  api_key=userdata.get("GROQ_API_KEY")
)

# %%
system_prompt = f"""You are an expert at providing answers about stocks. Please answer my question provided. and give the answer in formate
<Company Name> (<Ticker>) : <Answer>
"""

llm_response = client.chat.completions.create(
    model="llama-3.1-70b-versatile",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": augmented_query}
    ]
)

response = llm_response.choices[0].message.content

# %%
print(response)
# Out:
# GDS Holdings Limited (GDS) : Involved in developing and operating data centers in the People's Republic of China, offering services such as colocation, managed hosting, and cloud services.
#
# Iris Energy Limited (None, actual: IREN is the ticker for Iris Energy Limited in ASX and XRF is ticker for Iris Energy Limited in the OTCBB Market)  : Owns and operates bitcoin mining data centers, providing high-performance computing solutions and AI cloud services.
#
# Hewlett Packard Enterprise Company (HPE) : Offers data center solutions, including servers, storage, and converged edge systems, as well as management and support services.
#
# However, note that Hewlett Packard Enterprise Company is not primarily involved in data center real estate, the firm constructs, manages, markets, rents, and sells the equipment and services involved in running data centers.

# %%
df = yf.download(['MSFT', 'AAPL', 'VOO'], period='10y')
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
df.index
# Out:
# DatetimeIndex(['2024-11-04 00:00:00+00:00', '2024-11-05 00:00:00+00:00',
#                '2024-11-06 00:00:00+00:00', '2024-11-07 00:00:00+00:00',
#                '2024-11-08 00:00:00+00:00', '2024-11-11 00:00:00+00:00',
#                '2024-11-12 00:00:00+00:00', '2024-11-13 00:00:00+00:00',
#                '2024-11-14 00:00:00+00:00', '2024-11-15 00:00:00+00:00',
#                '2024-11-18 00:00:00+00:00', '2024-11-19 00:00:00+00:00',
#                '2024-11-20 00:00:00+00:00', '2024-11-21 00:00:00+00:00',
#                '2024-11-22 00:00:00+00:00', '2024-11-25 00:00:00+00:00',
#                '2024-11-26 00:00:00+00:00', '2024-11-27 00:00:00+00:00',
#                '2024-11-29 00:00:00+00:00', '2024-12-02 00:00:00+00:00',
#                '2024-12-03 00:00:00+00:00', '2024-12-04 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Date', freq=None)

# %%
import pandas as pd
import plotly.graph_objects as go

def plot_stock_data_interactive(df, tickers, price_type='Close'):
    """
    Creates an interactive plot for specified price type (e.g., Close, Open, High, Low).

    Args:
        df (pd.DataFrame): DataFrame with multi-index columns from yfinance download or similar.
        tickers (list): List of tickers to plot (e.g., ['AAPL', 'MSFT', 'VOO']).
        price_type (str): The type of price to plot (e.g., 'Close', 'Open', 'High', 'Low').
    """
    # Create the Plotly figure
    fig = go.Figure()

    # Add traces for each ticker
    for ticker in tickers:
        fig.add_trace(go.Scatter(
            x=df.index,
            y=df[(price_type, ticker)],
            mode='lines',
            name=ticker,
            hovertemplate=f"<b>{ticker}</b><br>Date: %{{x}}<br>{price_type} Price: $%{{y:.2f}}<extra></extra>"
        ))

    # Customize the layout
    fig.update_layout(
        title=f"Interactive {price_type} Prices Over Time",
        xaxis_title="Date",
        yaxis_title=f"{price_type} Price ($)",
        hovermode="x unified",
        legend_title="Stocks",
        template="plotly_dark"  # Optional: Use a dark theme
    )

    # Show the interactive plot
    fig.show()


# Example data preprocessing
df.columns = pd.MultiIndex.from_tuples(df.columns) if not isinstance(df.columns, pd.MultiIndex) else df.columns
df.index = pd.to_datetime(df.index)

# Extract tickers dynamically
tickers = df.columns.get_level_values(1).unique()

# Plot the stock data
plot_stock_data_interactive(df, tickers=tickers, price_type='Close')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7a631c51-0ffc-4254-abea-d0b883552bed" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7a631c51-0ffc-4254-abea-d0b883552bed")) {                    Plotly.newPlot(                        "7a631c51-0ffc-4254-abea-d0b883552bed",                        [{"hovertemplate":"\u003cb\u003eAAPL\u003c\u002fb\u003e\u003cbr\u003eDate: %{x}\u003cbr\u003eClose Price: $%{y:.2f}\u003cextra\u003e\u003c\u002fextra\u003e","mode":"lines","name":"AAPL","x":["2014-12-04T00:00:00+00:00","2014-12-05T00:00:00+00:00","2014-12-08T00:00:00+00:00","2014-12-09T00:00:00+00:00","2014-12-10T00:00:00+00:00","2014-12-11T00:00:00+00:00","2014-12-12T00:00:00+00:00","2014-12-15T00:00:00+00:00","2014-12-16T00:00:00+00:00","2014-12-17T00:00:00+00:00","2014-12-18T00:00:00+00:00","2014-12-19T00:00:00+00:00","2014-12-22T00:00:00+00:00","2014-12-23T00:00:00+00:00","2014-12-24T00:00:00+00:00","2014-12-26T00:00:00+00:00","2014-12-29T00:00:00+00:00","2014-12-30T00:00:00+00:00","2014-12-31T00:00:00+00:00","2015-01-02T00:00:00+00:00","2015-01-05T00:00:00+00:00","2015-01-06T00:00:00+00:00","2015-01-07T00:00:00+00:00","2015-01-08T00:00:00+00:00","2015-01-09T00:00:00+00:00","2015-01-12T00:00:00+00:00","2015-01-13T00:00:00+00:00","2015-01-14T00:00:00+00:00","2015-01-15T00:00:00+00:00","2015-01-16T00:00:00+00:00","2015-01-20T00:00:00+00:00","2015-01-21T00:00:00+00:00","2015-01-22T00:00:00+00:00","2015-01-23T00:00:00+00:00","2015-01-26T00:00:00+00:00","2015-01-27T00:00:00+00:00","2015-01-28T00:00:00+00:00","2015-01-29T00:00:00+00:00","2015-01-30T00:00:00+00:00","2015-02-02T00:00:00+00:00","2015-02-03T00:00:00+00:00","2015-02-04T00:00:00+00:00","2015-02-05T00:00:00+00:00","2015-02-06T00:00:00+00:00","2015-02-09T00:00:00+00:00","2015-02-10T00:00:00+00:00","2015-02-11T00:00:00+00:00","2015-02-12T00:00:00+00:00","2015-02-13T00:00:00+00:00","2015-02-17T00:00:00+00:00","2015-02-18T00:00:00+00:00","2015-02-19T00:00:00+00:00","2015-02-20T00:00:00+00:00","2015-02-23T00:00:00+00:00","2015-02-24T00:00:00+00:00","2015-02-25T00:00:00+00:00","2015-02-26T00:00:00+00:00","2015-02-27T00:00:00+00:00","2015-03-02T00:00:00+00:00","2015-03-03T00:00:00+00:00","2015-03-04T00:00:00+00:00","2015-03-05T00:00:00+00:00","2015-03-06T00:00:00+00:00","2015-03-09T00:00:00+00:00","2015-03-10T00:00:00+00:00","2015-03-11T00:00:00+00:00","2015-03-12T00:00:00+00:00","2015-03-13T00:00:00+00:00","2015-03-16T00:00:00+00:00","2015-03-17T00:00:00+00:00","2015-03-18T00:00:00+00:00","2015-03-19T00:00:00+00:00","2015-03-20T00:00:00+00:00","2015-03-23T00:00:00+00:00","2015-03-24T00:00:00+00:00","2015-03-25T00:00:00+00:00","2015-03-26T00:00:00+00:00","2015-03-27T00:00:00+00:00","2015-03-30T00:00:00+00:00","2015-03-31T00:00:00+00:00","2015-04-01T00:00:00+00:00","2015-04-02T00:00:00+00:00","2015-04-06T00:00:00+00:00","2015-04-07T00:00:00+00:00","2015-04-08T00:00:00+00:00","2015-04-09T00:00:00+00:00","2015-04-10T00:00:00+00:00","2015-04-13T00:00:00+00:00","2015-04-14T00:00:00+00:00","2015-04-15T00:00:00+00:00","2015-04-16T00:00:00+00:00","2015-04-17T00:00:00+00:00","2015-04-20T00:00:00+00:00","2015-04-21T00:00:00+00:00","2015-04-22T00:00:00+00:00","2015-04-23T00:00:00+00:00","2015-04-24T00:00:00+00:00","2015-04-27T00:00:00+00:00","2015-04-28T00:00:00+00:00","2015-04-29T00:00:00+00:00","2015-04-30T00:00:00+00:00","2015-05-01T00:00:00+00:00","2015-05-04T00:00:00+00:00","2015-05-05T00:00:00+00:00","2015-05-06T00:00:00+00:00","2015-05-07T00:00:00+00:00","2015-05-08T00:00:00+00:00","2015-05-11T00:00:00+00:00","2015-05-12T00:00:00+00:00","2015-05-13T00:00:00+00:00","2015-05-14T00:00:00+00:00","2015-05-15T00:00:00+00:00","2015-05-18T00:00:00+00:00","2015-05-19T00:00:00+00:00","2015-05-20T00:00:00+00:00","2015-05-21T00:00:00+00:00 ...

# %%
av_api_key=userdata.get("ALPHA_VAN_API")

# %%
import requests

params = {
    'function':' NEWS_SENTIMENT',
    'tickers': 'AAPL,MSFT',
    'apikey': 'YOUR_API_KEY'
}
url = f'https://www.alphavantage.co/query?function=NEWS_SENTIMENT&tickers=TSLA&limit=100&apikey={av_api_key}'
r = requests.get(url)
data = r.json()

data
# Out:
# {'items': '50',
#  'sentiment_score_definition': 'x <= -0.35: Bearish; -0.35 < x <= -0.15: Somewhat-Bearish; -0.15 < x < 0.15: Neutral; 0.15 <= x < 0.35: Somewhat_Bullish; x >= 0.35: Bullish',
#  'relevance_score_definition': '0 < x <= 1, with a higher score indicating higher relevance.',
#  'feed': [{'title': 'Making Money From Crowd Stampede - Palantir Becomes Largest Defense Contractor In Blink Of An Eye - Apple  ( NASDAQ:AAPL ) ',
#    'url': 'https://www.benzinga.com/trading-ideas/24/12/42325140/making-money-from-crowd-stampede-palantir-becomes-largest-defense-contractor-in-blink-of-an-eye',
#    'time_published': '20241204T201243',
#    'authors': ['The Arora Report'],
#    'summary': 'To gain an edge, this is what you need to know today. PLTR trailing PE is 354. RTX trailing PE is 34. PLTR forward PE is 151. RTX forward PE is 19. PLTR price/sales is 65. RTX price/sales is 2. In the early trade, money flows are positive in Apple Inc AAPL, Amazon.com, Inc.',
#    'banner_image': 'https://contributor-assets.benzinga.com/wp-content/uploads/2024/12/04201018/image-1024x628.png',
#    'source': 'Benzinga',
#    'category_within_source': 'Trading',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Economy - Monetary', 'relevance_score': '0.158519'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.993856'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'},
#     {'topic': 'Finance', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.291186,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'MSFT',
#      'relevance_score': '0.129866',
#      'ticker_sentiment_score': '0.158751',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'GOOG',
#      'relevance_score': '0.129866',
#      'ticker_sentiment_score': '0.158751',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'META',
#      'relevance_score': '0.129866',
#      'ticker_sentiment_score': '-0.318181',
#      'ticker_sentiment_label': 'Somewhat-Bearish'},
#     {'ticker': 'NVDA',
#      'relevance_score': '0.129866',
#      'ticker_sentiment_score': '0.158751',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'AAPL',
#      'relevance_score': '0.129866',
#      'ticker_sentiment_score': '0.158751',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.129866',
#      'ticker_sentiment_score': '0.158751',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'IVZ',
#      'relevance_score': '0.06515',
#      'ticker_sentiment_score': '0.350554',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': 'Tesla Boosts Marketing In China, Highlights Safety Features During Year-End Sales Push: Report - Tesla  ( NASDAQ:TSLA ) ',
#    'url': 'https://www.benzinga.com/news/global/24/12/42322754/tesla-boosts-marketing-in-china-highlights-safety-features-during-year-end-sales-push-report',
#    'time_published': '20241204T181524',
#    'authors': ['Nabaparna Bhattacharya'],
#    'summary': "Tesla, Inc. TSLA reportedly ramped up its marketing efforts in China to boost sales during the year-end car-buying season. Grace Tao, Tesla's vice president of external affairs, emphasized the safety of Tesla vehicles in a recent Weibo post, CnEV Post reports.",
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/04/Tesla-China.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'General',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Technology', 'relevance_score': '0.5'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.161647'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.2243,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.929758',
#      'ticker_sentiment_score': '0.263151',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'WB',
#      'relevance_score': '0.102888',
#      'ticker_sentiment_score': '0.123609',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'Is Sirius XM Finally a Tesla Stock Play?',
#    'url': 'https://www.fool.com/investing/2024/12/04/is-sirius-xm-finally-a-tesla-stock-play/',
#    'time_published': '20241204T164500',
#    'authors': ['Rick Munarriz'],
#    'summary': "The latest Tesla software update could be a boost to Sirius XM's sluggish subscriber base.",
#    'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F799831%2Ftesla-ev-electric-vehicle-charging-station.jpg&op=resize&w=700',
#    'source': 'Motley Fool',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.fool.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.413559'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'},
#     {'topic': 'Earnings', 'relevance_score': '0.360215'},
#     {'topic': 'Technology', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.110749,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'SIRI',
#      'relevance_score': '0.583426',
#      'ticker_sentiment_score': '0.153923',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.513775',
#      'ticker_sentiment_score': '0.242319',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': 'Nvidia-Backed Hugging Face CEO Makes 6 Predictions For 2025: Expect Robotics Growth, Valuation Cuts For AI - NVIDIA  ( NASDAQ:NVDA ) ',
#    'url': 'https://www.benzinga.com/24/12/42319922/artificial-intelligence-ceo-backed-by-nvidia-alphabet-amazon-shares-2025-ai-predictions-including-robots-chemistr',
#    'time_published': '20241204T162105',
#    'authors': ['Chris Katje'],
#    'summary': 'Many companies dealing in artificial intelligence ( AI ) saw their valuations skyrocket in 2024. Nvidia Corporation NVDA, for example, became the most valuable company in the world several times throughout the year.',
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/04/West-Bangal--India---July-5--2023--Huggi.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'News',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Economy - Monetary', 'relevance_score': '0.310843'},
#     {'topic': 'Retail & Wholesale', 'relevance_score': '0.333333'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.232194,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'GOOG',
#      'relevance_score': '0.076115',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NVDA',
#      'relevance_score': '0.297661',
#      'ticker_sentiment_score': '0.307037',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.151539',
#      'ticker_sentiment_score': '0.109386',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'IBM',
#      'relevance_score': '0.151539',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'QCOM',
#      'relevance_score': '0.151539',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'INTC',
#      'relevance_score': '0.151539',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'AMD',
#      'relevance_score': '0.151539',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'OPTGF',
#      'relevance_score': '0.076115',
#      'ticker_sentiment_score': '0.08542',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'AMZN',
#      'relevance_score': '0.151539',
#      'ticker_sentiment_score': '0.163629',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': "Tesla Analyst Lowers Q4 Delivery Estimate, Says 2 Dynamics Will Determine EV Stock's Valuation - Tesla  ( NASDAQ:TSLA ) ",
#    'url': 'https://www.benzinga.com/analyst-ratings/analyst-color/24/12/42319796/tesla-analyst-lowers-q4-delivery-estimate-says-2-dynamics-will-determine-ev-stocks-',
#    'time_published': '20241204T161502',
#    'authors': ['Chris Katje'],
#    'summary': 'A Tesla Inc TSLA analyst has lowered the fourth-quarter delivery estimate for the company citing weak demand and survey data, which could see the company miss full-year growth estimates. The Tesla Analyst: Goldman Sachs analyst Mark Delaney maintained a Neutral rating on Tesla with a $250 price ...',
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/04/Tesla--Inc--TSLA.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'Trading',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Finance', 'relevance_score': '0.5'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.316726'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.142668,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'GS',
#      'relevance_score': '0.073098',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'GM',
#      'relevance_score': '0.073098',
#      'ticker_sentiment_score': '0.064464',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.831224',
#      'ticker_sentiment_score': '0.057139',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'Hiccups in ETFs tracking MicroStrategy occurring as bull market fuels trading boom in single-stock funds',
#    'url': 'https://www.cnbc.com/2024/12/04/hiccups-in-etfs-tracking-microstrategy-occurring-as-bull-market-fuels-trading-boom-in-single-stock-funds.html',
#    'time_published': '20241204T151055',
#    'authors': [],
#    'summary': 'Single stock ETFs are seeing high trading volumes, and some are showing signs of stress.',
#    'banner_image': None,
#    'source': 'CNBC',
#    'category_within_source': 'Top News',
#    'source_domain': 'www.cnbc.com',
#    'topics': [{'topic': 'Life Sciences', 'relevance_score': '0.25'},
#     {'topic': 'Financial Markets', 'relevance_score': '1.0'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.25'},
#     {'topic': 'Technology', 'relevance_score': '0.25'},
#     {'topic': 'Finance', 'relevance_score': '0.25'}],
#    'overall_sentiment_score': 0.043386,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'MSTR',
#      'relevance_score': '0.360752',
#      'ticker_sentiment_score': '-0.066593',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NVDA',
#      'relevance_score': '0.062271',
#      'ticker_sentiment_score': '-0.012013',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'MORN',
#      'relevance_score': '0.062271',
#      'ticker_sentiment_score': '0.013042',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.062271',
#      'ticker_sentiment_score': '-0.012013',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NVO',
#      'relevance_score': '0.124164',
#      'ticker_sentiment_score': '0.171251',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': 'General Motors Recalls 132K Trucks Due to Tailgate Defect',
#    'url': 'https://www.zacks.com/stock/news/2378903/general-motors-recalls-132k-trucks-due-to-tailgate-defect',
#    'time_published': '20241204T144900',
#    'authors': ['Zacks Equity Research'],
#    'summary': 'GM recalls more than 132,000 trucks, including the 2024 Chevrolet Silverado HD 2500, 3500 and GMC Sierra HD 2500, 3500, to fix the tailgate issue.',
#    'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/68/487.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Earnings', 'relevance_score': '0.77141'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.118039,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'BYDDY',
#      'relevance_score': '0.204072',
#      'ticker_sentiment_score': '0.030402',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.204072',
#      'ticker_sentiment_score': '0.030402',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'DORM',
#      'relevance_score': '0.204072',
#      'ticker_sentiment_score': '0.030402',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'GM',
#      'relevance_score': '0.301933',
#      'ticker_sentiment_score': '-0.093461',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': "Jim Cramer's top 10 things to watch in the stock market Wednesday",
#    'url': 'https://www.cnbc.com/2024/12/04/jim-cramers-top-10-things-to-watch-in-the-stock-market-wednesday.html',
#    'time_published': '20241204T141849',
#    'authors': [],
#    'summary': "Eli Lilly crushed Novo Nordisk's in a head-to-head obesity drug trial. Salesforce and Marvell shares surged on earnings.",
#    'banner_image': None,
#    'source': 'CNBC',
#    'category_within_source': 'Top News',
#    'source_domain': 'www.cnbc.com',
#    'topics': [{'topic': 'Life Sciences', 'relevance_score': '0.2'},
#     {'topic': 'Technology', 'relevance_score': '0.2'},
#     {'topic': 'Finance', 'relevance_score': '0.2'},
#     {'topic': 'Retail & Wholesale', 'relevance_score': '0.2'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.99393'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.2'},
#     {'topic': 'Earnings', 'relevance_score': '0.972476'}],
#    'overall_sentiment_score': 0.153833,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'GOOG',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '0.086263',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NVDA',
#      'relevance_score': '0.148121',
#      'ticker_sentiment_score': '0.109513',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'DLTR',
#      'relevance_score': '0.099066',
#      'ticker_sentiment_score': '0.112411',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'FL',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '0.011967',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'GM',
#      'relevance_score': '0.099066',
#      'ticker_sentiment_score': '0.094871',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NVO',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '-0.098218',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NKE',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '0.011967',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'GS',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '0.068749',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'MSFT',
#      'relevance_score': '0.148121',
#      'ticker_sentiment_score': '0.157634',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'DTST',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '0.208195',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'PSTG',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '0.208195',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.099066',
#      'ticker_sentiment_score': '0.07397',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'ZS',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '-0.125',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'MRVL',
#      'relevance_score': '0.049629',
#      'ticker_sentiment_score': '0.086263',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'Foresight Signs AI-Driven Smart Parking Solutions Collaboration Agreement with South Korean 7meerkat and KONEC',
#    'url': 'https://www.globenewswire.com/news-release/2024/12/04/2991467/0/en/Foresight-Signs-AI-Driven-Smart-Parking-Solutions-Collaboration-Agreement-with-South-Korean-7meerkat-and-KONEC.html',
#    'time_published': '20241204T130500',
#    'authors': ['Foresight Autonomous Holdings Ltd.'],
#    'summary': 'The parties will collaborate to develop and commercialize advanced AI-powered parking management solutions to enhance urban parking, making it smarter, more efficient and ...',
#    'banner_image': 'https://ml.globenewswire.com/Resource/Download/22d51a3f-a279-4de4-8d9c-1bc778fb7c19',
#    'source': 'GlobeNewswire',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.globenewswire.com',
#    'topics': [{'topic': 'Technology', 'relevance_score': '0.5'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.310843'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.363621,
#    'overall_sentiment_label': 'Bullish',
#    'ticker_sentiment': [{'ticker': 'FRSX',
#      'relevance_score': '0.173022',
#      'ticker_sentiment_score': '0.357692',
#      'ticker_sentiment_label': 'Bullish'},
#     {'ticker': 'HYMLF',
#      'relevance_score': '0.043579',
#      'ticker_sentiment_score': '-0.025513',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.043579',
#      'ticker_sentiment_score': '-0.025513',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': "Tesla's 0% Interest Loan Offer On Model 3, Y To End Mid-December: Customers Who Order Now Can Get Delivery Before Year-End - Tesla  ( NASDAQ:TSLA ) ",
#    'url': 'https://www.benzinga.com/tech/24/12/42312826/teslas-0-interest-loan-offer-on-model-3-y-to-end-mid-december-customers-who-order-now-can-get-delivery-befor',
#    'time_published': '20241204T130016',
#    'authors': ['Anan Ashraf'],
#    'summary': 'Tesla Inc TSLA said on Tuesday that the company\'s 0% interest loan offer in North America on Model 3, Y will end mid-December. What Happened: "0% APR for new Model 3/Y in the US will end on 12/15," Tesla announced in an X post on Tuesday. "Order now and take delivery by 12/31," Tesla further urged.',
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/04/Teslas-Moves.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'News',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.161647'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.14024,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.939207',
#      'ticker_sentiment_score': '0.190976',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': "'Big Short' Trader Danny Moses Gives Up On Shorting Tesla, Says It Is 'Very Difficult To Short A Name That Is Not Trading On Fundamentals' - Tesla  ( NASDAQ:TSLA ) ",
#    'url': 'https://www.benzinga.com/24/12/42311290/trader-danny-moses-says-he-is-no-longer-shorting-tesla',
#    'time_published': '20241204T115710',
#    'authors': ['Anan Ashraf'],
#    'summary': 'Moses Ventures founder and "Big Short" fame trader Danny Moses said on Tuesday that he does not have a short position in Tesla Inc. TSLA anymore. What Happened: Moses has been short on Tesla at various times since Nov. 2016 when Tesla bought SolarCity, which he deemed to be an "awful deal."',
#    'banner_image': 'https://editorial-assets.benzinga.com/wp-content/uploads/2024/12/04022334/Tesla-ratings-1.jpg',
#    'source': 'Benzinga',
#    'category_within_source': 'Markets',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Economy - Fiscal', 'relevance_score': '0.158519'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.365926'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.155382,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.859898',
#      'ticker_sentiment_score': '0.269667',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': 'Where Will Dogecoin Be in 1 Year?',
#    'url': 'https://www.fool.com/investing/2024/12/04/where-will-dogecoin-be-in-1-year/',
#    'time_published': '20241204T115000',
#    'authors': ['Adam Spatacco'],
#    'summary': 'The price of Dogecoin has soared in 2024, but can it keep climbing higher?',
#    'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F799629%2Fshiba-inu-dog-doge-dogecoin-1.jpeg&op=resize&w=700',
#    'source': 'Motley Fool',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.fool.com',
#    'topics': [{'topic': 'Economy - Fiscal', 'relevance_score': '0.158519'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.538269'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'},
#     {'topic': 'Blockchain', 'relevance_score': '0.451494'}],
#    'overall_sentiment_score': 0.215882,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.058188',
#      'ticker_sentiment_score': '0.104983',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'CRYPTO:BTC',
#      'relevance_score': '0.116067',
#      'ticker_sentiment_score': '0.125097',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'CRYPTO:DOGE',
#      'relevance_score': '0.85567',
#      'ticker_sentiment_score': '0.330728',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': 'Zacks Investment Ideas feature highlights: Marvell Technology, Lululemon, Block, Amazon and Tesla',
#    'url': 'https://www.zacks.com/stock/news/2378585/zacks-investment-ideas-feature-highlights-marvell-technology-lululemon-block-amazon-and-tesla',
#    'time_published': '20241204T100000',
#    'authors': ['Zacks Investment Research'],
#    'summary': 'Marvell Technology, Lululemon, Block, Amazon and Tesla have been highlighted in this Investment Ideas article.',
#    'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/4d/1032.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Economy - Monetary', 'relevance_score': '0.451494'},
#     {'topic': 'Retail & Wholesale', 'relevance_score': '0.333333'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.962106'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Earnings', 'relevance_score': '0.158519'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.179323,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.171607',
#      'ticker_sentiment_score': '0.031907',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'MA',
#      'relevance_score': '0.03458',
#      'ticker_sentiment_score': '0.079687',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'AMZN',
#      'relevance_score': '0.171607',
#      'ticker_sentiment_score': '0.056377',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'SQ',
#      'relevance_score': '0.137671',
#      'ticker_sentiment_score': '0.026864',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'MRVL',
#      'relevance_score': '0.103479',
#      'ticker_sentiment_score': '0.014099',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'Tesla Car Crash In New York Claims 2 Lives, Cause Unclear: Report - Tesla  ( NASDAQ:TSLA ) ',
#    'url': 'https://www.benzinga.com/24/12/42309128/2-killed-after-tesla-crashes-into-rock-in-new-york-report',
#    'time_published': '20241204T083848',
#    'authors': ['Anan Ashraf'],
#    'summary': 'Two people were killed in a fiery Tesla crash in Pelham Manor, New York, on Tuesday, as per reports. What Happened: The two people who died are from New Rochelle, CBS News New York reported, citing sources.',
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/04/Price-Action.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'News',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': -0.271117,
#    'overall_sentiment_label': 'Somewhat-Bearish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.366061',
#      'ticker_sentiment_score': '-0.426271',
#      'ticker_sentiment_label': 'Bearish'}]},
#   {'title': "Tesla's Global Sales Could Witness A Decline Due To Slowdown In Europe And US, Even As China Set To Rise This Year, Warns Expert - Tesla  ( NASDAQ:TSLA ) ",
#    'url': 'https://www.benzinga.com/24/12/42308566/tesla-researcher-sees-drop-in-sales-in-europe-us-bring-down-global-deliveries-in-2024-despite-rise-in-china',
#    'time_published': '20241204T072432',
#    'authors': ['Anan Ashraf'],
#    'summary': "Tesla Inc TSLA researcher Troy Teslike said on Tuesday that while the EV giant's sales in China are slated to rise this year as compared to the last, sales in the U.S. and Europe will drop, weighing down on the company's overall global deliveries.",
#    'banner_image': 'https://editorial-assets.benzinga.com/wp-content/uploads/2024/12/04022334/Tesla-ratings-1.jpg',
#    'source': 'Benzinga',
#    'category_within_source': 'Markets',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.161647'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.002375,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.672712',
#      'ticker_sentiment_score': '0.117686',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': "Bluesky COO Rose Wang Addresses Platform's Anti-Musk Label, Monetization Plans: 'We Would Never Put Speech Behind A Paywall'",
#    'url': 'https://www.benzinga.com/24/12/42308102/bluesky-coo-rose-wang-addresses-the-platforms-political-neutrality-amid-anti-elon-musk-labels-asserts-we-would-ne',
#    'time_published': '20241204T060802',
#    'authors': ['Ananya Gairola'],
#    'summary': "On Tuesday, Bluesky COO Rose Wang addressed the platform's stance on political neutrality amid it getting labels such as being anti-Elon Musk. What Happened: During a conversation with Bloomberg TV, Wang discussed Bluesky's rapid growth following the 2024 U.S.",
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/04/How-To-Create-Your-Own-Starter-Pack.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'News',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.085218,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.100729',
#      'ticker_sentiment_score': '-0.135926',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'Sony-Honda EV Dream Collides With Trump-Backed Policy Shift Reality Ahead Of 2026 US Launch - Invesco Electric Vehicle Metals Commodity Strategy No K-1 ETF  ( NASDAQ:EVMT ) , Amplify Lithium & Battery Technology ETF  ( ARCA:BATT ) ',
#    'url': 'https://www.benzinga.com/24/12/42307375/sony-and-hondas-joint-ev-venture-faces-headwinds-ahead-of-us-launch-in-2026-amid-trump-backed-policy-shifts',
#    'time_published': '20241204T034334',
#    'authors': ['Kaustubh Bagalkote'],
#    'summary': "Sony Group Corp SONY and Honda Motor Co Ltd.'s HMC joint electric vehicle venture faces significant headwinds as it prepares to enter the U.S. market in 2026, amid expected policy changes under President-elect Donald Trump that could reshape the EV landscape.",
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/03/Push-Toward-Electric-Vehicles.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'Markets',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Finance', 'relevance_score': '0.5'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.917436'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.179907,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'SNEJF',
#      'relevance_score': '0.256538',
#      'ticker_sentiment_score': '0.079087',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.256538',
#      'ticker_sentiment_score': '0.400249',
#      'ticker_sentiment_label': 'Bullish'},
#     {'ticker': 'IVZ',
#      'relevance_score': '0.08687',
#      'ticker_sentiment_score': '-0.041763',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'HMC',
#      'relevance_score': '0.256538',
#      'ticker_sentiment_score': '0.079087',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': "What's Going On With Magnificent 7 Stocks? - NVIDIA  ( NASDAQ:NVDA ) ",
#    'url': 'https://www.benzinga.com/news/large-cap/24/12/42305868/whats-going-on-with-magnificent-7-stocks',
#    'time_published': '20241204T000134',
#    'authors': ['Erica Kollmann'],
#    'summary': "Aswath Damodaran, finance professor at New York Univerisity's Stern School of Business, told Bloomberg Television on Monday that he recommends buying any of the Magnificent Seven stocks on dips.",
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/03/magnificent-7-shutter.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'News',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Technology', 'relevance_score': '0.5'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.538269'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.262419,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'MSFT',
#      'relevance_score': '0.244109',
#      'ticker_sentiment_score': '0.057839',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'GOOG',
#      'relevance_score': '0.244109',
#      'ticker_sentiment_score': '-0.075213',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NVDA',
#      'relevance_score': '0.359014',
#      'ticker_sentiment_score': '0.078801',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'AAPL',
#      'relevance_score': '0.359014',
#      'ticker_sentiment_score': '0.078801',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.359014',
#      'ticker_sentiment_score': '0.578984',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': "The U.S. may have reached 'the high-water mark' in tensions with China, Jim Cramer says",
#    'url': 'https://www.cnbc.com/2024/12/03/jim-cramer-us-may-have-reached-high-water-mark-in-china-tensions.html',
#    'time_published': '20241203T233709',
#    'authors': [],
#    'summary': "CNBC's Jim Cramer wondered how President-elect Donald Trump's relationship with Tesla CEO Elon Musk will affect his administration's approach to China.",
#    'banner_image': None,
#    'source': 'CNBC',
#    'category_within_source': 'Top News',
#    'source_domain': 'www.cnbc.com',
#    'topics': [{'topic': 'Retail & Wholesale', 'relevance_score': '0.333333'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.451494'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.055357,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'LRCX',
#      'relevance_score': '0.092569',
#      'ticker_sentiment_score': '0.206275',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'AMAT',
#      'relevance_score': '0.092569',
#      'ticker_sentiment_score': '0.206275',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'META',
#      'relevance_score': '0.092569',
#      'ticker_sentiment_score': '-0.094549',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NKE',
#      'relevance_score': '0.092569',
#      'ticker_sentiment_score': '0.206275',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.092569',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'SBUX',
#      'relevance_score': '0.183895',
#      'ticker_sentiment_score': '0.401973',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': "Brian's Big Idea: Top 10 Stocks",
#    'url': 'https://www.zacks.com/stock/news/2378547/brians-big-idea-top-10-stocks',
#    'time_published': '20241203T225500',
#    'authors': ['Brian Bolan'],
#    'summary': 'A look at TSLA, FTNT, VRT, and a very popular service at Zacks.',
#    'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default105.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Retail & Wholesale', 'relevance_score': '0.333333'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.218246,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'VRT',
#      'relevance_score': '0.175859',
#      'ticker_sentiment_score': '0.150597',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'SFM',
#      'relevance_score': '0.175859',
#      'ticker_sentiment_score': '0.144545',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.175859',
#      'ticker_sentiment_score': '0.119558',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'FTNT',
#      'relevance_score': '0.175859',
#      'ticker_sentiment_score': '0.115324',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'Tesla  ( TSLA )  Stock Slides as Market Rises: Facts to Know Before You Trade',
#    'url': 'https://www.zacks.com/stock/news/2378538/tesla-tsla-stock-slides-as-market-rises-facts-to-know-before-you-trade',
#    'time_published': '20241203T224510',
#    'authors': ['Zacks Equity Research'],
#    'summary': 'Tesla (TSLA) closed at $351.42 in the latest trading session, marking a -1.59% move from the prior day.',
#    'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default192.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Earnings', 'relevance_score': '0.961735'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.266143'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.21899,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.531019',
#      'ticker_sentiment_score': '0.259051',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': 'Why Tesla Stock Jumped 38% in November',
#    'url': 'https://www.fool.com/investing/2024/12/03/why-tesla-stock-jumped-38-in-november/',
#    'time_published': '20241203T214900',
#    'authors': ['Jeremy Bowman'],
#    'summary': "After an underwhelming year, Tesla ( NASDAQ: TSLA ) stock soared last month, boosted by hopes that Trump's victory would help the electric vehicle ( EV ) maker, as CEO Elon Musk has made himself a close ally to president-elect Trump, spending heavily to aid his campaign before the election.As a ...",
#    'banner_image': 'https://media.ycharts.com/charts/2991b7f8b388d1599cc768a31ab60b36.png',
#    'source': 'Motley Fool',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.fool.com',
#    'topics': [{'topic': 'Earnings', 'relevance_score': '0.495866'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.266143'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.368279,
#    'overall_sentiment_label': 'Bullish',
#    'ticker_sentiment': [{'ticker': 'SPGI',
#      'relevance_score': '0.09186',
#      'ticker_sentiment_score': '0.148098',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.795641',
#      'ticker_sentiment_score': '0.534801',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': '3 Stocks Flashing Bullish Momentum: SOFI, TSLA, PLTR',
#    'url': 'https://www.zacks.com/commentary/2378521/3-stocks-flashing-bullish-momentum-sofi-tsla-pltr',
#    'time_published': '20241203T212400',
#    'authors': ['Derek Lewis'],
#    'summary': "Momentum investing is all about riding bullish trends where buyers are in control. And that's precisely what we've seen with Tesla, SoFi, and Palantir as of late.",
#    'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/69/61585.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.796627'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'},
#     {'topic': 'Earnings', 'relevance_score': '0.714479'},
#     {'topic': 'Real Estate & Construction', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.425229,
#    'overall_sentiment_label': 'Bullish',
#    'ticker_sentiment': [{'ticker': 'SOFI',
#      'relevance_score': '0.377142',
#      'ticker_sentiment_score': '0.518864',
#      'ticker_sentiment_label': 'Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.377142',
#      'ticker_sentiment_score': '0.267381',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': 'Meta Platforms Talks Political Misinformation, Content Moderation In Latest Blog - Meta Platforms  ( NASDAQ:META ) ',
#    'url': 'https://www.benzinga.com/tech/24/12/42302411/meta-platforms-talks-political-misinformation-content-moderation-in-latest-blog',
#    'time_published': '20241203T211731',
#    'authors': ['Anusuya Lahiri'],
#    'summary': "Meta Global Affairs President Nick Clegg flagged the company's evolving role amid global elections Meta updated and applied its content policies, introduced political content controls, conducted annual audits of words. Benzinga shares with you top insiders news",
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/03/zuckerberg-meta-shutterstock.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'News',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Technology', 'relevance_score': '0.5'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.108179'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': -0.080247,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'META',
#      'relevance_score': '0.423843',
#      'ticker_sentiment_score': '-0.211714',
#      'ticker_sentiment_label': 'Somewhat-Bearish'},
#     {'ticker': 'DJT',
#      'relevance_score': '0.147818',
#      'ticker_sentiment_score': '0.281037',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.147818',
#      'ticker_sentiment_score': '0.456205',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': 'Opportunities Among the Magnificent Seven  ( TSLA, AMZN, META ) ',
#    'url': 'https://www.zacks.com/commentary/2378514/opportunities-among-the-magnificent-seven-tsla-amzn-meta',
#    'time_published': '20241203T205700',
#    'authors': ['Ethan Feller'],
#    'summary': 'Tesla, Meta Platforms and Amazon all boast multiple bullish catalysts ...',
#    'banner_image': 'https://staticx-tuner.zacks.com/images/default_article_images/default263.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Retail & Wholesale', 'relevance_score': '0.333333'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.990999'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Earnings', 'relevance_score': '0.99915'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.473758,
#    'overall_sentiment_label': 'Bullish',
#    'ticker_sentiment': [{'ticker': 'META',
#      'relevance_score': '0.213048',
#      'ticker_sentiment_score': '0.508548',
#      'ticker_sentiment_label': 'Bullish'},
#     {'ticker': 'AMZN',
#      'relevance_score': '0.456884',
#      'ticker_sentiment_score': '0.561732',
#      'ticker_sentiment_label': 'Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.31482',
#      'ticker_sentiment_score': '0.48133',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': 'Tesla Vs. BYD: The EV Duel Heats Up - Tesla  ( NASDAQ:TSLA ) , BYD  ( OTC:BYDDF ) , BYD  ( OTC:BYDDY ) ',
#    'url': 'https://www.benzinga.com/trading-ideas/long-ideas/24/12/42299723/tesla-vs-byd-the-ev-duel-heats-up',
#    'time_published': '20241203T190741',
#    'authors': ['Surbhi Jain'],
#    'summary': 'In the electric vehicle ( EV ) battle, Tesla Inc. TSLA and BYD Co Ltd BYDDF BYDDY are two titans vying for dominance. Tesla dominates the premium EV space with its technological prowess and global brand appeal, while BYD, a Chinese heavyweight, is reshaping the mid-tier and budget markets with ...',
#    'banner_image': 'https://editorial-assets.benzinga.com/wp-content/uploads/2024/12/03094048/Screenshot-2024-12-03-at-8.09.55-PM.png',
#    'source': 'Benzinga',
#    'category_within_source': 'Trading',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Technology', 'relevance_score': '0.5'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.413559'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.356753,
#    'overall_sentiment_label': 'Bullish',
#    'ticker_sentiment': [{'ticker': 'BYDDF',
#      'relevance_score': '0.138464',
#      'ticker_sentiment_score': '0.154708',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'SSTK',
#      'relevance_score': '0.069495',
#      'ticker_sentiment_score': '0.296246',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.743088',
#      'ticker_sentiment_score': '0.560108',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': 'Historical Odds Favor Year-End Rally: Stocks to Watch',
#    'url': 'https://www.zacks.com/commentary/2378484/historical-odds-favor-year-end-rally-stocks-to-watch',
#    'time_published': '20241203T175000',
#    'authors': ['Bryan Hayes'],
#    'summary': 'If we finish in this territory, it would be the first time since 1998-99 that the S&P 500 rose 20% or more in consecutive years.',
#    'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/02/3765.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Economy - Monetary', 'relevance_score': '0.451494'},
#     {'topic': 'Retail & Wholesale', 'relevance_score': '0.333333'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.87644'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Earnings', 'relevance_score': '0.158519'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.172462,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'PSTG',
#      'relevance_score': '0.071463',
#      'ticker_sentiment_score': '0.017189',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.142355',
#      'ticker_sentiment_score': '0.044771',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'MA',
#      'relevance_score': '0.035768',
#      'ticker_sentiment_score': '0.080077',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'AMZN',
#      'relevance_score': '0.142355',
#      'ticker_sentiment_score': '0.073324',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'SQ',
#      'relevance_score': '0.107016',
#      'ticker_sentiment_score': '0.03966',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'MRVL',
#      'relevance_score': '0.071463',
#      'ticker_sentiment_score': '0.017189',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'Credo Technology Analyst Double Upgrades AI Play, Raises Forecast By Almost 200% - Credo Technology Group  ( NASDAQ:CRDO ) ',
#    'url': 'https://www.benzinga.com/analyst-ratings/analyst-color/24/12/42297692/credo-technology-analyst-double-upgrades-ai-play-raises-forecast-by-almost-200',
#    'time_published': '20241203T173016',
#    'authors': ['Priya Nigam'],
#    'summary': "Credo Technology Group Holding Ltd CRDO shares jumped almost 40% in early trading on Tuesday. The visibility into the company's growth inflection in the back half of the year improved significantly, according to BofA Securities.",
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/03/Credo-Technology-Group-Holding-Ltd.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'Trading',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Retail & Wholesale', 'relevance_score': '0.333333'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.538269'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Earnings', 'relevance_score': '0.158519'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.341926,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'MSFT',
#      'relevance_score': '0.279015',
#      'ticker_sentiment_score': '0.076646',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.279015',
#      'ticker_sentiment_score': '0.076646',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'CRDO',
#      'relevance_score': '0.7887',
#      'ticker_sentiment_score': '0.535718',
#      'ticker_sentiment_label': 'Bullish'},
#     {'ticker': 'AMZN',
#      'relevance_score': '0.279015',
#      'ticker_sentiment_score': '0.235667',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': 'Rule Breaker Investing: The 2024 Gratitude Episode',
#    'url': 'https://www.fool.com/investing/2024/12/03/rule-breaker-investing-the-2024-gratitude-episode/',
#    'time_published': '20241203T161700',
#    'authors': ['Motley Fool Staff'],
#    'summary': 'Motley Fool co-founder David Gardner explores the power of kindness, the transformative magic of community, and amazing journeys that listeners have shared with him over the years.',
#    'banner_image': 'https://g.foolcdn.com/editorial/images/799384/rbi_27.jpg',
#    'source': 'Motley Fool',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.fool.com',
#    'topics': [{'topic': 'Life Sciences', 'relevance_score': '0.25'},
#     {'topic': 'Retail & Wholesale', 'relevance_score': '0.25'},
#     {'topic': 'Financial Markets', 'relevance_score': '1.0'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.25'},
#     {'topic': 'Earnings', 'relevance_score': '0.310843'},
#     {'topic': 'Technology', 'relevance_score': '0.25'}],
#    'overall_sentiment_score': 0.293257,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'NFLX',
#      'relevance_score': '0.017162',
#      'ticker_sentiment_score': '0.051524',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'SHOP',
#      'relevance_score': '0.017162',
#      'ticker_sentiment_score': '0.068935',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'META',
#      'relevance_score': '0.011442',
#      'ticker_sentiment_score': '0.031171',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NVDA',
#      'relevance_score': '0.051453',
#      'ticker_sentiment_score': '0.058994',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'AAPL',
#      'relevance_score': '0.011442',
#      'ticker_sentiment_score': '0.073382',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'COST',
#      'relevance_score': '0.005721',
#      'ticker_sentiment_score': '0.184792',
# ...
#   {'title': 'Best-Performing ETF Areas of Last Week',
#    'url': 'https://www.zacks.com/stock/news/2378066/best-performing-etf-areas-of-last-week',
#    'time_published': '20241203T130000',
#    'authors': ['Sanghamitra Saha'],
#    'summary': 'Wall Street was upbeat last week with the Dow Jones and the S&P 500 hitting all-time highs last week.',
#    'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/a1/354.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.999336'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'},
#     {'topic': 'Earnings', 'relevance_score': '0.158519'},
#     {'topic': 'Blockchain', 'relevance_score': '0.158519'}],
#    'overall_sentiment_score': 0.290229,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.126119',
#      'ticker_sentiment_score': '0.263536',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'CRYPTO:BTC',
#      'relevance_score': '0.063258',
#      'ticker_sentiment_score': '0.223847',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'CRYPTO:ETH',
#      'relevance_score': '0.366061',
#      'ticker_sentiment_score': '0.459549',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': "Tesla Chair Estimates New Pay Plan For Elon Musk Could Cost $25B More. Now, Delaware Judge Has Rejected It For The 2nd Time: Here's What's Coming Next - Tesla  ( NASDAQ:TSLA ) ",
#    'url': 'https://www.benzinga.com/24/12/42287471/delaware-judge-rejects-musks-56b-pay-package-again-heres-whats-coming-next',
#    'time_published': '20241203T124524',
#    'authors': ['Anan Ashraf'],
#    'summary': 'A Delaware judge once again struck down a compensation plan for Tesla Inc. TSLA CEO Elon Musk from 2018 on Monday, six months after Tesla shareholders approved the $56 billion pay package for a second time.',
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/03/How-To-Invest-In-Elon-Musks-Private-Comp.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'News',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.161647'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.110043,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.630514',
#      'ticker_sentiment_score': '-0.076249',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': "US Stock Futures Dip As Dollar Slides And Treasuries Rise After S&P Hits 54th All-Time High This Year: Analyst Sees 'Further Upside' Of Around 10% In 2025 From Current Levels - Intel  ( NASDAQ:INTC ) ",
#    'url': 'https://www.benzinga.com/24/12/42286522/us-futures-marginally-changed-as-dollar-slips-and-treasuries-rise-after-sp-hits-54th-life-high-in-2024',
#    'time_published': '20241203T120812',
#    'authors': ['Rishabh Mishra'],
#    'summary': "U.S. stock futures were in negative territory during Tuesday's premarket hours as the dollar slipped to 106.3 level. The U.S. 10-year and two-year Treasury notes yielded 4.21% and 4.18%, respectively. Expectations of a further 25 basis point rate cut in December rose to 72.5%, according to CME ...",
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/03/Fat-Bear-Week-Returns.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'General',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Technology', 'relevance_score': '0.333333'},
#     {'topic': 'Finance', 'relevance_score': '0.333333'},
#     {'topic': 'Economy - Monetary', 'relevance_score': '0.838487'},
#     {'topic': 'Economy - Fiscal', 'relevance_score': '0.158519'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.999896'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Economy - Macro', 'relevance_score': '0.158519'}],
#    'overall_sentiment_score': 0.159489,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.209728',
#      'ticker_sentiment_score': '0.092333',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'IVZ',
#      'relevance_score': '0.042421',
#      'ticker_sentiment_score': '0.137496',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'INTC',
#      'relevance_score': '0.084722',
#      'ticker_sentiment_score': '0.106645',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'SMCI',
#      'relevance_score': '0.126784',
#      'ticker_sentiment_score': '0.318232',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'SHIM',
#      'relevance_score': '0.084722',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'FOREX:USD',
#      'relevance_score': '0.126784',
#      'ticker_sentiment_score': '-0.09621',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'CRYPTO:BTC',
#      'relevance_score': '0.084722',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': "Tesla Bear Craig Irwin Turns Bullish On EV Giant, Increases Price Target By 347%: 'There Are Abundant Positive Catalysts' - Tesla  ( NASDAQ:TSLA ) ",
#    'url': 'https://www.benzinga.com/24/12/42285783/tesla-bear-craig-irwin-turns-bullish-increases-price-target-from-85-to-380',
#    'time_published': '20241203T113553',
#    'authors': ['Anan Ashraf'],
#    'summary': 'Roth MKM analyst Craig Irwin on Monday raised Tesla Inc.\'s TSLA price target by 347% from $85 to $380 and upgraded the rating to a "buy" from "neutral." What Happened: A long-time Tesla bear, Irwin turned bullish on Tesla on Monday.',
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/03/musk-tesla-red-shutter.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'Markets',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.266143'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.287415,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.804667',
#      'ticker_sentiment_score': '0.55252',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': "Elon Musk says the latest rejection of his mega Tesla payday is 'totally crazy'",
#    'url': 'https://www.businessinsider.com/elon-musk-tesla-delaware-pay-deal-ruling-criticism-2024-12',
#    'time_published': '20241203T110401',
#    'authors': ['Nora Redmond'],
#    'summary': '• Elon Musk hit out at a Delaware judge\'s latest rejection of his mega pay package. • The Tesla CEO said the ruling was "totally crazy" and "absolute corruption." • Musk and Tesla supporters have criticized the ruling in posts on social media.',
#    'banner_image': 'https://i.insider.com/674ed896e45a68623a27838b?width=1024&format=jpeg',
#    'source': 'Business Insider',
#    'category_within_source': 'RSS',
#    'source_domain': 'www.businessinsider.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.108179'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': -0.009724,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.662945',
#      'ticker_sentiment_score': '-0.079148',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': "Tesla China Sees Robust Demand In Q4, With Registrations Up 14.2% YoY So Far: Expert Says EV Giant On Track For 'Best Quarter Ever' - Tesla  ( NASDAQ:TSLA ) ",
#    'url': 'https://www.benzinga.com/news/global/24/12/42284511/tesla-china-sees-robust-demand-in-q4-with-registrations-up-14-2-yoy-so-far-expert-says-ev-giant-on-tr',
#    'time_published': '20241203T103040',
#    'authors': ['Kaustubh Bagalkote'],
#    'summary': "Tesla Inc.'s TSLA insurance registrations in China reached 18,600 units for the week ending Dec. 1, indicating robust demand in one of the electric vehicle maker's key markets, according to data shared by industry analysts.",
#    'banner_image': 'https://editorial-assets.benzinga.com/wp-content/uploads/2024/12/03040325/Tesla-ratings.jpg',
#    'source': 'Benzinga',
#    'category_within_source': 'Markets',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.266143'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.296928,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.743214',
#      'ticker_sentiment_score': '0.381793',
#      'ticker_sentiment_label': 'Bullish'}]},
#   {'title': "Tesla Stock Soared 47% Since Nov. 5, but Here's a Better Way to Invest in the Self-Driving Revolution Right Now",
#    'url': 'https://www.fool.com/investing/2024/12/03/tesla-stock-soared-47-nov-5-invest-in-self-driving/',
#    'time_published': '20241203T101500',
#    'authors': ['Anthony Di Pizio'],
#    'summary': 'A top exchange-traded fund holds most of the stocks leading the autonomous driving revolution.',
#    'banner_image': 'https://g.foolcdn.com/image/?url=https%3A%2F%2Fg.foolcdn.com%2Feditorial%2Fimages%2F799547%2Fa-person-riding-in-a-futuristic-self-driving-robotaxi.jpg&op=resize&w=700',
#    'source': 'Motley Fool',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.fool.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.999974'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.333333'},
#     {'topic': 'Earnings', 'relevance_score': '0.158519'},
#     {'topic': 'Real Estate & Construction', 'relevance_score': '0.333333'},
#     {'topic': 'Technology', 'relevance_score': '0.333333'}],
#    'overall_sentiment_score': 0.209189,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'MSFT',
#      'relevance_score': '0.052801',
#      'ticker_sentiment_score': '0.116977',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'NVDA',
#      'relevance_score': '0.157483',
#      'ticker_sentiment_score': '0.072351',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.357049',
#      'ticker_sentiment_score': '0.083692',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'LINRF',
#      'relevance_score': '0.052801',
#      'ticker_sentiment_score': '0.174665',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'GM',
#      'relevance_score': '0.105372',
#      'ticker_sentiment_score': '0.161467',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'NKLA',
#      'relevance_score': '0.052801',
#      'ticker_sentiment_score': '-0.164031',
#      'ticker_sentiment_label': 'Somewhat-Bearish'},
#     {'ticker': 'PLUG',
#      'relevance_score': '0.052801',
#      'ticker_sentiment_score': '-0.164031',
#      'ticker_sentiment_label': 'Somewhat-Bearish'},
#     {'ticker': 'UBER',
#      'relevance_score': '0.052801',
#      'ticker_sentiment_score': '0.06992',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'PILBF',
#      'relevance_score': '0.052801',
#      'ticker_sentiment_score': '0.174665',
#      'ticker_sentiment_label': 'Somewhat-Bullish'}]},
#   {'title': 'SpaceX Reportedly Considers Tender Offer Valuing It At $350B, Surging From $210B In Previous Stake Sale - Destiny Tech100  ( NYSE:DXYZ ) ',
#    'url': 'https://www.benzinga.com/24/12/42284383/spacex-in-talks-for-tender-offer-valuing-company-at-about-350b-report',
#    'time_published': '20241203T101112',
#    'authors': ['Anan Ashraf'],
#    'summary': "Elon Musk's rocket manufacturing company SpaceX is reportedly in talks to sell insider shares of the company that could boost its valuation to about $350 billion.",
#    'banner_image': 'https://cdn.benzinga.com/files/images/story/2024/12/03/SpaceX.jpeg?width=1200&height=800&fit=crop',
#    'source': 'Benzinga',
#    'category_within_source': 'Markets',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'IPO', 'relevance_score': '0.310843'},
#     {'topic': 'Manufacturing', 'relevance_score': '0.5'},
#     {'topic': 'Mergers & Acquisitions', 'relevance_score': '0.158519'},
#     {'topic': 'Technology', 'relevance_score': '0.5'}],
#    'overall_sentiment_score': 0.211082,
#    'overall_sentiment_label': 'Somewhat-Bullish',
#    'ticker_sentiment': [{'ticker': 'DXYZ',
#      'relevance_score': '0.222838',
#      'ticker_sentiment_score': '0.386623',
#      'ticker_sentiment_label': 'Bullish'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.112532',
#      'ticker_sentiment_score': '0.006785',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'The Zacks Analyst Blog Highlights Tesla, Taiwan Semiconductor and Tencent',
#    'url': 'https://www.zacks.com/stock/news/2377993/the-zacks-analyst-blog-highlights-tesla-taiwan-semiconductor-and-tencent',
#    'time_published': '20241203T100000',
#    'authors': ['Zacks Investment Research'],
#    'summary': 'Tesla, Taiwan Semiconductor and Tencent are included in this Analyst Blog.',
#    'banner_image': 'https://staticx-tuner.zacks.com/images/articles/main/b9/441.jpg',
#    'source': 'Zacks Commentary',
#    'category_within_source': 'n/a',
#    'source_domain': 'www.zacks.com',
#    'topics': [{'topic': 'Economy - Monetary', 'relevance_score': '0.310843'},
#     {'topic': 'IPO', 'relevance_score': '0.158519'},
#     {'topic': 'Financial Markets', 'relevance_score': '0.413559'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.065135,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'SZIHF',
#      'relevance_score': '0.030563',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TSLA',
#      'relevance_score': '0.240786',
#      'ticker_sentiment_score': '0.164702',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'GM',
#      'relevance_score': '0.030563',
#      'ticker_sentiment_score': '0.100139',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'TCTZF',
#      'relevance_score': '0.121804',
#      'ticker_sentiment_score': '0.0',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'FOREX:EUR',
#      'relevance_score': '0.061081',
#      'ticker_sentiment_score': '-0.027105',
#      'ticker_sentiment_label': 'Neutral'},
#     {'ticker': 'FOREX:USD',
#      'relevance_score': '0.030563',
#      'ticker_sentiment_score': '0.17077',
#      'ticker_sentiment_label': 'Somewhat-Bullish'},
#     {'ticker': 'CRYPTO:BTC',
#      'relevance_score': '0.030563',
#      'ticker_sentiment_score': '-0.034293',
#      'ticker_sentiment_label': 'Neutral'}]},
#   {'title': 'Tesla Gives Cybertruck Production Line Workers 3 Days Off: Report - Tesla  ( NASDAQ:TSLA ) ',
#    'url': 'https://www.benzinga.com/24/12/42283708/tesla-gives-cybertruck-production-line-workers-three-days-off-report',
#    'time_published': '20241203T090538',
#    'authors': ['Anan Ashraf'],
#    'summary': 'EV giant Tesla Inc. TSLA has reportedly informed its workers on the Cybertruck production line at its gigafactory in Texas to take three days off starting from Tuesday. What Happened: Tesla told its employees in a memo seen by Business Insider that workers need not report to work on Tuesday, ...',
#    'banner_image': 'https://editorial-assets.benzinga.com/wp-content/uploads/2024/12/03040325/Tesla-ratings.jpg',
#    'source': 'Benzinga',
#    'category_within_source': 'News',
#    'source_domain': 'www.benzinga.com',
#    'topics': [{'topic': 'Financial Markets', 'relevance_score': '0.316726'},
#     {'topic': 'Manufacturing', 'relevance_score': '1.0'}],
#    'overall_sentiment_score': 0.072536,
#    'overall_sentiment_label': 'Neutral',
#    'ticker_sentiment': [{'ticker': 'TSLA',
#      'relevance_score': '0.63188',
#      'ticker_sentiment_score': '0.010741',
#      'ticker_sentiment_label': 'Neutral'}]}]}

# %%
structured_data = []
for entry in data['feed']:
    base_info = {
        'title': entry['title'],
        'url': entry['url'],
        'time_published': entry['time_published'],
        'overall_sentiment_score': entry['overall_sentiment_score'],
        'overall_sentiment_label': entry['overall_sentiment_label'],
    }
    # Extract ticker details
    for ticker_info in entry.get('ticker_sentiment', []):
        detailed_info = base_info.copy()
        detailed_info.update({
            'ticker': ticker_info['ticker'],
            'ticker_relevance_score': ticker_info['relevance_score'],
            'ticker_sentiment_score': ticker_info['ticker_sentiment_score'],
            'ticker_sentiment_label': ticker_info['ticker_sentiment_label'],
        })
        structured_data.append(detailed_info)

# Convert to DataFrame for better visualization
df = pd.DataFrame(structured_data)

# Sort by relevance score in descending order
df_sorted = df.sort_values(by='ticker_relevance_score', ascending=False)

# Get the top 10 entries
top_df = df_sorted.head(35)

# %%
for _, row in df_sorted.head(10).iterrows():
    print(f"  {row['ticker_relevance_score']} - {row['overall_sentiment_label']} - {row['ticker']}  - {row['url']}")
# Out:
#   0.939207 - Neutral - TSLA  - https://www.benzinga.com/tech/24/12/42312826/teslas-0-interest-loan-offer-on-model-3-y-to-end-mid-december-customers-who-order-now-can-get-delivery-befor
#   0.929758 - Somewhat-Bullish - TSLA  - https://www.benzinga.com/news/global/24/12/42322754/tesla-boosts-marketing-in-china-highlights-safety-features-during-year-end-sales-push-report
#   0.859898 - Somewhat-Bullish - TSLA  - https://www.benzinga.com/24/12/42311290/trader-danny-moses-says-he-is-no-longer-shorting-tesla
#   0.85567 - Somewhat-Bullish - CRYPTO:DOGE  - https://www.fool.com/investing/2024/12/04/where-will-dogecoin-be-in-1-year/
#   0.831224 - Neutral - TSLA  - https://www.benzinga.com/analyst-ratings/analyst-color/24/12/42319796/tesla-analyst-lowers-q4-delivery-estimate-says-2-dynamics-will-determine-ev-stocks-
#   0.804667 - Somewhat-Bullish - TSLA  - https://www.benzinga.com/24/12/42285783/tesla-bear-craig-irwin-turns-bullish-increases-price-target-from-85-to-380
#   0.795641 - Bullish - TSLA  - https://www.fool.com/investing/2024/12/03/why-tesla-stock-jumped-38-in-november/
#   0.7887 - Somewhat-Bullish - CRDO  - https://www.benzinga.com/analyst-ratings/analyst-color/24/12/42297692/credo-technology-analyst-double-upgrades-ai-play-raises-forecast-by-almost-200
#   0.78028 - Neutral - CHPT  - https://www.fool.com/investing/2024/12/03/why-chargepoint-wont-turn-a-profit-for-years-to-co/
#   0.743214 - Somewhat-Bullish - TSLA  - https://www.benzinga.com/news/global/24/12/42284511/tesla-china-sees-robust-demand-in-q4-with-registrations-up-14-2-yoy-so-far-expert-says-ev-giant-on-tr

# %%
system_prompt = f"""You are an expert at providing stock predictions and if its a good stock to buy or sell. Please answer my question provided.
example format -

<Example>
Here are the top stocks to buy and sell based on the provided article summaries:

		**Best to Buy:**

		1. **Tesla (TSLA)** - BUY: Tesla's stock has been experiencing a surge in recent months, and analysts are predicting it will continue to rise due to its strong sales and innovative technology.
		2. **Credo Technology Group (CRDO)** - BUY: Credo Technology Group's AI play is being double-upgraded, with a forecast increase of almost 200%, making it a promising investment opportunity.
		3. **SOFI (SOFI)** - BUY: SOFI's stock is flashing bullish momentum, making it a good opportunity to buy.
		4. **Amazon (AMZN)** - BUY: Amazon's stock is part of the "Magnificent Seven" and is expected to perform well, making it a good investment opportunity.
		5. **NVIDIA (NVDA)** - BUY: NVIDIA's stock is part of the "Magnificent Seven" and is expected to perform well, making it a good investment opportunity.

		**Best to Sell:**

		1. **Tesla (TSLA)** - SELL (Contrarian): Some analysts are predicting a decline in Tesla's global sales due to a slowdown in Europe and the US, making it a good opportunity to sell.
		2. **Meta Platforms (META)** - SELL: Meta's stock is experiencing a decline due to concerns about its content moderation and misinformation, making it a good opportunity to sell.

		**Neutral Stocks:**

		1. **ChargePoint Holdings (CHPT)** - NEUTRAL: ChargePoint's stock is neither considered a strong buy or sell, as it's expected to take years for it to turn a profit.
		2. **CrowdStrike Holdings (CRWD)** - NEUTRAL: CrowdStrike's stock is neither considered a strong buy or sell, as it's expected to have neutral momentum.
		3. **MicroStrategy (MSTR)** - NEUTRAL: MicroStrategy's stock is experiencing some hiccups, but overall, its momentum is neutral.



    <Example/>
order by best to buy followed by best to sell.
list top 10 urls at bottom
"""

# Convert DataFrame to string
formatted_string = top_df.to_string(index=False)
query = formatted_string
llm_response = client.chat.completions.create(
    model="llama-3.1-70b-versatile",
    messages=[
        {"role": "system", "content": system_prompt},
        {"role": "user", "content": query}
    ]
)

response = llm_response.choices[0].message.content

print(response)
# Out:
# **Best to Buy:**
#
# 1. **Credo Technology Group (CRDO)** - BUY: Credo Technology Group's AI play is being double-upgraded, with a forecast increase of almost 200%, making it a promising investment opportunity.
# 2. **SOFI (SOFI)** - BUY: SOFI's stock is flashing bullish momentum, making it a good opportunity to buy.
# 3. **NVIDIA (NVDA)** - BUY: NVIDIA's stock is part of the "Magnificent Seven" and is expected to perform well, making it a good investment opportunity.
# 4. **Tesla (TSLA)** - BUY: Tesla's stock has been experiencing a surge in recent months, and analysts are predicting it will continue to rise due to its strong sales and innovative technology.
# 5. **Amazon (AMZN)** - BUY: Amazon's stock is part of the "Magnificent Seven" and is expected to perform well, making it a good investment opportunity.
# 6. **General Motors (GM)** - BUY: General Motors' stock is experiencing a surge due to its decision to offload stakes in a battery plant at Michigan, making it a good opportunity to buy.
# 7. **Ethereum (ETH)** - BUY: Ethereum's stock is experiencing a surge due to its strong performance in the crypto market, making it a good investment opportunity.
#
# **Best to Sell:**
#
# 1. **Tesla (TSLA)** - SELL (Contrarian): Some analysts are predicting a decline in Tesla's global sales due to a slowdown in Europe and the US, making it a good opportunity to sell.
# 2. **Meta Platforms (META)** - SELL: Meta's stock is experiencing a decline due to concerns about its content moderation and misinformation, making it a good opportunity to sell.
#
# **Neutral Stocks:**
#
# 1. **CrowdStrike Holdings (CRWD)** - NEUTRAL: CrowdStrike's stock is neither considered a strong buy or sell, as it's expected to have neutral momentum.
# 2. **MicroStrategy (MSTR)** - NEUTRAL: MicroStrategy's stock is experiencing some hiccups, but overall, its momentum is neutral.
# 3. **ChargePoint Holdings (CHPT)** - NEUTRAL: ChargePoint's stock is neither considered a strong buy or sell, as it's expected to take years for it to turn a profit.
#
#
# **Top 10 URLs:**
#
# 1. https://www.benzinga.com/tech/24/12/42312826/teslas-0-interest-loan-offer-on-model-3-y-to-end-mid-december-customers-who-order-now-can-get-delivery-befor
# 2. https://www.benzinga.com/news/global/24/12/42322754/tesla-boosts-marketing-in-china-highlights-safety-features-during-year-end-sales-push-report
# 3. https://www.benzinga.com/24/12/42311290/trader-danny-moses-says-he-is-no-longer-shorting-tesla
# 4. https://www.fool.com/investing/2024/12/04/where-will-dogecoin-be-in-1-year/
# 5. https://www.benzinga.com/analyst-ratings/analyst-color/24/12/42319796/tesla-analyst-lowers-q4-delivery-estimate-says-2-dynamics-will-determine-ev-stocks-
# 6. https://www.benzinga.com/24/12/42285783/tesla-bear-craig-irwin-turns-bullish-increases-price-target-from-85-to-380
# 7. https://www.fool.com/investing/2024/12/03/why-tesla-stock-jumped-38-in-november/
# 8. https://www.benzinga.com/analyst-ratings/analyst-color/24/12/42297692/credo-technology-analyst-double-upgrades-ai-play-raises-forecast-by-almost-200
# 9. https://www.fool.com/investing/2024/12/03/why-chargepoint-wont-turn-a-profit-for-years-to-co/
# 10. https://www.benzinga.com/news/global/24/12/42284511/tesla-china-sees-robust-demand-in-q4-with-registrations-up-14-2-yoy-so-far-expert-says-ev-giant-on-tr
